# %%
## load necessary libraries
# %matplotlib inline
#%ma3tplotlib widget
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
from matplotlib.widgets import Slider, Button, RadioButtons
import os,time,subprocess,glob
from PIL import Image
import cripser as cr
import tcripser as tcr
import persim
import skimage
from skimage import io
from skimage.transform import rotate
from skimage.data import cells3d
from skimage.filters import threshold_otsu
from scipy.ndimage import distance_transform_edt,convolve
import os, re
from tkinter import filedialog
import tkinter as tk

# %%
import re
numbers = re.compile(r'(\d+)')
def numericalSort(value):
    parts = numbers.split(value)
    parts[1::2] = map(int, parts[1::2])
    return parts
def dt(img,radius=15,signed=False):
#    bw_img = (img >= rank.otsu(img, disk(radius)))
    bw_img = (img >= threshold_otsu(img))
    dt_img = distance_transform_edt(bw_img)
    if signed:
        dt_img -= distance_transform_edt(~bw_img)
    return(dt_img)

def explore_slices(data, cmap="gray"):
    #from ipywidgets import interact
    N = data.shape[-1]
    #@interact(plane=(0, N - 1))
    def display_slice(plane=N//2):
        fig, ax = plt.subplots(figsize=(20, 5))
        plt.imshow(data[:,:,plane],cmap=cmap)
        plt.show()
    return display_slice

if __name__ == "__main__":
    # Provide the path to the input DICOM folder and the output PNG folder
    input_folder = "C:\\Users\\Aneesh PB\\Downloads\\Topology Project\\Training image 20\\Bengin cases"

    for imgfile in sorted(os.listdir(input_folder), key=numericalSort):
    #for imgfile in os.listdir(input_folder):
        #imgfile = '/content/drive/MyDrive/project/png/1-001.png'
        # load image data
        #print(imgfile)
        imgfile = os.path.join(input_folder, imgfile)
        if os.path.isfile(imgfile):
            #print(imgfile)
            img2d = np.array(Image.open(imgfile))
        else: # if file is not found, load the demo img from skimage
            img2d = skimage.data.camera()
            io.imsave(imgfile, img2d)

        # apply distance transform
        img2d_dt = dt(img2d)

        fig,axs = plt.subplots(1,2)
        axs[0].imshow(img2d)
        #axs[1].imshow(img2d_dt)
        print(img2d.shape, img2d.dtype, f"{np.min(img2d)}--{np.max(img2d)}")
        
        #print(f"Conversion completed for {imgfile}")
        start = time.time()
        pd = cr.computePH(img2d)
        pds = [pd[pd[:,0] == i] for i in range(3)]
        print("Betti numbers: ",[len(pds[i]) for i in range(len(pds))])

        # compute PH for the T-construction of the original image (pixel value filtration)
        pdt = tcr.computePH(img2d)
        pdst = [pdt[pdt[:,0] == i] for i in range(3)]
        print("Betti numbers: ",[len(pdst[i]) for i in range(len(pdst))])

        print ("elapsed_time:{} sec".format(time.time() - start))
       # print(pds)
        ## plot persistent diagram using persim
        #fig,axs = plt.subplots(1,1)
        persim.plot_diagrams([p[:,1:3] for p in pds], ax=axs[1])
        fig.subplots_adjust(wspace=0.4)
        #persim.plot_diagrams([p[:,1:3] for p in pdst], ax=axs[1], title='T-construction')
        plt.show()
    print(f"All conversions completed")
# Out:
# C:\Users\Aneesh PB\AppData\Local\Temp\ipykernel_40244\2552932544.py:9: UserWarning: threshold_otsu is expected to work correctly only for grayscale images; image shape (512, 512, 3) looks like that of an RGB image.
#   bw_img = (img >= threshold_otsu(img))
# (512, 512, 3) uint8 37--255
# Betti numbers:  [18986, 12127, 0]
# Betti numbers:  [12552, 18610, 0]
# elapsed_time:4.271557807922363 sec
# c:\Users\Aneesh PB\AppData\Local\Programs\Python\Python312\Lib\site-packages\persim\visuals.py:87: RuntimeWarning: overflow encountered in cast
#   diagrams = [dgm.astype(np.float32, copy=True) for dgm in diagrams]
# C:\Users\Aneesh PB\AppData\Local\Temp\ipykernel_40244\2552932544.py:9: UserWarning: threshold_otsu is expected to work correctly only for grayscale images; image shape (512, 512, 3) looks like that of an RGB image.
#   bw_img = (img >= threshold_otsu(img))
# (512, 512, 3) uint8 37--255
# Betti numbers:  [18802, 12077, 0]
# Betti numbers:  [12573, 18391, 0]
# elapsed_time:3.974154233932495 sec
# c:\Users\Aneesh PB\AppData\Local\Programs\Python\Python312\Lib\site-packages\persim\visuals.py:87: RuntimeWarning: overflow encountered in cast
#   diagrams = [dgm.astype(np.float32, copy=True) for dgm in diagrams]
# C:\Users\Aneesh PB\AppData\Local\Temp\ipykernel_40244\2552932544.py:9: UserWarning: threshold_otsu is expected to work correctly only for grayscale images; image shape (512, 512, 3) looks like that of an RGB image.
#   bw_img = (img >= threshold_otsu(img))
# (512, 512, 3) uint8 37--255
# Betti numbers:  [18523, 11849, 0]
# Betti numbers:  [12352, 18010, 0]
# elapsed_time:4.096867799758911 sec
# c:\Users\Aneesh PB\AppData\Local\Programs\Python\Python312\Lib\site-packages\persim\visuals.py:87: RuntimeWarning: overflow encountered in cast
#   diagrams = [dgm.astype(np.float32, copy=True) for dgm in diagrams]
# C:\Users\Aneesh PB\AppData\Local\Temp\ipykernel_40244\2552932544.py:9: UserWarning: threshold_otsu is expected to work correctly only for grayscale images; image shape (512, 512, 3) looks like that of an RGB image.
#   bw_img = (img >= threshold_otsu(img))
# (512, 512, 3) uint8 37--255
# Betti numbers:  [19177, 12299, 0]
# Betti numbers:  [12496, 18963, 0]
# elapsed_time:4.187448263168335 sec
# c:\Users\Aneesh PB\AppData\Local\Programs\Python\Python312\Lib\site-packages\persim\visuals.py:87: RuntimeWarning: overflow encountered in cast
#   diagrams = [dgm.astype(np.float32, copy=True) for dgm in diagrams]
# C:\Users\Aneesh PB\AppData\Local\Temp\ipykernel_40244\2552932544.py:9: UserWarning: threshold_otsu is expected to work correctly only for grayscale images; image shape (512, 512, 3) looks like that of an RGB image.
#   bw_img = (img >= threshold_otsu(img))
# (512, 512, 3) uint8 37--255
# Betti numbers:  [19310, 12372, 0]
# Betti numbers:  [12634, 18961, 0]
# elapsed_time:4.3850977420806885 sec
# c:\Users\Aneesh PB\AppData\Local\Programs\Python\Python312\Lib\site-packages\persim\visuals.py:87: RuntimeWarning: overflow encountered in cast
#   diagrams = [dgm.astype(np.float32, copy=True) for dgm in diagrams]
# C:\Users\Aneesh PB\AppData\Local\Temp\ipykernel_40244\2552932544.py:9: UserWarning: threshold_otsu is expected to work correctly only for grayscale images; image shape (512, 512, 3) looks like that of an RGB image.
#   bw_img = (img >= threshold_otsu(img))
# (512, 512, 3) uint8 37--255
# Betti numbers:  [19122, 12135, 0]
# Betti numbers:  [12508, 18750, 0]
# elapsed_time:4.208714962005615 sec
# c:\Users\Aneesh PB\AppData\Local\Programs\Python\Python312\Lib\site-packages\persim\visuals.py:87: RuntimeWarning: overflow encountered in cast
#   diagrams = [dgm.astype(np.float32, copy=True) for dgm in diagrams]
# C:\Users\Aneesh PB\AppData\Local\Temp\ipykernel_40244\2552932544.py:9: UserWarning: threshold_otsu is expected to work correctly only for grayscale images; image shape (512, 512, 3) looks like that of an RGB image.
#   bw_img = (img >= threshold_otsu(img))
# (512, 512, 3) uint8 37--255
# Betti numbers:  [18969, 12236, 0]
# Betti numbers:  [12605, 18786, 0]
# elapsed_time:4.856452703475952 sec
# c:\Users\Aneesh PB\AppData\Local\Programs\Python\Python312\Lib\site-packages\persim\visuals.py:87: RuntimeWarning: overflow encountered in cast
#   diagrams = [dgm.astype(np.float32, copy=True) for dgm in diagrams]
# C:\Users\Aneesh PB\AppData\Local\Temp\ipykernel_40244\2552932544.py:9: UserWarning: threshold_otsu is expected to work correctly only for grayscale images; image shape (512, 512, 3) looks like that of an RGB image.
#   bw_img = (img >= threshold_otsu(img))
# (512, 512, 3) uint8 37--255
# Betti numbers:  [18969, 12236, 0]
# Betti numbers:  [12605, 18786, 0]
# elapsed_time:4.220247268676758 sec
# c:\Users\Aneesh PB\AppData\Local\Programs\Python\Python312\Lib\site-packages\persim\visuals.py:87: RuntimeWarning: overflow encountered in cast
#   diagrams = [dgm.astype(np.float32, copy=True) for dgm in diagrams]
# C:\Users\Aneesh PB\AppData\Local\Temp\ipykernel_40244\2552932544.py:9: UserWarning: threshold_otsu is expected to work correctly only for grayscale images; image shape (512, 512, 3) looks like that of an RGB image.
#   bw_img = (img >= threshold_otsu(img))
# (512, 512, 3) uint8 37--255
# Betti numbers:  [18265, 12233, 0]
# Betti numbers:  [12690, 17761, 0]
# elapsed_time:4.284281969070435 sec
# c:\Users\Aneesh PB\AppData\Local\Programs\Python\Python312\Lib\site-packages\persim\visuals.py:87: RuntimeWarning: overflow encountered in cast
#   diagrams = [dgm.astype(np.float32, copy=True) for dgm in diagrams]
# C:\Users\Aneesh PB\AppData\Local\Temp\ipykernel_40244\2552932544.py:9: UserWarning: threshold_otsu is expected to work correctly only for grayscale images; image shape (512, 512, 3) looks like that of an RGB image.
#   bw_img = (img >= threshold_otsu(img))
# (512, 512, 3) uint8 37--255
# Betti numbers:  [18248, 12140, 0]
# Betti numbers:  [12615, 17804, 0]
# elapsed_time:4.336570978164673 sec
# c:\Users\Aneesh PB\AppData\Local\Programs\Python\Python312\Lib\site-packages\persim\visuals.py:87: RuntimeWarning: overflow encountered in cast
#   diagrams = [dgm.astype(np.float32, copy=True) for dgm in diagrams]
# C:\Users\Aneesh PB\AppData\Local\Temp\ipykernel_40244\2552932544.py:9: UserWarning: threshold_otsu is expected to work correctly only for grayscale images; image shape (512, 512, 3) looks like that of an RGB image.
#   bw_img = (img >= threshold_otsu(img))
# (512, 512, 3) uint8 37--255
# Betti numbers:  [18144, 12125, 0]
# Betti numbers:  [12577, 17737, 0]
# elapsed_time:4.115586280822754 sec
# c:\Users\Aneesh PB\AppData\Local\Programs\Python\Python312\Lib\site-packages\persim\visuals.py:87: RuntimeWarning: overflow encountered in cast
#   diagrams = [dgm.astype(np.float32, copy=True) for dgm in diagrams]
# C:\Users\Aneesh PB\AppData\Local\Temp\ipykernel_40244\2552932544.py:9: UserWarning: threshold_otsu is expected to work correctly only for grayscale images; image shape (512, 512, 3) looks like that of an RGB image.
#   bw_img = (img >= threshold_otsu(img))
# (512, 512, 3) uint8 37--255
# Betti numbers:  [17953, 11822, 0]
# Betti numbers:  [12473, 17462, 0]
# elapsed_time:4.286058187484741 sec
# c:\Users\Aneesh PB\AppData\Local\Programs\Python\Python312\Lib\site-packages\persim\visuals.py:87: RuntimeWarning: overflow encountered in cast
#   diagrams = [dgm.astype(np.float32, copy=True) for dgm in diagrams]
# C:\Users\Aneesh PB\AppData\Local\Temp\ipykernel_40244\2552932544.py:9: UserWarning: threshold_otsu is expected to work correctly only for grayscale images; image shape (512, 512, 3) looks like that of an RGB image.
#   bw_img = (img >= threshold_otsu(img))
# (512, 512, 3) uint8 37--255
# Betti numbers:  [18004, 11711, 0]
# Betti numbers:  [12223, 17597, 0]
# elapsed_time:4.250904321670532 sec
# c:\Users\Aneesh PB\AppData\Local\Programs\Python\Python312\Lib\site-packages\persim\visuals.py:87: RuntimeWarning: overflow encountered in cast
#   diagrams = [dgm.astype(np.float32, copy=True) for dgm in diagrams]
# C:\Users\Aneesh PB\AppData\Local\Temp\ipykernel_40244\2552932544.py:9: UserWarning: threshold_otsu is expected to work correctly only for grayscale images; image shape (512, 512, 3) looks like that of an RGB image.
#   bw_img = (img >= threshold_otsu(img))
# (512, 512, 3) uint8 37--255
# Betti numbers:  [17836, 11801, 0]
# Betti numbers:  [12221, 17254, 0]
# elapsed_time:4.223207473754883 sec
# c:\Users\Aneesh PB\AppData\Local\Programs\Python\Python312\Lib\site-packages\persim\visuals.py:87: RuntimeWarning: overflow encountered in cast
#   diagrams = [dgm.astype(np.float32, copy=True) for dgm in diagrams]
# C:\Users\Aneesh PB\AppData\Local\Temp\ipykernel_40244\2552932544.py:9: UserWarning: threshold_otsu is expected to work correctly only for grayscale images; image shape (512, 512, 3) looks like that of an RGB image.
#   bw_img = (img >= threshold_otsu(img))
# (512, 512, 3) uint8 37--255
# Betti numbers:  [17836, 11801, 0]
# Betti numbers:  [12221, 17254, 0]
# elapsed_time:4.100939989089966 sec
# c:\Users\Aneesh PB\AppData\Local\Programs\Python\Python312\Lib\site-packages\persim\visuals.py:87: RuntimeWarning: overflow encountered in cast
#   diagrams = [dgm.astype(np.float32, copy=True) for dgm in diagrams]
# C:\Users\Aneesh PB\AppData\Local\Temp\ipykernel_40244\2552932544.py:9: UserWarning: threshold_otsu is expected to work correctly only for grayscale images; image shape (512, 512, 3) looks like that of an RGB image.
#   bw_img = (img >= threshold_otsu(img))
# (512, 512, 3) uint8 37--255
# Betti numbers:  [17927, 11949, 0]
# Betti numbers:  [12368, 17450, 0]
# elapsed_time:4.2546916007995605 sec
# c:\Users\Aneesh PB\AppData\Local\Programs\Python\Python312\Lib\site-packages\persim\visuals.py:87: RuntimeWarning: overflow encountered in cast
#   diagrams = [dgm.astype(np.float32, copy=True) for dgm in diagrams]
# C:\Users\Aneesh PB\AppData\Local\Temp\ipykernel_40244\2552932544.py:9: UserWarning: threshold_otsu is expected to work correctly only for grayscale images; image shape (512, 512, 3) looks like that of an RGB image.
#   bw_img = (img >= threshold_otsu(img))
# (512, 512, 3) uint8 37--255
# Betti numbers:  [17927, 11949, 0]
# Betti numbers:  [12368, 17450, 0]
# elapsed_time:4.181946277618408 sec
# c:\Users\Aneesh PB\AppData\Local\Programs\Python\Python312\Lib\site-packages\persim\visuals.py:87: RuntimeWarning: overflow encountered in cast
#   diagrams = [dgm.astype(np.float32, copy=True) for dgm in diagrams]
# C:\Users\Aneesh PB\AppData\Local\Temp\ipykernel_40244\2552932544.py:9: UserWarning: threshold_otsu is expected to work correctly only for grayscale images; image shape (512, 512, 3) looks like that of an RGB image.
#   bw_img = (img >= threshold_otsu(img))
# (512, 512, 3) uint8 37--255
# Betti numbers:  [17954, 11826, 0]
# Betti numbers:  [12204, 17380, 0]
# elapsed_time:4.22478985786438 sec
# c:\Users\Aneesh PB\AppData\Local\Programs\Python\Python312\Lib\site-packages\persim\visuals.py:87: RuntimeWarning: overflow encountered in cast
#   diagrams = [dgm.astype(np.float32, copy=True) for dgm in diagrams]
# C:\Users\Aneesh PB\AppData\Local\Temp\ipykernel_40244\2552932544.py:9: UserWarning: threshold_otsu is expected to work correctly only for grayscale images; image shape (512, 512, 3) looks like that of an RGB image.
#   bw_img = (img >= threshold_otsu(img))
# (512, 512, 3) uint8 37--255
# Betti numbers:  [17795, 11685, 0]
# Betti numbers:  [12080, 17244, 0]
# elapsed_time:4.723800420761108 sec
# c:\Users\Aneesh PB\AppData\Local\Programs\Python\Python312\Lib\site-packages\persim\visuals.py:87: RuntimeWarning: overflow encountered in cast
#   diagrams = [dgm.astype(np.float32, copy=True) for dgm in diagrams]
# C:\Users\Aneesh PB\AppData\Local\Temp\ipykernel_40244\2552932544.py:9: UserWarning: threshold_otsu is expected to work correctly only for grayscale images; image shape (512, 512, 3) looks like that of an RGB image.
#   bw_img = (img >= threshold_otsu(img))
# (512, 512, 3) uint8 37--255
# Betti numbers:  [18499, 12082, 0]
# Betti numbers:  [12755, 17839, 0]
# elapsed_time:3.974971294403076 sec
# c:\Users\Aneesh PB\AppData\Local\Programs\Python\Python312\Lib\site-packages\persim\visuals.py:87: RuntimeWarning: overflow encountered in cast
#   diagrams = [dgm.astype(np.float32, copy=True) for dgm in diagrams]
# C:\Users\Aneesh PB\AppData\Local\Temp\ipykernel_40244\2552932544.py:9: UserWarning: threshold_otsu is expected to work correctly only for grayscale images; image shape (512, 512, 3) looks like that of an RGB image.
#   bw_img = (img >= threshold_otsu(img))
# (512, 512, 3) uint8 37--255
# Betti numbers:  [18488, 12176, 0]
# Betti numbers:  [12580, 18077, 0]
# elapsed_time:3.8917438983917236 sec
# c:\Users\Aneesh PB\AppData\Local\Programs\Python\Python312\Lib\site-packages\persim\visuals.py:87: RuntimeWarning: overflow encountered in cast
#   diagrams = [dgm.astype(np.float32, copy=True) for dgm in diagrams]
# C:\Users\Aneesh PB\AppData\Local\Temp\ipykernel_40244\2552932544.py:9: UserWarning: threshold_otsu is expected to work correctly only for grayscale images; image shape (512, 512, 3) looks like that of an RGB image.
#   bw_img = (img >= threshold_otsu(img))
# (512, 512, 3) uint8 37--255
# Betti numbers:  [18488, 12176, 0]
# Betti numbers:  [12580, 18077, 0]
# elapsed_time:3.8698291778564453 sec
# c:\Users\Aneesh PB\AppData\Local\Programs\Python\Python312\Lib\site-packages\persim\visuals.py:87: RuntimeWarning: overflow encountered in cast
#   diagrams = [dgm.astype(np.float32, copy=True) for dgm in diagrams]
# C:\Users\Aneesh PB\AppData\Local\Temp\ipykernel_40244\2552932544.py:9: UserWarning: threshold_otsu is expected to work correctly only for grayscale images; image shape (512, 512, 3) looks like that of an RGB image.
#   bw_img = (img >= threshold_otsu(img))
# (512, 512, 3) uint8 37--255
# Betti numbers:  [17586, 11605, 0]
# Betti numbers:  [12225, 17019, 0]
# elapsed_time:4.101550817489624 sec
# c:\Users\Aneesh PB\AppData\Local\Programs\Python\Python312\Lib\site-packages\persim\visuals.py:87: RuntimeWarning: overflow encountered in cast
#   diagrams = [dgm.astype(np.float32, copy=True) for dgm in diagrams]
# C:\Users\Aneesh PB\AppData\Local\Temp\ipykernel_40244\2552932544.py:9: UserWarning: threshold_otsu is expected to work correctly only for grayscale images; image shape (512, 512, 3) looks like that of an RGB image.
#   bw_img = (img >= threshold_otsu(img))
# (512, 512, 3) uint8 37--255
# Betti numbers:  [17547, 11669, 0]
# Betti numbers:  [12034, 17123, 0]
# elapsed_time:3.9190542697906494 sec
# c:\Users\Aneesh PB\AppData\Local\Programs\Python\Python312\Lib\site-packages\persim\visuals.py:87: RuntimeWarning: overflow encountered in cast
#   diagrams = [dgm.astype(np.float32, copy=True) for dgm in diagrams]
# C:\Users\Aneesh PB\AppData\Local\Temp\ipykernel_40244\2552932544.py:9: UserWarning: threshold_otsu is expected to work correctly only for grayscale images; image shape (512, 512, 3) looks like that of an RGB image.
#   bw_img = (img >= threshold_otsu(img))
# (512, 512, 3) uint8 37--255
# Betti numbers:  [18525, 11752, 0]
# Betti numbers:  [12525, 17714, 0]
# elapsed_time:3.9681954383850098 sec
# c:\Users\Aneesh PB\AppData\Local\Programs\Python\Python312\Lib\site-packages\persim\visuals.py:87: RuntimeWarning: overflow encountered in cast
#   diagrams = [dgm.astype(np.float32, copy=True) for dgm in diagrams]
# C:\Users\Aneesh PB\AppData\Local\Temp\ipykernel_40244\2552932544.py:9: UserWarning: threshold_otsu is expected to work correctly only for grayscale images; image shape (512, 512, 3) looks like that of an RGB image.
#   bw_img = (img >= threshold_otsu(img))
# (512, 512, 3) uint8 37--255
# Betti numbers:  [18525, 11752, 0]
# Betti numbers:  [12525, 17714, 0]
# elapsed_time:3.901191473007202 sec
# c:\Users\Aneesh PB\AppData\Local\Programs\Python\Python312\Lib\site-packages\persim\visuals.py:87: RuntimeWarning: overflow encountered in cast
#   diagrams = [dgm.astype(np.float32, copy=True) for dgm in diagrams]
# C:\Users\Aneesh PB\AppData\Local\Temp\ipykernel_40244\2552932544.py:9: UserWarning: threshold_otsu is expected to work correctly only for grayscale images; image shape (512, 512, 3) looks like that of an RGB image.
#   bw_img = (img >= threshold_otsu(img))
# (512, 512, 3) uint8 37--255
# Betti numbers:  [18236, 11897, 0]
# Betti numbers:  [12516, 17682, 0]
# elapsed_time:4.041866779327393 sec
# c:\Users\Aneesh PB\AppData\Local\Programs\Python\Python312\Lib\site-packages\persim\visuals.py:87: RuntimeWarning: overflow encountered in cast
#   diagrams = [dgm.astype(np.float32, copy=True) for dgm in diagrams]
# C:\Users\Aneesh PB\AppData\Local\Temp\ipykernel_40244\2552932544.py:9: UserWarning: threshold_otsu is expected to work correctly only for grayscale images; image shape (512, 512, 3) looks like that of an RGB image.
#   bw_img = (img >= threshold_otsu(img))
# (512, 512, 3) uint8 37--255
# Betti numbers:  [18782, 12079, 0]
# Betti numbers:  [12730, 18196, 0]
# elapsed_time:5.554478168487549 sec
# c:\Users\Aneesh PB\AppData\Local\Programs\Python\Python312\Lib\site-packages\persim\visuals.py:87: RuntimeWarning: overflow encountered in cast
#   diagrams = [dgm.astype(np.float32, copy=True) for dgm in diagrams]
# C:\Users\Aneesh PB\AppData\Local\Temp\ipykernel_40244\2552932544.py:9: UserWarning: threshold_otsu is expected to work correctly only for grayscale images; image shape (512, 512, 3) looks like that of an RGB image.
#   bw_img = (img >= threshold_otsu(img))
# (512, 512, 3) uint8 37--255
# Betti numbers:  [16408, 10656, 0]
# Betti numbers:  [11468, 15534, 0]
# elapsed_time:3.996755361557007 sec
# c:\Users\Aneesh PB\AppData\Local\Programs\Python\Python312\Lib\site-packages\persim\visuals.py:87: RuntimeWarning: overflow encountered in cast
#   diagrams = [dgm.astype(np.float32, copy=True) for dgm in diagrams]
# C:\Users\Aneesh PB\AppData\Local\Temp\ipykernel_40244\2552932544.py:9: UserWarning: threshold_otsu is expected to work correctly only for grayscale images; image shape (512, 512, 3) looks like that of an RGB image.
#   bw_img = (img >= threshold_otsu(img))
# (512, 512, 3) uint8 37--255
# Betti numbers:  [16316, 10864, 0]
# Betti numbers:  [11514, 15755, 0]
# elapsed_time:5.387693881988525 sec
# c:\Users\Aneesh PB\AppData\Local\Programs\Python\Python312\Lib\site-packages\persim\visuals.py:87: RuntimeWarning: overflow encountered in cast
#   diagrams = [dgm.astype(np.float32, copy=True) for dgm in diagrams]
# C:\Users\Aneesh PB\AppData\Local\Temp\ipykernel_40244\2552932544.py:9: UserWarning: threshold_otsu is expected to work correctly only for grayscale images; image shape (512, 512, 3) looks like that of an RGB image.
#   bw_img = (img >= threshold_otsu(img))
# (512, 512, 3) uint8 37--255
# Betti numbers:  [17036, 10943, 0]
# Betti numbers:  [11694, 16314, 0]
# elapsed_time:6.4077630043029785 sec
# c:\Users\Aneesh PB\AppData\Local\Programs\Python\Python312\Lib\site-packages\persim\visuals.py:87: RuntimeWarning: overflow encountered in cast
#   diagrams = [dgm.astype(np.float32, copy=True) for dgm in diagrams]
# C:\Users\Aneesh PB\AppData\Local\Temp\ipykernel_40244\2552932544.py:9: UserWarning: threshold_otsu is expected to work correctly only for grayscale images; image shape (512, 512, 3) looks like that of an RGB image.
#   bw_img = (img >= threshold_otsu(img))
# (512, 512, 3) uint8 37--255
# Betti numbers:  [16777, 10980, 0]
# Betti numbers:  [11681, 16101, 0]
# elapsed_time:5.5324037075042725 sec
# c:\Users\Aneesh PB\AppData\Local\Programs\Python\Python312\Lib\site-packages\persim\visuals.py:87: RuntimeWarning: overflow encountered in cast
#   diagrams = [dgm.astype(np.float32, copy=True) for dgm in diagrams]
# C:\Users\Aneesh PB\AppData\Local\Temp\ipykernel_40244\2552932544.py:9: UserWarning: threshold_otsu is expected to work correctly only for grayscale images; image shape (512, 512, 3) looks like that of an RGB image.
#   bw_img = (img >= threshold_otsu(img))
# (512, 512, 3) uint8 37--255
# Betti numbers:  [16890, 10938, 0]
# Betti numbers:  [11598, 16127, 0]
# elapsed_time:5.515592813491821 sec
# c:\Users\Aneesh PB\AppData\Local\Programs\Python\Python312\Lib\site-packages\persim\visuals.py:87: RuntimeWarning: overflow encountered in cast
#   diagrams = [dgm.astype(np.float32, copy=True) for dgm in diagrams]
# C:\Users\Aneesh PB\AppData\Local\Temp\ipykernel_40244\2552932544.py:9: UserWarning: threshold_otsu is expected to work correctly only for grayscale images; image shape (512, 512, 3) looks like that of an RGB image.
#   bw_img = (img >= threshold_otsu(img))
# (512, 512, 3) uint8 37--255
# Betti numbers:  [18334, 12071, 0]
# Betti numbers:  [12587, 17846, 0]
# elapsed_time:5.6106648445129395 sec
# c:\Users\Aneesh PB\AppData\Local\Programs\Python\Python312\Lib\site-packages\persim\visuals.py:87: RuntimeWarning: overflow encountered in cast
#   diagrams = [dgm.astype(np.float32, copy=True) for dgm in diagrams]
# C:\Users\Aneesh PB\AppData\Local\Temp\ipykernel_40244\2552932544.py:9: UserWarning: threshold_otsu is expected to work correctly only for grayscale images; image shape (512, 512, 3) looks like that of an RGB image.
#   bw_img = (img >= threshold_otsu(img))
# (512, 512, 3) uint8 37--255
# Betti numbers:  [18714, 11883, 0]
# Betti numbers:  [12486, 18141, 0]
# elapsed_time:5.6351659297943115 sec
# c:\Users\Aneesh PB\AppData\Local\Programs\Python\Python312\Lib\site-packages\persim\visuals.py:87: RuntimeWarning: overflow encountered in cast
#   diagrams = [dgm.astype(np.float32, copy=True) for dgm in diagrams]
# C:\Users\Aneesh PB\AppData\Local\Temp\ipykernel_40244\2552932544.py:9: UserWarning: threshold_otsu is expected to work correctly only for grayscale images; image shape (512, 512, 3) looks like that of an RGB image.
#   bw_img = (img >= threshold_otsu(img))
# (512, 512, 3) uint8 37--255
# Betti numbers:  [18256, 11922, 0]
# Betti numbers:  [12206, 18150, 0]
# elapsed_time:5.5944294929504395 sec
# c:\Users\Aneesh PB\AppData\Local\Programs\Python\Python312\Lib\site-packages\persim\visuals.py:87: RuntimeWarning: overflow encountered in cast
#   diagrams = [dgm.astype(np.float32, copy=True) for dgm in diagrams]
# C:\Users\Aneesh PB\AppData\Local\Temp\ipykernel_40244\2552932544.py:9: UserWarning: threshold_otsu is expected to work correctly only for grayscale images; image shape (512, 512, 3) looks like that of an RGB image.
#   bw_img = (img >= threshold_otsu(img))
# (512, 512, 3) uint8 37--255
# Betti numbers:  [18329, 11746, 0]
# Betti numbers:  [12274, 17796, 0]
# elapsed_time:5.683563709259033 sec
# c:\Users\Aneesh PB\AppData\Local\Programs\Python\Python312\Lib\site-packages\persim\visuals.py:87: RuntimeWarning: overflow encountered in cast
#   diagrams = [dgm.astype(np.float32, copy=True) for dgm in diagrams]
# C:\Users\Aneesh PB\AppData\Local\Temp\ipykernel_40244\2552932544.py:9: UserWarning: threshold_otsu is expected to work correctly only for grayscale images; image shape (512, 512, 3) looks like that of an RGB image.
#   bw_img = (img >= threshold_otsu(img))
# (512, 512, 3) uint8 37--255
# Betti numbers:  [18129, 11654, 0]
# Betti numbers:  [12289, 17540, 0]
# elapsed_time:5.594177484512329 sec
# c:\Users\Aneesh PB\AppData\Local\Programs\Python\Python312\Lib\site-packages\persim\visuals.py:87: RuntimeWarning: overflow encountered in cast
#   diagrams = [dgm.astype(np.float32, copy=True) for dgm in diagrams]
# C:\Users\Aneesh PB\AppData\Local\Temp\ipykernel_40244\2552932544.py:9: UserWarning: threshold_otsu is expected to work correctly only for grayscale images; image shape (512, 512, 3) looks like that of an RGB image.
#   bw_img = (img >= threshold_otsu(img))
# (512, 512, 3) uint8 37--255
# Betti numbers:  [18212, 11689, 0]
# Betti numbers:  [12305, 17776, 0]
# elapsed_time:5.6576714515686035 sec
# c:\Users\Aneesh PB\AppData\Local\Programs\Python\Python312\Lib\site-packages\persim\visuals.py:87: RuntimeWarning: overflow encountered in cast
#   diagrams = [dgm.astype(np.float32, copy=True) for dgm in diagrams]
# C:\Users\Aneesh PB\AppData\Local\Temp\ipykernel_40244\2552932544.py:9: UserWarning: threshold_otsu is expected to work correctly only for grayscale images; image shape (512, 512, 3) looks like that of an RGB image.
#   bw_img = (img >= threshold_otsu(img))
# (512, 512, 3) uint8 37--255
# Betti numbers:  [18042, 11659, 0]
# Betti numbers:  [12186, 17561, 0]
# elapsed_time:5.579411506652832 sec
# c:\Users\Aneesh PB\AppData\Local\Programs\Python\Python312\Lib\site-packages\persim\visuals.py:87: RuntimeWarning: overflow encountered in cast
#   diagrams = [dgm.astype(np.float32, copy=True) for dgm in diagrams]
# C:\Users\Aneesh PB\AppData\Local\Temp\ipykernel_40244\2552932544.py:9: UserWarning: threshold_otsu is expected to work correctly only for grayscale images; image shape (512, 512, 3) looks like that of an RGB image.
#   bw_img = (img >= threshold_otsu(img))
# (512, 512, 3) uint8 37--255
# Betti numbers:  [17508, 11689, 0]
# Betti numbers:  [12229, 17044, 0]
# elapsed_time:5.7030205726623535 sec
# c:\Users\Aneesh PB\AppData\Local\Programs\Python\Python312\Lib\site-packages\persim\visuals.py:87: RuntimeWarning: overflow encountered in cast
#   diagrams = [dgm.astype(np.float32, copy=True) for dgm in diagrams]
# C:\Users\Aneesh PB\AppData\Local\Temp\ipykernel_40244\2552932544.py:9: UserWarning: threshold_otsu is expected to work correctly only for grayscale images; image shape (512, 512, 3) looks like that of an RGB image.
#   bw_img = (img >= threshold_otsu(img))
# (512, 512, 3) uint8 37--255
# Betti numbers:  [17766, 11752, 0]
# Betti numbers:  [12231, 17192, 0]
# elapsed_time:5.625111818313599 sec
# c:\Users\Aneesh PB\AppData\Local\Programs\Python\Python312\Lib\site-packages\persim\visuals.py:87: RuntimeWarning: overflow encountered in cast
#   diagrams = [dgm.astype(np.float32, copy=True) for dgm in diagrams]
# C:\Users\Aneesh PB\AppData\Local\Temp\ipykernel_40244\2552932544.py:9: UserWarning: threshold_otsu is expected to work correctly only for grayscale images; image shape (512, 512, 3) looks like that of an RGB image.
#   bw_img = (img >= threshold_otsu(img))
# (512, 512, 3) uint8 37--255
# Betti numbers:  [17808, 11678, 0]
# Betti numbers:  [12341, 17207, 0]
# elapsed_time:5.811983108520508 sec
# c:\Users\Aneesh PB\AppData\Local\Programs\Python\Python312\Lib\site-packages\persim\visuals.py:87: RuntimeWarning: overflow encountered in cast
#   diagrams = [dgm.astype(np.float32, copy=True) for dgm in diagrams]
# C:\Users\Aneesh PB\AppData\Local\Temp\ipykernel_40244\2552932544.py:9: UserWarning: threshold_otsu is expected to work correctly only for grayscale images; image shape (512, 512, 3) looks like that of an RGB image.
#   bw_img = (img >= threshold_otsu(img))
# (512, 512, 3) uint8 37--255
# Betti numbers:  [18114, 11811, 0]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[3], line 58
#      56 # compute PH for the T-construction of the original image (pixel value filtration)
#      57 pdt = tcr.computePH(img2d)
# ---> 58 pdst = [pdt[pdt[:,0] == i] for i in range(3)]
#      59 print("Betti numbers: ",[len(pdst[i]) for i in range(len(pdst))])
#      61 print ("elapsed_time:{} sec".format(time.time() - start))
#
# KeyboardInterrupt:
