# %%
## load necessary libraries
# %matplotlib inline
#%ma3tplotlib widget
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
from matplotlib.widgets import Slider, Button, RadioButtons
import os,time,subprocess,glob
from PIL import Image
import cripser as cr
import tcripser as tcr
import persim
import skimage
from skimage import io
from skimage.transform import rotate
from skimage.data import cells3d
from skimage.filters import threshold_otsu
from scipy.ndimage import distance_transform_edt,convolve
import os, re
from tkinter import filedialog
import tkinter as tk

# %%
import re
numbers = re.compile(r'(\d+)')
def numericalSort(value):
    parts = numbers.split(value)
    parts[1::2] = map(int, parts[1::2])
    return parts
def dt(img,radius=15,signed=False):
#    bw_img = (img >= rank.otsu(img, disk(radius)))
    bw_img = (img >= threshold_otsu(img))
    dt_img = distance_transform_edt(bw_img)
    if signed:
        dt_img -= distance_transform_edt(~bw_img)
    return(dt_img)

def explore_slices(data, cmap="gray"):
    #from ipywidgets import interact
    N = data.shape[-1]
    #@interact(plane=(0, N - 1))
    def display_slice(plane=N//2):
        fig, ax = plt.subplots(figsize=(20, 5))
        plt.imshow(data[:,:,plane],cmap=cmap)
        plt.show()
    return display_slice

if __name__ == "__main__":
    # Provide the path to the input DICOM folder and the output PNG folder
    input_folder = "C:\\Users\\Aneesh PB\\Downloads\\Topology Project\\Training image 20\\Malignant cases"

    for imgfile in sorted(os.listdir(input_folder), key=numericalSort):
    #for imgfile in os.listdir(input_folder):
        #imgfile = '/content/drive/MyDrive/project/png/1-001.png'
        # load image data
        #print(imgfile)
        imgfile = os.path.join(input_folder, imgfile)
        if os.path.isfile(imgfile):
            #print(imgfile)
            img2d = np.array(Image.open(imgfile))
        else: # if file is not found, load the demo img from skimage
            img2d = skimage.data.camera()
            io.imsave(imgfile, img2d)

        # apply distance transform
        img2d_dt = dt(img2d)

        fig,axs = plt.subplots(1,2)
        axs[0].imshow(img2d)
        #axs[1].imshow(img2d_dt)
        print(img2d.shape, img2d.dtype, f"{np.min(img2d)}--{np.max(img2d)}")
        
        #print(f"Conversion completed for {imgfile}")
        start = time.time()
        pd = cr.computePH(img2d)
        pds = [pd[pd[:,0] == i] for i in range(3)]
        print("Betti numbers: ",[len(pds[i]) for i in range(len(pds))])

        # compute PH for the T-construction of the original image (pixel value filtration)
        pdt = tcr.computePH(img2d)
        pdst = [pdt[pdt[:,0] == i] for i in range(3)]
        print("Betti numbers: ",[len(pdst[i]) for i in range(len(pdst))])

        print ("elapsed_time:{} sec".format(time.time() - start))
       # print(pds)
        ## plot persistent diagram using persim
        #fig,axs = plt.subplots(1,1)
        persim.plot_diagrams([p[:,1:3] for p in pds], ax=axs[1])
        #persim.plot_diagrams([p[:,1:3] for p in pdst], ax=axs[1], title='T-construction')
        fig.subplots_adjust(wspace=0.4)
        plt.show()
    print(f"All conversions completed")
# Out:
# C:\Users\Aneesh PB\AppData\Local\Temp\ipykernel_47800\2072340124.py:9: UserWarning: threshold_otsu is expected to work correctly only for grayscale images; image shape (512, 512, 3) looks like that of an RGB image.
#   bw_img = (img >= threshold_otsu(img))
# (512, 512, 3) uint8 37--255
# Betti numbers:  [8035, 5539, 0]
# Betti numbers:  [5660, 8131, 0]
# elapsed_time:3.9218063354492188 sec
# c:\Users\Aneesh PB\AppData\Local\Programs\Python\Python312\Lib\site-packages\persim\visuals.py:87: RuntimeWarning: overflow encountered in cast
#   diagrams = [dgm.astype(np.float32, copy=True) for dgm in diagrams]
# C:\Users\Aneesh PB\AppData\Local\Temp\ipykernel_47800\2072340124.py:9: UserWarning: threshold_otsu is expected to work correctly only for grayscale images; image shape (512, 512, 3) looks like that of an RGB image.
#   bw_img = (img >= threshold_otsu(img))
# (512, 512, 3) uint8 37--255
# Betti numbers:  [12635, 8539, 0]
# Betti numbers:  [9146, 12032, 0]
# elapsed_time:4.117851972579956 sec
# c:\Users\Aneesh PB\AppData\Local\Programs\Python\Python312\Lib\site-packages\persim\visuals.py:87: RuntimeWarning: overflow encountered in cast
#   diagrams = [dgm.astype(np.float32, copy=True) for dgm in diagrams]
# C:\Users\Aneesh PB\AppData\Local\Temp\ipykernel_47800\2072340124.py:9: UserWarning: threshold_otsu is expected to work correctly only for grayscale images; image shape (512, 512, 3) looks like that of an RGB image.
#   bw_img = (img >= threshold_otsu(img))
# (512, 512, 3) uint8 37--255
# Betti numbers:  [12643, 8596, 0]
# Betti numbers:  [9099, 12110, 0]
# elapsed_time:4.13817024230957 sec
# c:\Users\Aneesh PB\AppData\Local\Programs\Python\Python312\Lib\site-packages\persim\visuals.py:87: RuntimeWarning: overflow encountered in cast
#   diagrams = [dgm.astype(np.float32, copy=True) for dgm in diagrams]
# C:\Users\Aneesh PB\AppData\Local\Temp\ipykernel_47800\2072340124.py:9: UserWarning: threshold_otsu is expected to work correctly only for grayscale images; image shape (512, 512, 3) looks like that of an RGB image.
#   bw_img = (img >= threshold_otsu(img))
# (512, 512, 3) uint8 37--255
# Betti numbers:  [12635, 8698, 0]
# Betti numbers:  [9136, 12282, 0]
# elapsed_time:4.312065601348877 sec
# c:\Users\Aneesh PB\AppData\Local\Programs\Python\Python312\Lib\site-packages\persim\visuals.py:87: RuntimeWarning: overflow encountered in cast
#   diagrams = [dgm.astype(np.float32, copy=True) for dgm in diagrams]
# C:\Users\Aneesh PB\AppData\Local\Temp\ipykernel_47800\2072340124.py:9: UserWarning: threshold_otsu is expected to work correctly only for grayscale images; image shape (512, 512, 3) looks like that of an RGB image.
#   bw_img = (img >= threshold_otsu(img))
# (512, 512, 3) uint8 37--255
# Betti numbers:  [12741, 8716, 0]
# Betti numbers:  [9263, 12308, 0]
# elapsed_time:4.327263116836548 sec
# c:\Users\Aneesh PB\AppData\Local\Programs\Python\Python312\Lib\site-packages\persim\visuals.py:87: RuntimeWarning: overflow encountered in cast
#   diagrams = [dgm.astype(np.float32, copy=True) for dgm in diagrams]
# C:\Users\Aneesh PB\AppData\Local\Temp\ipykernel_47800\2072340124.py:9: UserWarning: threshold_otsu is expected to work correctly only for grayscale images; image shape (512, 512, 3) looks like that of an RGB image.
#   bw_img = (img >= threshold_otsu(img))
# (512, 512, 3) uint8 37--255
# Betti numbers:  [12745, 8764, 0]
# Betti numbers:  [9258, 12333, 0]
# elapsed_time:4.208647012710571 sec
# c:\Users\Aneesh PB\AppData\Local\Programs\Python\Python312\Lib\site-packages\persim\visuals.py:87: RuntimeWarning: overflow encountered in cast
#   diagrams = [dgm.astype(np.float32, copy=True) for dgm in diagrams]
# C:\Users\Aneesh PB\AppData\Local\Temp\ipykernel_47800\2072340124.py:9: UserWarning: threshold_otsu is expected to work correctly only for grayscale images; image shape (512, 512, 3) looks like that of an RGB image.
#   bw_img = (img >= threshold_otsu(img))
# (512, 512, 3) uint8 37--255
# Betti numbers:  [12744, 8719, 0]
# Betti numbers:  [9182, 12335, 0]
# elapsed_time:4.231393575668335 sec
# c:\Users\Aneesh PB\AppData\Local\Programs\Python\Python312\Lib\site-packages\persim\visuals.py:87: RuntimeWarning: overflow encountered in cast
#   diagrams = [dgm.astype(np.float32, copy=True) for dgm in diagrams]
# C:\Users\Aneesh PB\AppData\Local\Temp\ipykernel_47800\2072340124.py:9: UserWarning: threshold_otsu is expected to work correctly only for grayscale images; image shape (512, 512, 3) looks like that of an RGB image.
#   bw_img = (img >= threshold_otsu(img))
# (512, 512, 3) uint8 37--255
# Betti numbers:  [12091, 7877, 0]
# Betti numbers:  [8464, 11607, 0]
# elapsed_time:4.670264005661011 sec
# c:\Users\Aneesh PB\AppData\Local\Programs\Python\Python312\Lib\site-packages\persim\visuals.py:87: RuntimeWarning: overflow encountered in cast
#   diagrams = [dgm.astype(np.float32, copy=True) for dgm in diagrams]
# C:\Users\Aneesh PB\AppData\Local\Temp\ipykernel_47800\2072340124.py:9: UserWarning: threshold_otsu is expected to work correctly only for grayscale images; image shape (512, 512, 3) looks like that of an RGB image.
#   bw_img = (img >= threshold_otsu(img))
# (512, 512, 3) uint8 37--255
# Betti numbers:  [12142, 7944, 0]
# Betti numbers:  [8604, 11811, 0]
# elapsed_time:4.1401591300964355 sec
# c:\Users\Aneesh PB\AppData\Local\Programs\Python\Python312\Lib\site-packages\persim\visuals.py:87: RuntimeWarning: overflow encountered in cast
#   diagrams = [dgm.astype(np.float32, copy=True) for dgm in diagrams]
# C:\Users\Aneesh PB\AppData\Local\Temp\ipykernel_47800\2072340124.py:9: UserWarning: threshold_otsu is expected to work correctly only for grayscale images; image shape (512, 512, 3) looks like that of an RGB image.
#   bw_img = (img >= threshold_otsu(img))
# (512, 512, 3) uint8 37--255
# Betti numbers:  [11689, 7740, 0]
# Betti numbers:  [8321, 11309, 0]
# elapsed_time:4.058124780654907 sec
# c:\Users\Aneesh PB\AppData\Local\Programs\Python\Python312\Lib\site-packages\persim\visuals.py:87: RuntimeWarning: overflow encountered in cast
#   diagrams = [dgm.astype(np.float32, copy=True) for dgm in diagrams]
# C:\Users\Aneesh PB\AppData\Local\Temp\ipykernel_47800\2072340124.py:9: UserWarning: threshold_otsu is expected to work correctly only for grayscale images; image shape (512, 512, 3) looks like that of an RGB image.
#   bw_img = (img >= threshold_otsu(img))
# (512, 512, 3) uint8 37--255
# Betti numbers:  [11652, 7597, 0]
# Betti numbers:  [8171, 11130, 0]
# elapsed_time:4.2841949462890625 sec
# c:\Users\Aneesh PB\AppData\Local\Programs\Python\Python312\Lib\site-packages\persim\visuals.py:87: RuntimeWarning: overflow encountered in cast
#   diagrams = [dgm.astype(np.float32, copy=True) for dgm in diagrams]
# C:\Users\Aneesh PB\AppData\Local\Temp\ipykernel_47800\2072340124.py:9: UserWarning: threshold_otsu is expected to work correctly only for grayscale images; image shape (512, 512, 3) looks like that of an RGB image.
#   bw_img = (img >= threshold_otsu(img))
# (512, 512, 3) uint8 37--255
# Betti numbers:  [11826, 7682, 0]
# Betti numbers:  [8286, 11275, 0]
# elapsed_time:4.09451150894165 sec
# c:\Users\Aneesh PB\AppData\Local\Programs\Python\Python312\Lib\site-packages\persim\visuals.py:87: RuntimeWarning: overflow encountered in cast
#   diagrams = [dgm.astype(np.float32, copy=True) for dgm in diagrams]
# C:\Users\Aneesh PB\AppData\Local\Temp\ipykernel_47800\2072340124.py:9: UserWarning: threshold_otsu is expected to work correctly only for grayscale images; image shape (512, 512, 3) looks like that of an RGB image.
#   bw_img = (img >= threshold_otsu(img))
# (512, 512, 3) uint8 37--255
# Betti numbers:  [11860, 7706, 0]
# Betti numbers:  [8384, 11248, 0]
# elapsed_time:4.055002450942993 sec
# c:\Users\Aneesh PB\AppData\Local\Programs\Python\Python312\Lib\site-packages\persim\visuals.py:87: RuntimeWarning: overflow encountered in cast
#   diagrams = [dgm.astype(np.float32, copy=True) for dgm in diagrams]
# C:\Users\Aneesh PB\AppData\Local\Temp\ipykernel_47800\2072340124.py:9: UserWarning: threshold_otsu is expected to work correctly only for grayscale images; image shape (512, 512, 3) looks like that of an RGB image.
#   bw_img = (img >= threshold_otsu(img))
# (512, 512, 3) uint8 37--255
# Betti numbers:  [12108, 7886, 0]
# Betti numbers:  [8538, 11691, 0]
# elapsed_time:4.023717880249023 sec
# c:\Users\Aneesh PB\AppData\Local\Programs\Python\Python312\Lib\site-packages\persim\visuals.py:87: RuntimeWarning: overflow encountered in cast
#   diagrams = [dgm.astype(np.float32, copy=True) for dgm in diagrams]
# C:\Users\Aneesh PB\AppData\Local\Temp\ipykernel_47800\2072340124.py:9: UserWarning: threshold_otsu is expected to work correctly only for grayscale images; image shape (512, 512, 3) looks like that of an RGB image.
#   bw_img = (img >= threshold_otsu(img))
# (512, 512, 3) uint8 37--255
# Betti numbers:  [12276, 7909, 0]
# Betti numbers:  [8475, 11687, 0]
# elapsed_time:4.251106023788452 sec
# c:\Users\Aneesh PB\AppData\Local\Programs\Python\Python312\Lib\site-packages\persim\visuals.py:87: RuntimeWarning: overflow encountered in cast
#   diagrams = [dgm.astype(np.float32, copy=True) for dgm in diagrams]
# C:\Users\Aneesh PB\AppData\Local\Temp\ipykernel_47800\2072340124.py:9: UserWarning: threshold_otsu is expected to work correctly only for grayscale images; image shape (512, 512, 3) looks like that of an RGB image.
#   bw_img = (img >= threshold_otsu(img))
# (512, 512, 3) uint8 37--255
# Betti numbers:  [12254, 8003, 0]
# Betti numbers:  [8451, 11791, 0]
# elapsed_time:4.069926977157593 sec
# c:\Users\Aneesh PB\AppData\Local\Programs\Python\Python312\Lib\site-packages\persim\visuals.py:87: RuntimeWarning: overflow encountered in cast
#   diagrams = [dgm.astype(np.float32, copy=True) for dgm in diagrams]
# C:\Users\Aneesh PB\AppData\Local\Temp\ipykernel_47800\2072340124.py:9: UserWarning: threshold_otsu is expected to work correctly only for grayscale images; image shape (512, 512, 3) looks like that of an RGB image.
#   bw_img = (img >= threshold_otsu(img))
# (512, 512, 3) uint8 37--255
# Betti numbers:  [8147, 5551, 0]
# Betti numbers:  [5736, 8307, 0]
# elapsed_time:3.9266905784606934 sec
# c:\Users\Aneesh PB\AppData\Local\Programs\Python\Python312\Lib\site-packages\persim\visuals.py:87: RuntimeWarning: overflow encountered in cast
#   diagrams = [dgm.astype(np.float32, copy=True) for dgm in diagrams]
# C:\Users\Aneesh PB\AppData\Local\Temp\ipykernel_47800\2072340124.py:9: UserWarning: threshold_otsu is expected to work correctly only for grayscale images; image shape (512, 512, 3) looks like that of an RGB image.
#   bw_img = (img >= threshold_otsu(img))
# (512, 512, 3) uint8 37--255
# Betti numbers:  [8064, 5592, 0]
# Betti numbers:  [5634, 8331, 0]
# elapsed_time:3.8223156929016113 sec
# c:\Users\Aneesh PB\AppData\Local\Programs\Python\Python312\Lib\site-packages\persim\visuals.py:87: RuntimeWarning: overflow encountered in cast
#   diagrams = [dgm.astype(np.float32, copy=True) for dgm in diagrams]
# C:\Users\Aneesh PB\AppData\Local\Temp\ipykernel_47800\2072340124.py:9: UserWarning: threshold_otsu is expected to work correctly only for grayscale images; image shape (512, 512, 3) looks like that of an RGB image.
#   bw_img = (img >= threshold_otsu(img))
# (512, 512, 3) uint8 37--255
# Betti numbers:  [18247, 11078, 0]
# Betti numbers:  [11338, 17895, 0]
# elapsed_time:3.8907692432403564 sec
# c:\Users\Aneesh PB\AppData\Local\Programs\Python\Python312\Lib\site-packages\persim\visuals.py:87: RuntimeWarning: overflow encountered in cast
#   diagrams = [dgm.astype(np.float32, copy=True) for dgm in diagrams]
# C:\Users\Aneesh PB\AppData\Local\Temp\ipykernel_47800\2072340124.py:9: UserWarning: threshold_otsu is expected to work correctly only for grayscale images; image shape (512, 512, 3) looks like that of an RGB image.
#   bw_img = (img >= threshold_otsu(img))
# (512, 512, 3) uint8 37--255
# Betti numbers:  [18413, 11150, 0]
# Betti numbers:  [11589, 17875, 0]
# elapsed_time:4.395100116729736 sec
# c:\Users\Aneesh PB\AppData\Local\Programs\Python\Python312\Lib\site-packages\persim\visuals.py:87: RuntimeWarning: overflow encountered in cast
#   diagrams = [dgm.astype(np.float32, copy=True) for dgm in diagrams]
# C:\Users\Aneesh PB\AppData\Local\Temp\ipykernel_47800\2072340124.py:9: UserWarning: threshold_otsu is expected to work correctly only for grayscale images; image shape (512, 512, 3) looks like that of an RGB image.
#   bw_img = (img >= threshold_otsu(img))
# (512, 512, 3) uint8 37--255
# Betti numbers:  [18519, 11295, 0]
# Betti numbers:  [11641, 18200, 0]
# elapsed_time:3.8040225505828857 sec
# c:\Users\Aneesh PB\AppData\Local\Programs\Python\Python312\Lib\site-packages\persim\visuals.py:87: RuntimeWarning: overflow encountered in cast
#   diagrams = [dgm.astype(np.float32, copy=True) for dgm in diagrams]
# C:\Users\Aneesh PB\AppData\Local\Temp\ipykernel_47800\2072340124.py:9: UserWarning: threshold_otsu is expected to work correctly only for grayscale images; image shape (512, 512, 3) looks like that of an RGB image.
#   bw_img = (img >= threshold_otsu(img))
# (512, 512, 3) uint8 37--255
# Betti numbers:  [18557, 11287, 0]
# Betti numbers:  [11464, 18379, 0]
# elapsed_time:4.030222177505493 sec
# c:\Users\Aneesh PB\AppData\Local\Programs\Python\Python312\Lib\site-packages\persim\visuals.py:87: RuntimeWarning: overflow encountered in cast
#   diagrams = [dgm.astype(np.float32, copy=True) for dgm in diagrams]
# C:\Users\Aneesh PB\AppData\Local\Temp\ipykernel_47800\2072340124.py:9: UserWarning: threshold_otsu is expected to work correctly only for grayscale images; image shape (512, 512, 3) looks like that of an RGB image.
#   bw_img = (img >= threshold_otsu(img))
# (512, 512, 3) uint8 37--255
# Betti numbers:  [18467, 11237, 0]
# Betti numbers:  [11408, 18206, 0]
# elapsed_time:3.879394054412842 sec
# c:\Users\Aneesh PB\AppData\Local\Programs\Python\Python312\Lib\site-packages\persim\visuals.py:87: RuntimeWarning: overflow encountered in cast
#   diagrams = [dgm.astype(np.float32, copy=True) for dgm in diagrams]
# C:\Users\Aneesh PB\AppData\Local\Temp\ipykernel_47800\2072340124.py:9: UserWarning: threshold_otsu is expected to work correctly only for grayscale images; image shape (512, 512, 3) looks like that of an RGB image.
#   bw_img = (img >= threshold_otsu(img))
# (512, 512, 3) uint8 37--255
# Betti numbers:  [18340, 11167, 0]
# Betti numbers:  [11312, 18323, 0]
# elapsed_time:3.9464004039764404 sec
# c:\Users\Aneesh PB\AppData\Local\Programs\Python\Python312\Lib\site-packages\persim\visuals.py:87: RuntimeWarning: overflow encountered in cast
#   diagrams = [dgm.astype(np.float32, copy=True) for dgm in diagrams]
# C:\Users\Aneesh PB\AppData\Local\Temp\ipykernel_47800\2072340124.py:9: UserWarning: threshold_otsu is expected to work correctly only for grayscale images; image shape (512, 512, 3) looks like that of an RGB image.
#   bw_img = (img >= threshold_otsu(img))
# (512, 512, 3) uint8 37--255
# Betti numbers:  [18688, 11254, 0]
# Betti numbers:  [11716, 18312, 0]
# elapsed_time:3.795799493789673 sec
# c:\Users\Aneesh PB\AppData\Local\Programs\Python\Python312\Lib\site-packages\persim\visuals.py:87: RuntimeWarning: overflow encountered in cast
#   diagrams = [dgm.astype(np.float32, copy=True) for dgm in diagrams]
# C:\Users\Aneesh PB\AppData\Local\Temp\ipykernel_47800\2072340124.py:9: UserWarning: threshold_otsu is expected to work correctly only for grayscale images; image shape (512, 512, 3) looks like that of an RGB image.
#   bw_img = (img >= threshold_otsu(img))
# (512, 512, 3) uint8 37--255
# Betti numbers:  [18241, 11340, 0]
# Betti numbers:  [11516, 18172, 0]
# elapsed_time:3.88991117477417 sec
# c:\Users\Aneesh PB\AppData\Local\Programs\Python\Python312\Lib\site-packages\persim\visuals.py:87: RuntimeWarning: overflow encountered in cast
#   diagrams = [dgm.astype(np.float32, copy=True) for dgm in diagrams]
# C:\Users\Aneesh PB\AppData\Local\Temp\ipykernel_47800\2072340124.py:9: UserWarning: threshold_otsu is expected to work correctly only for grayscale images; image shape (512, 512, 3) looks like that of an RGB image.
#   bw_img = (img >= threshold_otsu(img))
# (512, 512, 3) uint8 37--255
# Betti numbers:  [18155, 10751, 0]
# Betti numbers:  [11247, 17454, 0]
# elapsed_time:5.615017652511597 sec
# c:\Users\Aneesh PB\AppData\Local\Programs\Python\Python312\Lib\site-packages\persim\visuals.py:87: RuntimeWarning: overflow encountered in cast
#   diagrams = [dgm.astype(np.float32, copy=True) for dgm in diagrams]
# C:\Users\Aneesh PB\AppData\Local\Temp\ipykernel_47800\2072340124.py:9: UserWarning: threshold_otsu is expected to work correctly only for grayscale images; image shape (512, 512, 3) looks like that of an RGB image.
#   bw_img = (img >= threshold_otsu(img))
# (512, 512, 3) uint8 37--255
# Betti numbers:  [18114, 10814, 0]
# Betti numbers:  [11367, 17385, 0]
# elapsed_time:3.895270824432373 sec
# c:\Users\Aneesh PB\AppData\Local\Programs\Python\Python312\Lib\site-packages\persim\visuals.py:87: RuntimeWarning: overflow encountered in cast
#   diagrams = [dgm.astype(np.float32, copy=True) for dgm in diagrams]
# C:\Users\Aneesh PB\AppData\Local\Temp\ipykernel_47800\2072340124.py:9: UserWarning: threshold_otsu is expected to work correctly only for grayscale images; image shape (512, 512, 3) looks like that of an RGB image.
#   bw_img = (img >= threshold_otsu(img))
# (512, 512, 3) uint8 37--255
# Betti numbers:  [17453, 10391, 0]
# Betti numbers:  [11290, 16579, 0]
# elapsed_time:4.907566547393799 sec
# c:\Users\Aneesh PB\AppData\Local\Programs\Python\Python312\Lib\site-packages\persim\visuals.py:87: RuntimeWarning: overflow encountered in cast
#   diagrams = [dgm.astype(np.float32, copy=True) for dgm in diagrams]
# C:\Users\Aneesh PB\AppData\Local\Temp\ipykernel_47800\2072340124.py:9: UserWarning: threshold_otsu is expected to work correctly only for grayscale images; image shape (512, 512, 3) looks like that of an RGB image.
#   bw_img = (img >= threshold_otsu(img))
# (512, 512, 3) uint8 37--255
# Betti numbers:  [14393, 9778, 0]
# Betti numbers:  [10140, 14074, 0]
# elapsed_time:5.595033645629883 sec
# c:\Users\Aneesh PB\AppData\Local\Programs\Python\Python312\Lib\site-packages\persim\visuals.py:87: RuntimeWarning: overflow encountered in cast
#   diagrams = [dgm.astype(np.float32, copy=True) for dgm in diagrams]
# C:\Users\Aneesh PB\AppData\Local\Temp\ipykernel_47800\2072340124.py:9: UserWarning: threshold_otsu is expected to work correctly only for grayscale images; image shape (512, 512, 3) looks like that of an RGB image.
#   bw_img = (img >= threshold_otsu(img))
# (512, 512, 3) uint8 37--255
# Betti numbers:  [14788, 9938, 0]
# Betti numbers:  [10415, 14289, 0]
# elapsed_time:5.361217260360718 sec
# c:\Users\Aneesh PB\AppData\Local\Programs\Python\Python312\Lib\site-packages\persim\visuals.py:87: RuntimeWarning: overflow encountered in cast
#   diagrams = [dgm.astype(np.float32, copy=True) for dgm in diagrams]
# C:\Users\Aneesh PB\AppData\Local\Temp\ipykernel_47800\2072340124.py:9: UserWarning: threshold_otsu is expected to work correctly only for grayscale images; image shape (512, 512, 3) looks like that of an RGB image.
#   bw_img = (img >= threshold_otsu(img))
# (512, 512, 3) uint8 37--255
# Betti numbers:  [14717, 10141, 0]
# Betti numbers:  [10504, 14460, 0]
# elapsed_time:6.062893867492676 sec
# c:\Users\Aneesh PB\AppData\Local\Programs\Python\Python312\Lib\site-packages\persim\visuals.py:87: RuntimeWarning: overflow encountered in cast
#   diagrams = [dgm.astype(np.float32, copy=True) for dgm in diagrams]
# C:\Users\Aneesh PB\AppData\Local\Temp\ipykernel_47800\2072340124.py:9: UserWarning: threshold_otsu is expected to work correctly only for grayscale images; image shape (512, 512, 3) looks like that of an RGB image.
#   bw_img = (img >= threshold_otsu(img))
# (512, 512, 3) uint8 37--255
# Betti numbers:  [14722, 10092, 0]
# Betti numbers:  [10400, 14489, 0]
# elapsed_time:5.595034837722778 sec
# c:\Users\Aneesh PB\AppData\Local\Programs\Python\Python312\Lib\site-packages\persim\visuals.py:87: RuntimeWarning: overflow encountered in cast
#   diagrams = [dgm.astype(np.float32, copy=True) for dgm in diagrams]
# C:\Users\Aneesh PB\AppData\Local\Temp\ipykernel_47800\2072340124.py:9: UserWarning: threshold_otsu is expected to work correctly only for grayscale images; image shape (512, 512, 3) looks like that of an RGB image.
#   bw_img = (img >= threshold_otsu(img))
# (512, 512, 3) uint8 37--255
# Betti numbers:  [14862, 10202, 0]
# Betti numbers:  [10588, 14529, 0]
# elapsed_time:5.578913450241089 sec
# c:\Users\Aneesh PB\AppData\Local\Programs\Python\Python312\Lib\site-packages\persim\visuals.py:87: RuntimeWarning: overflow encountered in cast
#   diagrams = [dgm.astype(np.float32, copy=True) for dgm in diagrams]
# C:\Users\Aneesh PB\AppData\Local\Temp\ipykernel_47800\2072340124.py:9: UserWarning: threshold_otsu is expected to work correctly only for grayscale images; image shape (512, 512, 3) looks like that of an RGB image.
#   bw_img = (img >= threshold_otsu(img))
# (512, 512, 3) uint8 37--255
# Betti numbers:  [14902, 10295, 0]
# Betti numbers:  [10648, 14643, 0]
# elapsed_time:5.628297805786133 sec
# c:\Users\Aneesh PB\AppData\Local\Programs\Python\Python312\Lib\site-packages\persim\visuals.py:87: RuntimeWarning: overflow encountered in cast
#   diagrams = [dgm.astype(np.float32, copy=True) for dgm in diagrams]
# C:\Users\Aneesh PB\AppData\Local\Temp\ipykernel_47800\2072340124.py:9: UserWarning: threshold_otsu is expected to work correctly only for grayscale images; image shape (512, 512, 3) looks like that of an RGB image.
#   bw_img = (img >= threshold_otsu(img))
# (512, 512, 3) uint8 37--255
# Betti numbers:  [15299, 9889, 0]
# Betti numbers:  [10446, 14734, 0]
# elapsed_time:5.554041624069214 sec
# c:\Users\Aneesh PB\AppData\Local\Programs\Python\Python312\Lib\site-packages\persim\visuals.py:87: RuntimeWarning: overflow encountered in cast
#   diagrams = [dgm.astype(np.float32, copy=True) for dgm in diagrams]
# C:\Users\Aneesh PB\AppData\Local\Temp\ipykernel_47800\2072340124.py:9: UserWarning: threshold_otsu is expected to work correctly only for grayscale images; image shape (512, 512, 3) looks like that of an RGB image.
#   bw_img = (img >= threshold_otsu(img))
# (512, 512, 3) uint8 37--255
# Betti numbers:  [14577, 9828, 0]
# Betti numbers:  [10375, 14140, 0]
# elapsed_time:5.594152212142944 sec
# c:\Users\Aneesh PB\AppData\Local\Programs\Python\Python312\Lib\site-packages\persim\visuals.py:87: RuntimeWarning: overflow encountered in cast
#   diagrams = [dgm.astype(np.float32, copy=True) for dgm in diagrams]
# C:\Users\Aneesh PB\AppData\Local\Temp\ipykernel_47800\2072340124.py:9: UserWarning: threshold_otsu is expected to work correctly only for grayscale images; image shape (512, 512, 3) looks like that of an RGB image.
#   bw_img = (img >= threshold_otsu(img))
# (512, 512, 3) uint8 37--255
# Betti numbers:  [14372, 9743, 0]
# Betti numbers:  [10141, 13857, 0]
# elapsed_time:5.484771251678467 sec
# c:\Users\Aneesh PB\AppData\Local\Programs\Python\Python312\Lib\site-packages\persim\visuals.py:87: RuntimeWarning: overflow encountered in cast
#   diagrams = [dgm.astype(np.float32, copy=True) for dgm in diagrams]
# C:\Users\Aneesh PB\AppData\Local\Temp\ipykernel_47800\2072340124.py:9: UserWarning: threshold_otsu is expected to work correctly only for grayscale images; image shape (512, 512, 3) looks like that of an RGB image.
#   bw_img = (img >= threshold_otsu(img))
# (512, 512, 3) uint8 37--255
# Betti numbers:  [14185, 9708, 0]
# Betti numbers:  [10020, 13941, 0]
# elapsed_time:5.548380613327026 sec
# c:\Users\Aneesh PB\AppData\Local\Programs\Python\Python312\Lib\site-packages\persim\visuals.py:87: RuntimeWarning: overflow encountered in cast
#   diagrams = [dgm.astype(np.float32, copy=True) for dgm in diagrams]
# C:\Users\Aneesh PB\AppData\Local\Temp\ipykernel_47800\2072340124.py:9: UserWarning: threshold_otsu is expected to work correctly only for grayscale images; image shape (512, 512, 3) looks like that of an RGB image.
#   bw_img = (img >= threshold_otsu(img))
# (512, 512, 3) uint8 37--255
# Betti numbers:  [14287, 9712, 0]
# Betti numbers:  [10145, 13956, 0]
# elapsed_time:5.578521013259888 sec
# c:\Users\Aneesh PB\AppData\Local\Programs\Python\Python312\Lib\site-packages\persim\visuals.py:87: RuntimeWarning: overflow encountered in cast
#   diagrams = [dgm.astype(np.float32, copy=True) for dgm in diagrams]
# C:\Users\Aneesh PB\AppData\Local\Temp\ipykernel_47800\2072340124.py:9: UserWarning: threshold_otsu is expected to work correctly only for grayscale images; image shape (512, 512, 3) looks like that of an RGB image.
#   bw_img = (img >= threshold_otsu(img))
# (512, 512, 3) uint8 37--255
# Betti numbers:  [14393, 9867, 0]
# Betti numbers:  [10177, 14030, 0]
# elapsed_time:5.468634843826294 sec
# c:\Users\Aneesh PB\AppData\Local\Programs\Python\Python312\Lib\site-packages\persim\visuals.py:87: RuntimeWarning: overflow encountered in cast
#   diagrams = [dgm.astype(np.float32, copy=True) for dgm in diagrams]
# C:\Users\Aneesh PB\AppData\Local\Temp\ipykernel_47800\2072340124.py:9: UserWarning: threshold_otsu is expected to work correctly only for grayscale images; image shape (512, 512, 3) looks like that of an RGB image.
#   bw_img = (img >= threshold_otsu(img))
# (512, 512, 3) uint8 37--255
# Betti numbers:  [14395, 9690, 0]
# Betti numbers:  [10169, 13898, 0]
# elapsed_time:5.485743045806885 sec
# c:\Users\Aneesh PB\AppData\Local\Programs\Python\Python312\Lib\site-packages\persim\visuals.py:87: RuntimeWarning: overflow encountered in cast
#   diagrams = [dgm.astype(np.float32, copy=True) for dgm in diagrams]
# C:\Users\Aneesh PB\AppData\Local\Temp\ipykernel_47800\2072340124.py:9: UserWarning: threshold_otsu is expected to work correctly only for grayscale images; image shape (512, 512, 3) looks like that of an RGB image.
#   bw_img = (img >= threshold_otsu(img))
# (512, 512, 3) uint8 37--255
# Betti numbers:  [14351, 9758, 0]
# Betti numbers:  [10062, 14032, 0]
# elapsed_time:5.849056005477905 sec
# c:\Users\Aneesh PB\AppData\Local\Programs\Python\Python312\Lib\site-packages\persim\visuals.py:87: RuntimeWarning: overflow encountered in cast
#   diagrams = [dgm.astype(np.float32, copy=True) for dgm in diagrams]
# C:\Users\Aneesh PB\AppData\Local\Temp\ipykernel_47800\2072340124.py:9: UserWarning: threshold_otsu is expected to work correctly only for grayscale images; image shape (512, 512, 3) looks like that of an RGB image.
#   bw_img = (img >= threshold_otsu(img))
# (512, 512, 3) uint8 37--255
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[3], line 53
#      51 start = time.time()
#      52 pd = cr.computePH(img2d)
# ---> 53 pds = [pd[pd[:,0] == i] for i in range(3)]
#      54 print("Betti numbers: ",[len(pds[i]) for i in range(len(pds))])
#      56 # compute PH for the T-construction of the original image (pixel value filtration)
#
# KeyboardInterrupt:
