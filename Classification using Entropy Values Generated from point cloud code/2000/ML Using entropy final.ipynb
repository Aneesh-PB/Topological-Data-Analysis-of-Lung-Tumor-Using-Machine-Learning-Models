# %%
import os
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split, RandomizedSearchCV
from sklearn.metrics import classification_report, confusion_matrix
from sklearn.preprocessing import StandardScaler
import xgboost as xgb
from scipy.stats import uniform, randint

# Data Preprocessing (same as before)
data_dir = "C:\\Users\\Aneesh PB\\Downloads\\Topology Project\\Full segment\\Entropy code\\2000\\Entropy\\"
classes = ['Normal cases', 'Bengin cases', 'Malignant cases']
X = []
y = []

max_length = 0

# First pass to find max_length
for class_name in classes:
    class_dir = os.path.join(data_dir, class_name)
    for file_name in os.listdir(class_dir):
        if file_name.endswith('.xlsx'):
            file_path = os.path.join(class_dir, file_name)
            df = pd.read_excel(file_path)
            flattened = df.to_numpy().flatten()
            max_length = max(max_length, len(flattened))

# Second pass: flatten arrays and pad them to max_length
for class_idx, class_name in enumerate(classes):
    class_dir = os.path.join(data_dir, class_name)
    for file_name in os.listdir(class_dir):
        if file_name.endswith('.xlsx'):
            file_path = os.path.join(class_dir, file_name)
            df = pd.read_excel(file_path)
            flattened = df.to_numpy().flatten()
            padded_features = np.pad(flattened, (0, max_length - len(flattened)), mode='constant')
            X.append(padded_features)
            y.append(class_idx)

X = np.array(X)
y = np.array(y)

# Split data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=2)

# Feature Scaling
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# %%
import optuna
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score
from sklearn.preprocessing import StandardScaler

# Split the data into train and test sets
# X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=2)

# # Standardize the features (important for KNN)
# scaler = StandardScaler()
# X_train_scaled = scaler.fit_transform(X_train)
# X_test_scaled = scaler.transform(X_test)

# Define the Optuna objective function
def objective(trial):
    # Hyperparameters to tune
    n_neighbors = trial.suggest_int('n_neighbors', 3, 15)  # Number of neighbors
    metric = trial.suggest_categorical('metric', ['euclidean', 'manhattan', 'minkowski'])  # Distance metric
    weights = trial.suggest_categorical('weights', ['uniform', 'distance'])  # Weight function
    p = trial.suggest_int('p', 1, 2)  # Power parameter for Minkowski distance (1 for Manhattan, 2 for Euclidean)

    # Create the KNN model with the hyperparameters
    model = KNeighborsClassifier(n_neighbors=n_neighbors, metric=metric, weights=weights, p=p)

    # Train the model
    model.fit(X_train, y_train)

    # Predict on the test set
    y_pred = model.predict(X_test)

    # Evaluate the accuracy
    accuracy = accuracy_score(y_test, y_pred)
    return accuracy  # Return the accuracy as the objective to maximize

# Create an Optuna study and optimize the hyperparameters
study = optuna.create_study(direction='maximize')  # Maximize accuracy
study.optimize(objective, n_trials=5000)  # Number of trials can be adjusted based on time and computation

# Print the best hyperparameters and corresponding accuracy
print(f"Best Hyperparameters: {study.best_params}")
print(f"Best Accuracy: {study.best_value:.4f}")

# Optionally, you can train the model with the best parameters
best_params = study.best_params
best_knn = KNeighborsClassifier(n_neighbors=best_params['n_neighbors'],
                                metric=best_params['metric'],
                                weights=best_params['weights'],
                                p=best_params['p'])

best_knn.fit(X_train, y_train)
y_pred_best_knn = best_knn.predict(X_test)

# Final Evaluation
accuracy_best_knn = accuracy_score(y_test, y_pred_best_knn)
print(f"Accuracy with Optimized KNN: {accuracy_best_knn * 100:.2f}%")
# Out:
# [I 2024-11-20 17:37:18,528] A new study created in memory with name: no-name-44012342-be0a-4667-895b-c18d08e8c7ec
 'metric': 'manhattan', 'weights': 'distance', 'p': 1}
# Best Accuracy: 0.9767
# Accuracy with Optimized KNN: 97.67%

# %%
import optuna
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import cross_val_score

def optimize_random_forest(trial):
    # Define the hyperparameters to tune
    n_estimators = trial.suggest_int("n_estimators", 50, 500)  # Increased range for more flexibility
    max_depth = trial.suggest_int("max_depth", 3, 30)
    min_samples_split = trial.suggest_int("min_samples_split", 2, 20)
    random_state= trial.suggest_int("random_state", 0, 50)
    min_samples_leaf = trial.suggest_int("min_samples_leaf", 1, 20)
    max_features = trial.suggest_float("max_features", 0.1, 1.0)  # Allows fractional values for features
    
    # Additional parameters
    bootstrap = trial.suggest_categorical("bootstrap", [True, False])
    criterion = trial.suggest_categorical("criterion", ["gini", "entropy", "log_loss"])  # Adds different splitting criteria
    if bootstrap:  # max_samples is only relevant if bootstrap is True
        max_samples = trial.suggest_float("max_samples", 0.5, 1.0)

    # Initialize the model with suggested hyperparameters
    rf_model = RandomForestClassifier(
        n_estimators=n_estimators,
        max_depth=max_depth,
        min_samples_split=min_samples_split,
        min_samples_leaf=min_samples_leaf,
        max_features=max_features,
        bootstrap=bootstrap,
        criterion=criterion,
        max_samples=max_samples if bootstrap else None,  # Only applies if bootstrap is True
        random_state=random_state,
        n_jobs=-1
    )

    # Perform cross-validation
    scores = cross_val_score(rf_model, X_train, y_train, cv=3, scoring="accuracy")
    return scores.mean()

# Create a study and optimize the objective function
study = optuna.create_study(direction="maximize")

study.optimize(optimize_random_forest, n_trials=5000)

# Retrieve the best parameters
best_rf_params = study.best_params
print("Best parameters for Random Forest:", best_rf_params)

# Train the best RandomForest model with these parameters
best_rf_model = RandomForestClassifier(**best_rf_params, n_jobs=-1)
best_rf_model.fit(X_train, y_train)
# Out:
# [I 2024-11-19 21:53:23,262] A new study created in memory with name: no-name-9d8a4ed3-e41c-4d96-a86c-df9764aec853
# [I 2024-11-19 21:53:39,558] Trial 0 finished with value: 0.8904428904428904 and parameters: {'n_estimators': 340, 'max_depth': 30, 'min_samples_split': 8, 'random_state': 44, 'min_samples_leaf': 3, 'max_features': 0.8872928447202564, 'bootstrap': True, 'criterion': 'log_loss', 'max_samples': 0.671346274905495}. Best is trial 0 with value: 0.8904428904428904.
# [I 2024-11-19 21:53:46,964] Trial 1 finished with value: 0.9102564102564102 and parameters: {'n_estimators': 168, 'max_depth': 11, 'min_samples_split': 7, 'random_state': 43, 'min_samples_leaf': 5, 'max_features': 0.40177025182099135, 'bootstrap': False, 'criterion': 'log_loss'}. Best is trial 1 with value: 0.9102564102564102.
# [I 2024-11-19 21:53:57,049] Trial 2 finished with value: 0.8682983682983684 and parameters: {'n_estimators': 446, 'max_depth': 16, 'min_samples_split': 2, 'random_state': 29, 'min_samples_leaf': 12, 'max_features': 0.4369015716249578, 'bootstrap': True, 'criterion': 'log_loss', 'max_samples': 0.7753009571391922}. Best is trial 1 with value: 0.9102564102564102.
# [I 2024-11-19 21:54:04,876] Trial 3 finished with value: 0.8414918414918415 and parameters: {'n_estimators': 139, 'max_depth': 3, 'min_samples_split': 2, 'random_state': 0, 'min_samples_leaf': 1, 'max_features': 0.7759009119753193, 'bootstrap': False, 'criterion': 'log_loss'}. Best is trial 1 with value: 0.9102564102564102.
# [I 2024-11-19 21:54:27,182] Trial 4 finished with value: 0.8368298368298369 and parameters: {'n_estimators': 328, 'max_depth': 24, 'min_samples_split': 12, 'random_state': 11, 'min_samples_leaf': 17, 'max_features': 0.9173535152860446, 'bootstrap': False, 'criterion': 'gini'}. Best is trial 1 with value: 0.9102564102564102.
# [I 2024-11-19 21:54:42,308] Trial 5 finished with value: 0.8764568764568764 and parameters: {'n_estimators': 363, 'max_depth': 27, 'min_samples_split': 10, 'random_state': 26, 'min_samples_leaf': 19, 'max_features': 0.46852981170478303, 'bootstrap': False, 'criterion': 'log_loss'}. Best is trial 1 with value: 0.9102564102564102.
# [I 2024-11-19 21:54:45,367] Trial 6 finished with value: 0.8519813519813519 and parameters: {'n_estimators': 174, 'max_depth': 23, 'min_samples_split': 18, 'random_state': 10, 'min_samples_leaf': 14, 'max_features': 0.4259129536210562, 'bootstrap': True, 'criterion': 'log_loss', 'max_samples': 0.5879379311952366}. Best is trial 1 with value: 0.9102564102564102.
# [I 2024-11-19 21:54:53,401] Trial 7 finished with value: 0.8706293706293705 and parameters: {'n_estimators': 327, 'max_depth': 23, 'min_samples_split': 18, 'random_state': 25, 'min_samples_leaf': 2, 'max_features': 0.3587983186256356, 'bootstrap': True, 'criterion': 'gini', 'max_samples': 0.6057822446631282}. Best is trial 1 with value: 0.9102564102564102.
# [I 2024-11-19 21:54:54,224] Trial 8 finished with value: 0.8986013986013986 and parameters: {'n_estimators': 55, 'max_depth': 15, 'min_samples_split': 3, 'random_state': 33, 'min_samples_leaf': 1, 'max_features': 0.14075571751685076, 'bootstrap': True, 'criterion': 'log_loss', 'max_samples': 0.5931726388999947}. Best is trial 1 with value: 0.9102564102564102.
# [I 2024-11-19 21:55:03,298] Trial 9 finished with value: 0.9044289044289044 and parameters: {'n_estimators': 118, 'max_depth': 23, 'min_samples_split': 11, 'random_state': 22, 'min_samples_leaf': 4, 'max_features': 0.5913013075133103, 'bootstrap': False, 'criterion': 'log_loss'}. Best is trial 1 with value: 0.9102564102564102.
# [I 2024-11-19 21:55:09,453] Trial 10 finished with value: 0.9067599067599067 and parameters: {'n_estimators': 224, 'max_depth': 8, 'min_samples_split': 6, 'random_state': 48, 'min_samples_leaf': 7, 'max_features': 0.20944563088396892, 'bootstrap': False, 'criterion': 'entropy'}. Best is trial 1 with value: 0.9102564102564102.
# [I 2024-11-19 21:55:13,658] Trial 11 finished with value: 0.9160839160839161 and parameters: {'n_estimators': 215, 'max_depth': 8, 'min_samples_split': 6, 'random_state': 49, 'min_samples_leaf': 7, 'max_features': 0.1430761674156813, 'bootstrap': False, 'criterion': 'entropy'}. Best is trial 11 with value: 0.9160839160839161.
# [I 2024-11-19 21:55:20,477] Trial 12 finished with value: 0.9055944055944055 and parameters: {'n_estimators': 234, 'max_depth': 11, 'min_samples_split': 7, 'random_state': 41, 'min_samples_leaf': 8, 'max_features': 0.2292166998222337, 'bootstrap': False, 'criterion': 'entropy'}. Best is trial 11 with value: 0.9160839160839161.
# [I 2024-11-19 21:55:38,952] Trial 13 finished with value: 0.8869463869463869 and parameters: {'n_estimators': 235, 'max_depth': 8, 'min_samples_split': 5, 'random_state': 38, 'min_samples_leaf': 7, 'max_features': 0.6850564112063735, 'bootstrap': False, 'criterion': 'entropy'}. Best is trial 11 with value: 0.9160839160839161.
# [I 2024-11-19 21:55:41,068] Trial 14 finished with value: 0.8706293706293705 and parameters: {'n_estimators': 67, 'max_depth': 4, 'min_samples_split': 15, 'random_state': 49, 'min_samples_leaf': 10, 'max_features': 0.2921546614509942, 'bootstrap': False, 'criterion': 'entropy'}. Best is trial 11 with value: 0.9160839160839161.
# [I 2024-11-19 21:55:44,612] Trial 15 finished with value: 0.9184149184149183 and parameters: {'n_estimators': 178, 'max_depth': 12, 'min_samples_split': 9, 'random_state': 36, 'min_samples_leaf': 5, 'max_features': 0.14297058465756296, 'bootstrap': False, 'criterion': 'entropy'}. Best is trial 15 with value: 0.9184149184149183.
# [I 2024-11-19 21:55:48,775] Trial 16 finished with value: 0.9055944055944055 and parameters: {'n_estimators': 271, 'max_depth': 19, 'min_samples_split': 14, 'random_state': 33, 'min_samples_leaf': 10, 'max_features': 0.11885495852641392, 'bootstrap': False, 'criterion': 'entropy'}. Best is trial 15 with value: 0.9184149184149183.
# [I 2024-11-19 21:56:10,353] Trial 17 finished with value: 0.9137529137529138 and parameters: {'n_estimators': 494, 'max_depth': 12, 'min_samples_split': 9, 'random_state': 37, 'min_samples_leaf': 5, 'max_features': 0.29269554643664836, 'bootstrap': False, 'criterion': 'entropy'}. Best is trial 15 with value: 0.9184149184149183.
# [I 2024-11-19 21:56:29,646] Trial 18 finished with value: 0.8834498834498835 and parameters: {'n_estimators': 180, 'max_depth': 7, 'min_samples_split': 4, 'random_state': 50, 'min_samples_leaf': 13, 'max_features': 0.5814194794330441, 'bootstrap': False, 'criterion': 'entropy'}. Best is trial 15 with value: 0.9184149184149183.
# [I 2024-11-19 21:56:42,712] Trial 19 finished with value: 0.9079254079254079 and parameters: {'n_estimators': 287, 'max_depth': 14, 'min_samples_split': 13, 'random_state': 18, 'min_samples_leaf': 8, 'max_features': 0.20190948277163207, 'bootstrap': False, 'criterion': 'entropy'}. Best is trial 15 with value: 0.9184149184149183.
# [I 2024-11-19 21:56:48,482] Trial 20 finished with value: 0.8822843822843822 and parameters: {'n_estimators': 102, 'max_depth': 19, 'min_samples_split': 16, 'random_state': 35, 'min_samples_leaf': 15, 'max_features': 0.3049087336696677, 'bootstrap': False, 'criterion': 'gini'}. Best is trial 15 with value: 0.9184149184149183.
# [I 2024-11-19 21:57:02,547] Trial 21 finished with value: 0.9207459207459207 and parameters: {'n_estimators': 455, 'max_depth': 12, 'min_samples_split': 9, 'random_state': 39, 'min_samples_leaf': 5, 'max_features': 0.12171639728164554, 'bootstrap': False, 'criterion': 'entropy'}. Best is trial 21 with value: 0.9207459207459207.
# [I 2024-11-19 21:57:13,300] Trial 22 finished with value: 0.900932400932401 and parameters: {'n_estimators': 400, 'max_depth': 6, 'min_samples_split': 9, 'random_state': 44, 'min_samples_leaf': 6, 'max_features': 0.1124041613154908, 'bootstrap': False, 'criterion': 'entropy'}. Best is trial 21 with value: 0.9207459207459207.
# [I 2024-11-19 21:57:21,233] Trial 23 finished with value: 0.9079254079254079 and parameters: {'n_estimators': 208, 'max_depth': 10, 'min_samples_split': 11, 'random_state': 38, 'min_samples_leaf': 9, 'max_features': 0.18549510953042717, 'bootstrap': False, 'criterion': 'entropy'}. Best is trial 21 with value: 0.9207459207459207.
# [I 2024-11-19 21:57:36,415] Trial 24 finished with value: 0.9125874125874125 and parameters: {'n_estimators': 280, 'max_depth': 18, 'min_samples_split': 5, 'random_state': 46, 'min_samples_leaf': 5, 'max_features': 0.26846524417486284, 'bootstrap': False, 'criterion': 'entropy'}. Best is trial 21 with value: 0.9207459207459207.
# [I 2024-11-19 21:57:47,437] Trial 25 finished with value: 0.9254079254079254 and parameters: {'n_estimators': 441, 'max_depth': 13, 'min_samples_split': 8, 'random_state': 30, 'min_samples_leaf': 4, 'max_features': 0.10462959915764206, 'bootstrap': False, 'criterion': 'entropy'}. Best is trial 25 with value: 0.9254079254079254.
# [I 2024-11-19 21:58:11,323] Trial 26 finished with value: 0.9020979020979021 and parameters: {'n_estimators': 497, 'max_depth': 13, 'min_samples_split': 9, 'random_state': 30, 'min_samples_leaf': 3, 'max_features': 0.352732023784231, 'bootstrap': True, 'criterion': 'entropy', 'max_samples': 0.9585099797516758}. Best is trial 25 with value: 0.9254079254079254.
# [I 2024-11-19 21:58:47,233] Trial 27 finished with value: 0.9020979020979021 and parameters: {'n_estimators': 427, 'max_depth': 17, 'min_samples_split': 20, 'random_state': 21, 'min_samples_leaf': 3, 'max_features': 0.5091079540427423, 'bootstrap': False, 'criterion': 'gini'}. Best is trial 25 with value: 0.9254079254079254.
# [I 2024-11-19 21:59:02,389] Trial 28 finished with value: 0.9242424242424242 and parameters: {'n_estimators': 438, 'max_depth': 10, 'min_samples_split': 12, 'random_state': 29, 'min_samples_leaf': 4, 'max_features': 0.1689117878593866, 'bootstrap': False, 'criterion': 'entropy'}. Best is trial 25 with value: 0.9254079254079254.
# [I 2024-11-19 21:59:42,641] Trial 29 finished with value: 0.8834498834498835 and parameters: {'n_estimators': 461, 'max_depth': 5, 'min_samples_split': 13, 'random_state': 30, 'min_samples_leaf': 3, 'max_features': 0.8472547602518692, 'bootstrap': True, 'criterion': 'entropy', 'max_samples': 0.9865768848685282}. Best is trial 25 with value: 0.9254079254079254.
# [I 2024-11-19 21:59:59,010] Trial 30 finished with value: 0.9160839160839161 and parameters: {'n_estimators': 387, 'max_depth': 10, 'min_samples_split': 8, 'random_state': 15, 'min_samples_leaf': 4, 'max_features': 0.24093074670574316, 'bootstrap': False, 'criterion': 'entropy'}. Best is trial 25 with value: 0.9254079254079254.
# [I 2024-11-19 22:00:07,817] Trial 31 finished with value: 0.9184149184149185 and parameters: {'n_estimators': 417, 'max_depth': 15, 'min_samples_split': 10, 'random_state': 40, 'min_samples_leaf': 6, 'max_features': 0.10090355451803723, 'bootstrap': False, 'criterion': 'entropy'}. Best is trial 25 with value: 0.9254079254079254.
# [I 2024-11-19 22:00:20,006] Trial 32 finished with value: 0.9172494172494172 and parameters: {'n_estimators': 415, 'max_depth': 14, 'min_samples_split': 12, 'random_state': 41, 'min_samples_leaf': 6, 'max_features': 0.16923551164105322, 'bootstrap': False, 'criterion': 'entropy'}. Best is trial 25 with value: 0.9254079254079254.
# [I 2024-11-19 22:00:30,943] Trial 33 finished with value: 0.9207459207459207 and parameters: {'n_estimators': 461, 'max_depth': 15, 'min_samples_split': 10, 'random_state': 27, 'min_samples_leaf': 2, 'max_features': 0.11373408344574693, 'bootstrap': False, 'criterion': 'entropy'}. Best is trial 25 with value: 0.9254079254079254.
# [I 2024-11-19 22:00:47,160] Trial 34 finished with value: 0.923076923076923 and parameters: {'n_estimators': 462, 'max_depth': 10, 'min_samples_split': 7, 'random_state': 28, 'min_samples_leaf': 1, 'max_features': 0.18491449486641642, 'bootstrap': False, 'criterion': 'entropy'}. Best is trial 25 with value: 0.9254079254079254.
# [I 2024-11-19 22:02:08,894] Trial 35 finished with value: 0.8706293706293707 and parameters: {'n_estimators': 448, 'max_depth': 10, 'min_samples_split': 7, 'random_state': 33, 'min_samples_leaf': 1, 'max_features': 0.9818947411542434, 'bootstrap': False, 'criterion': 'gini'}. Best is trial 25 with value: 0.9254079254079254.
# [I 2024-11-19 22:02:34,143] Trial 36 finished with value: 0.9114219114219114 and parameters: {'n_estimators': 360, 'max_depth': 9, 'min_samples_split': 8, 'random_state': 22, 'min_samples_leaf': 2, 'max_features': 0.3786511628505641, 'bootstrap': False, 'criterion': 'entropy'}. Best is trial 25 with value: 0.9254079254079254.
# [I 2024-11-19 22:02:50,390] Trial 37 finished with value: 0.900932400932401 and parameters: {'n_estimators': 486, 'max_depth': 12, 'min_samples_split': 8, 'random_state': 28, 'min_samples_leaf': 4, 'max_features': 0.2503811553428625, 'bootstrap': True, 'criterion': 'entropy', 'max_samples': 0.8263109517180833}. Best is trial 25 with value: 0.9254079254079254.
# [I 2024-11-19 22:03:16,387] Trial 38 finished with value: 0.8997668997668997 and parameters: {'n_estimators': 371, 'max_depth': 6, 'min_samples_split': 11, 'random_state': 24, 'min_samples_leaf': 1, 'max_features': 0.33361301119389797, 'bootstrap': False, 'criterion': 'log_loss'}. Best is trial 25 with value: 0.9254079254079254.
# [I 2024-11-19 22:03:27,247] Trial 39 finished with value: 0.8671328671328671 and parameters: {'n_estimators': 471, 'max_depth': 17, 'min_samples_split': 6, 'random_state': 4, 'min_samples_leaf': 12, 'max_features': 0.20427044617532203, 'bootstrap': True, 'criterion': 'gini', 'max_samples': 0.8382584256976429}. Best is trial 25 with value: 0.9254079254079254.
# [I 2024-11-19 22:03:59,839] Trial 40 finished with value: 0.8741258741258742 and parameters: {'n_estimators': 435, 'max_depth': 21, 'min_samples_split': 12, 'random_state': 32, 'min_samples_leaf': 20, 'max_features': 0.4665123656599821, 'bootstrap': False, 'criterion': 'entropy'}. Best is trial 25 with value: 0.9254079254079254.
# [I 2024-11-19 22:04:18,844] Trial 41 finished with value: 0.921911421911422 and parameters: {'n_estimators': 462, 'max_depth': 15, 'min_samples_split': 10, 'random_state': 28, 'min_samples_leaf': 2, 'max_features': 0.1657114245607112, 'bootstrap': False, 'criterion': 'entropy'}. Best is trial 25 with value: 0.9254079254079254.
# [I 2024-11-19 22:04:37,378] Trial 42 finished with value: 0.923076923076923 and parameters: {'n_estimators': 448, 'max_depth': 13, 'min_samples_split': 10, 'random_state': 25, 'min_samples_leaf': 2, 'max_features': 0.1727377912975728, 'bootstrap': False, 'criterion': 'entropy'}. Best is trial 25 with value: 0.9254079254079254.
# [I 2024-11-19 22:04:54,965] Trial 43 finished with value: 0.9254079254079254 and parameters: {'n_estimators': 396, 'max_depth': 14, 'min_samples_split': 11, 'random_state': 25, 'min_samples_leaf': 2, 'max_features': 0.17082302318577866, 'bootstrap': False, 'criterion': 'entropy'}. Best is trial 25 with value: 0.9254079254079254.
# [I 2024-11-19 22:05:10,787] Trial 44 finished with value: 0.9195804195804196 and parameters: {'n_estimators': 348, 'max_depth': 28, 'min_samples_split': 12, 'random_state': 17, 'min_samples_leaf': 3, 'max_features': 0.18112237152999994, 'bootstrap': False, 'criterion': 'log_loss'}. Best is trial 25 with value: 0.9254079254079254.
# [I 2024-11-19 22:05:33,235] Trial 45 finished with value: 0.9160839160839161 and parameters: {'n_estimators': 392, 'max_depth': 13, 'min_samples_split': 14, 'random_state': 24, 'min_samples_leaf': 1, 'max_features': 0.2406785244153532, 'bootstrap': False, 'criterion': 'entropy'}. Best is trial 25 with value: 0.9254079254079254.
# [I 2024-11-19 22:06:33,611] Trial 46 finished with value: 0.9102564102564102 and parameters: {'n_estimators': 437, 'max_depth': 9, 'min_samples_split': 7, 'random_state': 20, 'min_samples_leaf': 4, 'max_features': 0.645843426286834, 'bootstrap': False, 'criterion': 'entropy'}. Best is trial 25 with value: 0.9254079254079254.
# [I 2024-11-19 22:07:10,263] Trial 47 finished with value: 0.9114219114219114 and parameters: {'n_estimators': 408, 'max_depth': 11, 'min_samples_split': 11, 'random_state': 25, 'min_samples_leaf': 2, 'max_features': 0.39750234392290495, 'bootstrap': False, 'criterion': 'log_loss'}. Best is trial 25 with value: 0.9254079254079254.
# [I 2024-11-19 22:07:21,792] Trial 48 finished with value: 0.8543123543123543 and parameters: {'n_estimators': 310, 'max_depth': 3, 'min_samples_split': 2, 'random_state': 13, 'min_samples_leaf': 1, 'max_features': 0.33059785139529174, 'bootstrap': True, 'criterion': 'entropy', 'max_samples': 0.7011819895861837}. Best is trial 25 with value: 0.9254079254079254.
# [I 2024-11-19 22:07:38,403] Trial 49 finished with value: 0.923076923076923 and parameters: {'n_estimators': 376, 'max_depth': 16, 'min_samples_split': 13, 'random_state': 31, 'min_samples_leaf': 3, 'max_features': 0.15634444661106728, 'bootstrap': False, 'criterion': 'entropy'}. Best is trial 25 with value: 0.9254079254079254.
# [I 2024-11-19 22:08:01,902] Trial 50 finished with value: 0.9149184149184149 and parameters: {'n_estimators': 477, 'max_depth': 13, 'min_samples_split': 16, 'random_state': 26, 'min_samples_leaf': 2, 'max_features': 0.20966161791114435, 'bootstrap': False, 'criterion': 'entropy'}. Best is trial 25 with value: 0.9254079254079254.
# [I 2024-11-19 22:08:17,668] Trial 51 finished with value: 0.9184149184149185 and parameters: {'n_estimators': 379, 'max_depth': 14, 'min_samples_split': 13, 'random_state': 31, 'min_samples_leaf': 4, 'max_features': 0.1589011301099459, 'bootstrap': False, 'criterion': 'entropy'}. Best is trial 25 with value: 0.9254079254079254.
# [I 2024-11-19 22:08:45,931] Trial 52 finished with value: 0.9137529137529138 and parameters: {'n_estimators': 438, 'max_depth': 17, 'min_samples_split': 14, 'random_state': 35, 'min_samples_leaf': 3, 'max_features': 0.26890728103451467, 'bootstrap': False, 'criterion': 'entropy'}. Best is trial 25 with value: 0.9254079254079254.
# [I 2024-11-19 22:08:57,210] Trial 53 finished with value: 0.8811188811188811 and parameters: {'n_estimators': 337, 'max_depth': 16, 'min_samples_split': 10, 'random_state': 23, 'min_samples_leaf': 17, 'max_features': 0.14992137816547144, 'bootstrap': False, 'criterion': 'entropy'}. Best is trial 25 with value: 0.9254079254079254.
# [I 2024-11-19 22:09:18,492] Trial 54 finished with value: 0.9149184149184149 and parameters: {'n_estimators': 426, 'max_depth': 11, 'min_samples_split': 15, 'random_state': 29, 'min_samples_leaf': 1, 'max_features': 0.21545032802984448, 'bootstrap': False, 'criterion': 'entropy'}. Best is trial 25 with value: 0.9254079254079254.
# [I 2024-11-19 22:10:29,790] Trial 55 finished with value: 0.8974358974358975 and parameters: {'n_estimators': 397, 'max_depth': 20, 'min_samples_split': 12, 'random_state': 26, 'min_samples_leaf': 3, 'max_features': 0.7648707012407422, 'bootstrap': False, 'criterion': 'entropy'}. Best is trial 25 with value: 0.9254079254079254.
# [I 2024-11-19 22:10:40,290] Trial 56 finished with value: 0.9114219114219114 and parameters: {'n_estimators': 309, 'max_depth': 16, 'min_samples_split': 11, 'random_state': 19, 'min_samples_leaf': 5, 'max_features': 0.1411850437157055, 'bootstrap': False, 'criterion': 'gini'}. Best is trial 25 with value: 0.9254079254079254.
# [I 2024-11-19 22:11:06,269] Trial 57 finished with value: 0.9149184149184149 and parameters: {'n_estimators': 358, 'max_depth': 9, 'min_samples_split': 5, 'random_state': 31, 'min_samples_leaf': 4, 'max_features': 0.30342112021305234, 'bootstrap': False, 'criterion': 'entropy'}. Best is trial 25 with value: 0.9254079254079254.
# [I 2024-11-19 22:11:20,945] Trial 58 finished with value: 0.9265734265734267 and parameters: {'n_estimators': 477, 'max_depth': 13, 'min_samples_split': 8, 'random_state': 34, 'min_samples_leaf': 2, 'max_features': 0.10236661691269511, 'bootstrap': False, 'criterion': 'entropy'}. Best is trial 58 with value: 0.9265734265734267.
# [I 2024-11-19 22:11:36,010] Trial 59 finished with value: 0.9265734265734267 and parameters: {'n_estimators': 479, 'max_depth': 13, 'min_samples_split': 8, 'random_state': 34, 'min_samples_leaf': 2, 'max_features': 0.10174565719534115, 'bootstrap': False, 'criterion': 'log_loss'}. Best is trial 58 with value: 0.9265734265734267.
# [I 2024-11-19 22:11:47,406] Trial 60 finished with value: 0.9079254079254078 and parameters: {'n_estimators': 481, 'max_depth': 7, 'min_samples_split': 6, 'random_state': 34, 'min_samples_leaf': 1, 'max_features': 0.11199406650783221, 'bootstrap': True, 'criterion': 'log_loss', 'max_samples': 0.903921523760935}. Best is trial 58 with value: 0.9265734265734267.
# [I 2024-11-19 22:12:11,329] Trial 61 finished with value: 0.9242424242424243 and parameters: {'n_estimators': 500, 'max_depth': 13, 'min_samples_split': 7, 'random_state': 28, 'min_samples_leaf': 2, 'max_features': 0.18930810703946138, 'bootstrap': False, 'criterion': 'log_loss'}. Best is trial 58 with value: 0.9265734265734267.
# [I 2024-11-19 22:12:26,130] Trial 62 finished with value: 0.9242424242424243 and parameters: {'n_estimators': 492, 'max_depth': 11, 'min_samples_split': 8, 'random_state': 36, 'min_samples_leaf': 2, 'max_features': 0.10151563003254233, 'bootstrap': False, 'criterion': 'log_loss'}. Best is trial 58 with value: 0.9265734265734267.
# [I 2024-11-19 22:12:41,571] Trial 63 finished with value: 0.93006993006993 and parameters: {'n_estimators': 486, 'max_depth': 14, 'min_samples_split': 8, 'random_state': 36, 'min_samples_leaf': 2, 'max_features': 0.10400417638993852, 'bootstrap': False, 'criterion': 'log_loss'}. Best is trial 63 with value: 0.93006993006993.
# [I 2024-11-19 22:12:52,769] Trial 64 finished with value: 0.9254079254079254 and parameters: {'n_estimators': 500, 'max_depth': 14, 'min_samples_split': 8, 'random_state': 37, 'min_samples_leaf': 2, 'max_features': 0.1019912416818364, 'bootstrap': False, 'criterion': 'log_loss'}. Best is trial 63 with value: 0.93006993006993.
# [I 2024-11-19 22:13:07,462] Trial 65 finished with value: 0.9242424242424243 and parameters: {'n_estimators': 498, 'max_depth': 14, 'min_samples_split': 8, 'random_state': 42, 'min_samples_leaf': 2, 'max_features': 0.13216351530714862, 'bootstrap': False, 'criterion': 'log_loss'}. Best is trial 63 with value: 0.93006993006993.
# [I 2024-11-19 22:13:20,593] Trial 66 finished with value: 0.9312354312354313 and parameters: {'n_estimators': 472, 'max_depth': 12, 'min_samples_split': 6, 'random_state': 38, 'min_samples_leaf': 3, 'max_features': 0.1305007824712714, 'bootstrap': False, 'criterion': 'log_loss'}. Best is trial 66 with value: 0.9312354312354313.
# [I 2024-11-19 22:13:33,679] Trial 67 finished with value: 0.9242424242424243 and parameters: {'n_estimators': 477, 'max_depth': 12, 'min_samples_split': 4, 'random_state': 38, 'min_samples_leaf': 6, 'max_features': 0.1331762816319696, 'bootstrap': False, 'criterion': 'log_loss'}. Best is trial 66 with value: 0.9312354312354313.
# [I 2024-11-19 22:13:45,623] Trial 68 finished with value: 0.9254079254079254 and parameters: {'n_estimators': 472, 'max_depth': 18, 'min_samples_split': 4, 'random_state': 43, 'min_samples_leaf': 3, 'max_features': 0.10174078175032247, 'bootstrap': False, 'criterion': 'log_loss'}. Best is trial 66 with value: 0.9312354312354313.
# [I 2024-11-19 22:14:05,075] Trial 69 finished with value: 0.914918414918415 and parameters: {'n_estimators': 451, 'max_depth': 15, 'min_samples_split': 9, 'random_state': 46, 'min_samples_leaf': 5, 'max_features': 0.22330341025410907, 'bootstrap': False, 'criterion': 'log_loss'}. Best is trial 66 with value: 0.9312354312354313.
# [I 2024-11-19 22:14:18,275] Trial 70 finished with value: 0.9195804195804196 and parameters: {'n_estimators': 424, 'max_depth': 14, 'min_samples_split': 6, 'random_state': 37, 'min_samples_leaf': 4, 'max_features': 0.14521819346264345, 'bootstrap': False, 'criterion': 'log_loss'}. Best is trial 66 with value: 0.9312354312354313.
# [I 2024-11-19 22:14:30,618] Trial 71 finished with value: 0.9254079254079254 and parameters: {'n_estimators': 475, 'max_depth': 18, 'min_samples_split': 4, 'random_state': 43, 'min_samples_leaf': 3, 'max_features': 0.10200721730370295, 'bootstrap': False, 'criterion': 'log_loss'}. Best is trial 66 with value: 0.9312354312354313.
# [I 2024-11-19 22:14:42,907] Trial 72 finished with value: 0.9242424242424243 and parameters: {'n_estimators': 468, 'max_depth': 15, 'min_samples_split': 5, 'random_state': 40, 'min_samples_leaf': 3, 'max_features': 0.13051381485264432, 'bootstrap': False, 'criterion': 'log_loss'}. Best is trial 66 with value: 0.9312354312354313.
# [I 2024-11-19 22:14:55,356] Trial 73 finished with value: 0.9242424242424242 and parameters: {'n_estimators': 485, 'max_depth': 18, 'min_samples_split': 3, 'random_state': 45, 'min_samples_leaf': 3, 'max_features': 0.12419858274170562, 'bootstrap': False, 'criterion': 'log_loss'}. Best is trial 66 with value: 0.9312354312354313.
# [I 2024-11-19 22:15:12,709] Trial 74 finished with value: 0.9254079254079254 and parameters: {'n_estimators': 450, 'max_depth': 12, 'min_samples_split': 7, 'random_state': 35, 'min_samples_leaf': 1, 'max_features': 0.19552213104700583, 'bootstrap': False, 'criterion': 'log_loss'}. Best is trial 66 with value: 0.9312354312354313.
# [I 2024-11-19 22:15:24,089] Trial 75 finished with value: 0.9265734265734266 and parameters: {'n_estimators': 487, 'max_depth': 19, 'min_samples_split': 9, 'random_state': 34, 'min_samples_leaf': 2, 'max_features': 0.10092278513413855, 'bootstrap': False, 'criterion': 'log_loss'}. Best is trial 66 with value: 0.9312354312354313.
# [I 2024-11-19 22:15:40,341] Trial 76 finished with value: 0.9265734265734267 and parameters: {'n_estimators': 490, 'max_depth': 22, 'min_samples_split': 9, 'random_state': 33, 'min_samples_leaf': 2, 'max_features': 0.15295254307601375, 'bootstrap': False, 'criterion': 'log_loss'}. Best is trial 66 with value: 0.9312354312354313.
# [I 2024-11-19 22:15:52,588] Trial 77 finished with value: 0.8869463869463869 and parameters: {'n_estimators': 487, 'max_depth': 22, 'min_samples_split': 9, 'random_state': 33, 'min_samples_leaf': 2, 'max_features': 0.27574555736730993, 'bootstrap': True, 'criterion': 'log_loss', 'max_samples': 0.5096861267011923}. Best is trial 66 with value: 0.9312354312354313.
# [I 2024-11-19 22:16:05,351] Trial 78 finished with value: 0.9114219114219114 and parameters: {'n_estimators': 412, 'max_depth': 25, 'min_samples_split': 9, 'random_state': 34, 'min_samples_leaf': 8, 'max_features': 0.1561710609863846, 'bootstrap': False, 'criterion': 'log_loss'}. Best is trial 66 with value: 0.9312354312354313.
# [I 2024-11-19 22:16:27,256] Trial 79 finished with value: 0.9184149184149183 and parameters: {'n_estimators': 463, 'max_depth': 25, 'min_samples_split': 8, 'random_state': 39, 'min_samples_leaf': 4, 'max_features': 0.2489498003200144, 'bootstrap': False, 'criterion': 'log_loss'}. Best is trial 66 with value: 0.9312354312354313.
# [I 2024-11-19 22:16:37,789] Trial 80 finished with value: 0.9020979020979021 and parameters: {'n_estimators': 438, 'max_depth': 20, 'min_samples_split': 10, 'random_state': 33, 'min_samples_leaf': 11, 'max_features': 0.13252445343902908, 'bootstrap': False, 'criterion': 'log_loss'}. Best is trial 66 with value: 0.9312354312354313.
# [I 2024-11-19 22:16:54,416] Trial 81 finished with value: 0.9207459207459207 and parameters: {'n_estimators': 489, 'max_depth': 22, 'min_samples_split': 8, 'random_state': 37, 'min_samples_leaf': 2, 'max_features': 0.17440731875180754, 'bootstrap': False, 'criterion': 'log_loss'}. Best is trial 66 with value: 0.9312354312354313.
# [I 2024-11-19 22:17:04,952] Trial 82 finished with value: 0.9254079254079254 and parameters: {'n_estimators': 455, 'max_depth': 13, 'min_samples_split': 9, 'random_state': 36, 'min_samples_leaf': 1, 'max_features': 0.10124048436030565, 'bootstrap': False, 'criterion': 'log_loss'}. Best is trial 66 with value: 0.9312354312354313.
# [I 2024-11-19 22:17:18,753] Trial 83 finished with value: 0.9265734265734266 and parameters: {'n_estimators': 496, 'max_depth': 14, 'min_samples_split': 7, 'random_state': 40, 'min_samples_leaf': 2, 'max_features': 0.12653910827927453, 'bootstrap': False, 'criterion': 'log_loss'}. Best is trial 66 with value: 0.9312354312354313.
# [I 2024-11-19 22:17:28,988] Trial 84 finished with value: 0.923076923076923 and parameters: {'n_estimators': 253, 'max_depth': 19, 'min_samples_split': 6, 'random_state': 39, 'min_samples_leaf': 1, 'max_features': 0.19130204619525693, 'bootstrap': False, 'criterion': 'log_loss'}. Best is trial 66 with value: 0.9312354312354313.
# [I 2024-11-19 22:17:49,617] Trial 85 finished with value: 0.921911421911422 and parameters: {'n_estimators': 470, 'max_depth': 13, 'min_samples_split': 7, 'random_state': 32, 'min_samples_leaf': 3, 'max_features': 0.21806694166612112, 'bootstrap': False, 'criterion': 'log_loss'}. Best is trial 66 with value: 0.9312354312354313.
# [I 2024-11-19 22:18:03,084] Trial 86 finished with value: 0.9079254079254079 and parameters: {'n_estimators': 486, 'max_depth': 24, 'min_samples_split': 7, 'random_state': 41, 'min_samples_leaf': 5, 'max_features': 0.15589070782105546, 'bootstrap': False, 'criterion': 'gini'}. Best is trial 66 with value: 0.9312354312354313.
# [I 2024-11-19 22:18:15,343] Trial 87 finished with value: 0.93006993006993 and parameters: {'n_estimators': 458, 'max_depth': 16, 'min_samples_split': 5, 'random_state': 30, 'min_samples_leaf': 1, 'max_features': 0.12532839088660952, 'bootstrap': False, 'criterion': 'log_loss'}. Best is trial 66 with value: 0.9312354312354313.
# [I 2024-11-19 22:18:27,609] Trial 88 finished with value: 0.9277389277389277 and parameters: {'n_estimators': 457, 'max_depth': 16, 'min_samples_split': 5, 'random_state': 30, 'min_samples_leaf': 1, 'max_features': 0.12364947356688064, 'bootstrap': False, 'criterion': 'log_loss'}. Best is trial 66 with value: 0.9312354312354313.
# [I 2024-11-19 22:18:40,431] Trial 89 finished with value: 0.9289044289044289 and parameters: {'n_estimators': 453, 'max_depth': 16, 'min_samples_split': 5, 'random_state': 34, 'min_samples_leaf': 1, 'max_features': 0.12938181137659885, 'bootstrap': False, 'criterion': 'log_loss'}. Best is trial 66 with value: 0.9312354312354313.
# [I 2024-11-19 22:18:47,989] Trial 90 finished with value: 0.8962703962703963 and parameters: {'n_estimators': 456, 'max_depth': 16, 'min_samples_split': 5, 'random_state': 35, 'min_samples_leaf': 1, 'max_features': 0.1437435751221543, 'bootstrap': True, 'criterion': 'log_loss', 'max_samples': 0.5095677679231368}. Best is trial 66 with value: 0.9312354312354313.
# [I 2024-11-19 22:19:01,366] Trial 91 finished with value: 0.9277389277389277 and parameters: {'n_estimators': 479, 'max_depth': 17, 'min_samples_split': 5, 'random_state': 32, 'min_samples_leaf': 1, 'max_features': 0.1251479837647952, 'bootstrap': False, 'criterion': 'log_loss'}. Best is trial 66 with value: 0.9312354312354313.
# [I 2024-11-19 22:19:14,372] Trial 92 finished with value: 0.923076923076923 and parameters: {'n_estimators': 479, 'max_depth': 17, 'min_samples_split': 5, 'random_state': 32, 'min_samples_leaf': 1, 'max_features': 0.12454643443873045, 'bootstrap': False, 'criterion': 'log_loss'}. Best is trial 66 with value: 0.9312354312354313.
# [I 2024-11-19 22:19:29,747] Trial 93 finished with value: 0.9265734265734267 and parameters: {'n_estimators': 465, 'max_depth': 19, 'min_samples_split': 3, 'random_state': 34, 'min_samples_leaf': 1, 'max_features': 0.17496417445136014, 'bootstrap': False, 'criterion': 'log_loss'}. Best is trial 66 with value: 0.9312354312354313.
# [I 2024-11-19 22:19:44,981] Trial 94 finished with value: 0.9114219114219114 and parameters: {'n_estimators': 149, 'max_depth': 16, 'min_samples_split': 3, 'random_state': 30, 'min_samples_leaf': 1, 'max_features': 0.5448772008530063, 'bootstrap': False, 'criterion': 'log_loss'}. Best is trial 66 with value: 0.9312354312354313.
# [I 2024-11-19 22:20:03,150] Trial 95 finished with value: 0.9265734265734266 and parameters: {'n_estimators': 429, 'max_depth': 17, 'min_samples_split': 3, 'random_state': 36, 'min_samples_leaf': 1, 'max_features': 0.20084726659266167, 'bootstrap': False, 'criterion': 'log_loss'}. Best is trial 66 with value: 0.9312354312354313.
# [I 2024-11-19 22:20:19,796] Trial 96 finished with value: 0.9277389277389277 and parameters: {'n_estimators': 445, 'max_depth': 20, 'min_samples_split': 4, 'random_state': 32, 'min_samples_leaf': 1, 'max_features': 0.17877965661121376, 'bootstrap': False, 'criterion': 'log_loss'}. Best is trial 66 with value: 0.9312354312354313.
# [I 2024-11-19 22:20:39,581] Trial 97 finished with value: 0.9195804195804196 and parameters: {'n_estimators': 444, 'max_depth': 21, 'min_samples_split': 6, 'random_state': 31, 'min_samples_leaf': 2, 'max_features': 0.23853877245749433, 'bootstrap': False, 'criterion': 'log_loss'}. Best is trial 66 with value: 0.9312354312354313.
# [I 2024-11-19 22:20:53,853] Trial 98 finished with value: 0.9289044289044289 and parameters: {'n_estimators': 455, 'max_depth': 20, 'min_samples_split': 4, 'random_state': 29, 'min_samples_leaf': 1, 'max_features': 0.15004709085215487, 'bootstrap': False, 'criterion': 'log_loss'}. Best is trial 66 with value: 0.9312354312354313.
# [I 2024-11-19 22:21:04,409] Trial 99 finished with value: 0.9312354312354313 and parameters: {'n_estimators': 420, 'max_depth': 20, 'min_samples_split': 4, 'random_state': 27, 'min_samples_leaf': 1, 'max_features': 0.11983781509450792, 'bootstrap': False, 'criterion': 'log_loss'}. Best is trial 66 with value: 0.9312354312354313.
# [I 2024-11-19 22:21:18,864] Trial 100 finished with value: 0.9265734265734267 and parameters: {'n_estimators': 405, 'max_depth': 20, 'min_samples_split': 4, 'random_state': 27, 'min_samples_leaf': 1, 'max_features': 0.18456206637949046, 'bootstrap': False, 'criterion': 'log_loss'}. Best is trial 66 with value: 0.9312354312354313.
# [I 2024-11-19 22:21:31,327] Trial 101 finished with value: 0.9289044289044289 and parameters: {'n_estimators': 446, 'max_depth': 18, 'min_samples_split': 5, 'random_state': 29, 'min_samples_leaf': 1, 'max_features': 0.12663311736109262, 'bootstrap': False, 'criterion': 'log_loss'}. Best is trial 66 with value: 0.9312354312354313.
# [I 2024-11-19 22:21:42,333] Trial 102 finished with value: 0.93006993006993 and parameters: {'n_estimators': 426, 'max_depth': 18, 'min_samples_split': 4, 'random_state': 29, 'min_samples_leaf': 1, 'max_features': 0.12111221674134916, 'bootstrap': False, 'criterion': 'log_loss'}. Best is trial 66 with value: 0.9312354312354313.
# [I 2024-11-19 22:21:53,415] Trial 103 finished with value: 0.9324009324009324 and parameters: {'n_estimators': 422, 'max_depth': 18, 'min_samples_split': 2, 'random_state': 29, 'min_samples_leaf': 1, 'max_features': 0.12496257700908477, 'bootstrap': False, 'criterion': 'log_loss'}. Best is trial 103 with value: 0.9324009324009324.
# [I 2024-11-19 22:22:05,035] Trial 104 finished with value: 0.9324009324009324 and parameters: {'n_estimators': 424, 'max_depth': 18, 'min_samples_split': 2, 'random_state': 29, 'min_samples_leaf': 1, 'max_features': 0.12388329219659756, 'bootstrap': False, 'criterion': 'log_loss'}. Best is trial 103 with value: 0.9324009324009324.
# [I 2024-11-19 22:22:16,758] Trial 105 finished with value: 0.9242424242424243 and parameters: {'n_estimators': 421, 'max_depth': 18, 'min_samples_split': 2, 'random_state': 29, 'min_samples_leaf': 1, 'max_features': 0.14480912550087519, 'bootstrap': False, 'criterion': 'log_loss'}. Best is trial 103 with value: 0.9324009324009324.
# [I 2024-11-19 22:22:30,574] Trial 106 finished with value: 0.9277389277389277 and parameters: {'n_estimators': 427, 'max_depth': 21, 'min_samples_split': 2, 'random_state': 30, 'min_samples_leaf': 1, 'max_features': 0.1639580120525387, 'bootstrap': False, 'criterion': 'log_loss'}. Best is trial 103 with value: 0.9324009324009324.
# [I 2024-11-19 22:22:44,153] Trial 107 finished with value: 0.8927738927738927 and parameters: {'n_estimators': 433, 'max_depth': 19, 'min_samples_split': 3, 'random_state': 28, 'min_samples_leaf': 14, 'max_features': 0.20418581559314597, 'bootstrap': False, 'criterion': 'log_loss'}. Best is trial 103 with value: 0.9324009324009324.
# [I 2024-11-19 22:23:32,039] Trial 108 finished with value: 0.9032634032634034 and parameters: {'n_estimators': 410, 'max_depth': 18, 'min_samples_split': 2, 'random_state': 27, 'min_samples_leaf': 2, 'max_features': 0.7299671174656611, 'bootstrap': False, 'criterion': 'log_loss'}. Best is trial 103 with value: 0.9324009324009324.
# [I 2024-11-19 22:23:40,347] Trial 109 finished with value: 0.914918414918415 and parameters: {'n_estimators': 384, 'max_depth': 15, 'min_samples_split': 4, 'random_state': 26, 'min_samples_leaf': 1, 'max_features': 0.12021546066743982, 'bootstrap': True, 'criterion': 'log_loss', 'max_samples': 0.8606448054215241}. Best is trial 103 with value: 0.9324009324009324.
# [I 2024-11-19 22:24:00,535] Trial 110 finished with value: 0.9242424242424243 and parameters: {'n_estimators': 415, 'max_depth': 17, 'min_samples_split': 5, 'random_state': 22, 'min_samples_leaf': 3, 'max_features': 0.22750104732151982, 'bootstrap': False, 'criterion': 'log_loss'}. Best is trial 103 with value: 0.9324009324009324.
# [I 2024-11-19 22:24:13,891] Trial 111 finished with value: 0.9300699300699301 and parameters: {'n_estimators': 457, 'max_depth': 17, 'min_samples_split': 5, 'random_state': 29, 'min_samples_leaf': 1, 'max_features': 0.1241950606443532, 'bootstrap': False, 'criterion': 'log_loss'}. Best is trial 103 with value: 0.9324009324009324.
# [I 2024-11-19 22:24:27,553] Trial 112 finished with value: 0.93006993006993 and parameters: {'n_estimators': 456, 'max_depth': 18, 'min_samples_split': 4, 'random_state': 29, 'min_samples_leaf': 1, 'max_features': 0.1387329811403142, 'bootstrap': False, 'criterion': 'log_loss'}. Best is trial 103 with value: 0.9324009324009324.
# [I 2024-11-19 22:24:40,584] Trial 113 finished with value: 0.9289044289044289 and parameters: {'n_estimators': 441, 'max_depth': 18, 'min_samples_split': 4, 'random_state': 27, 'min_samples_leaf': 2, 'max_features': 0.14159840966238096, 'bootstrap': False, 'criterion': 'log_loss'}. Best is trial 103 with value: 0.9324009324009324.
# [I 2024-11-19 22:24:54,929] Trial 114 finished with value: 0.9289044289044289 and parameters: {'n_estimators': 402, 'max_depth': 19, 'min_samples_split': 3, 'random_state': 29, 'min_samples_leaf': 1, 'max_features': 0.1654327374111232, 'bootstrap': False, 'criterion': 'log_loss'}. Best is trial 103 with value: 0.9324009324009324.
# [I 2024-11-19 22:25:08,368] Trial 115 finished with value: 0.9265734265734267 and parameters: {'n_estimators': 454, 'max_depth': 20, 'min_samples_split': 4, 'random_state': 24, 'min_samples_leaf': 2, 'max_features': 0.14468470611722317, 'bootstrap': False, 'criterion': 'log_loss'}. Best is trial 103 with value: 0.9324009324009324.
# [I 2024-11-19 22:25:18,354] Trial 116 finished with value: 0.9265734265734267 and parameters: {'n_estimators': 430, 'max_depth': 18, 'min_samples_split': 2, 'random_state': 29, 'min_samples_leaf': 1, 'max_features': 0.11619198265082306, 'bootstrap': False, 'criterion': 'gini'}. Best is trial 103 with value: 0.9324009324009324.
# [I 2024-11-19 22:25:44,451] Trial 117 finished with value: 0.8799533799533799 and parameters: {'n_estimators': 417, 'max_depth': 17, 'min_samples_split': 6, 'random_state': 28, 'min_samples_leaf': 17, 'max_features': 0.4523759235050283, 'bootstrap': False, 'criterion': 'log_loss'}. Best is trial 103 with value: 0.9324009324009324.
# [I 2024-11-19 22:25:56,603] Trial 118 finished with value: 0.8986013986013986 and parameters: {'n_estimators': 83, 'max_depth': 15, 'min_samples_split': 5, 'random_state': 26, 'min_samples_leaf': 3, 'max_features': 0.8416711256786908, 'bootstrap': False, 'criterion': 'log_loss'}. Best is trial 103 with value: 0.9324009324009324.
# [I 2024-11-19 22:26:10,891] Trial 119 finished with value: 0.9277389277389277 and parameters: {'n_estimators': 464, 'max_depth': 21, 'min_samples_split': 3, 'random_state': 31, 'min_samples_leaf': 2, 'max_features': 0.1574374117277609, 'bootstrap': False, 'criterion': 'log_loss'}. Best is trial 103 with value: 0.9324009324009324.
# [I 2024-11-19 22:26:26,327] Trial 120 finished with value: 0.923076923076923 and parameters: {'n_estimators': 443, 'max_depth': 19, 'min_samples_split': 6, 'random_state': 23, 'min_samples_leaf': 1, 'max_features': 0.18649448043131123, 'bootstrap': False, 'criterion': 'log_loss'}. Best is trial 103 with value: 0.9324009324009324.
# [I 2024-11-19 22:26:39,143] Trial 121 finished with value: 0.9289044289044289 and parameters: {'n_estimators': 439, 'max_depth': 18, 'min_samples_split': 4, 'random_state': 27, 'min_samples_leaf': 2, 'max_features': 0.13892901123468288, 'bootstrap': False, 'criterion': 'log_loss'}. Best is trial 103 with value: 0.9324009324009324.
# [I 2024-11-19 22:26:50,885] Trial 122 finished with value: 0.9312354312354313 and parameters: {'n_estimators': 448, 'max_depth': 18, 'min_samples_split': 4, 'random_state': 30, 'min_samples_leaf': 2, 'max_features': 0.11891584812629596, 'bootstrap': False, 'criterion': 'log_loss'}. Best is trial 103 with value: 0.9324009324009324.
# [I 2024-11-19 22:27:03,265] Trial 123 finished with value: 0.9277389277389277 and parameters: {'n_estimators': 451, 'max_depth': 16, 'min_samples_split': 3, 'random_state': 29, 'min_samples_leaf': 2, 'max_features': 0.12248786402371199, 'bootstrap': False, 'criterion': 'log_loss'}. Best is trial 103 with value: 0.9324009324009324.
# [I 2024-11-19 22:27:09,745] Trial 124 finished with value: 0.923076923076923 and parameters: {'n_estimators': 189, 'max_depth': 19, 'min_samples_split': 4, 'random_state': 25, 'min_samples_leaf': 1, 'max_features': 0.15910221235493116, 'bootstrap': False, 'criterion': 'log_loss'}. Best is trial 103 with value: 0.9324009324009324.
# [I 2024-11-19 22:27:20,539] Trial 125 finished with value: 0.9114219114219114 and parameters: {'n_estimators': 468, 'max_depth': 17, 'min_samples_split': 5, 'random_state': 28, 'min_samples_leaf': 9, 'max_features': 0.11764281257694435, 'bootstrap': False, 'criterion': 'log_loss'}. Best is trial 103 with value: 0.9324009324009324.
# [I 2024-11-19 22:27:32,962] Trial 126 finished with value: 0.9300699300699301 and parameters: {'n_estimators': 425, 'max_depth': 20, 'min_samples_split': 5, 'random_state': 30, 'min_samples_leaf': 1, 'max_features': 0.13667240426140834, 'bootstrap': False, 'criterion': 'log_loss'}. Best is trial 103 with value: 0.9324009324009324.
# [I 2024-11-19 22:27:47,715] Trial 127 finished with value: 0.9242424242424243 and parameters: {'n_estimators': 424, 'max_depth': 20, 'min_samples_split': 4, 'random_state': 31, 'min_samples_leaf': 3, 'max_features': 0.17340882979187167, 'bootstrap': False, 'criterion': 'log_loss'}. Best is trial 103 with value: 0.9324009324009324.
# [I 2024-11-19 22:28:00,434] Trial 128 finished with value: 0.9265734265734267 and parameters: {'n_estimators': 432, 'max_depth': 20, 'min_samples_split': 2, 'random_state': 5, 'min_samples_leaf': 2, 'max_features': 0.14428621213079412, 'bootstrap': False, 'criterion': 'log_loss'}. Best is trial 103 with value: 0.9324009324009324.
# [I 2024-11-19 22:28:48,541] Trial 129 finished with value: 0.9125874125874125 and parameters: {'n_estimators': 458, 'max_depth': 16, 'min_samples_split': 6, 'random_state': 31, 'min_samples_leaf': 1, 'max_features': 0.627013388475765, 'bootstrap': False, 'criterion': 'log_loss'}. Best is trial 103 with value: 0.9324009324009324.
# [I 2024-11-19 22:29:03,951] Trial 130 finished with value: 0.921911421911422 and parameters: {'n_estimators': 395, 'max_depth': 21, 'min_samples_split': 3, 'random_state': 30, 'min_samples_leaf': 3, 'max_features': 0.20026547247329712, 'bootstrap': False, 'criterion': 'log_loss'}. Best is trial 103 with value: 0.9324009324009324.
# [I 2024-11-19 22:29:16,411] Trial 131 finished with value: 0.9265734265734267 and parameters: {'n_estimators': 447, 'max_depth': 18, 'min_samples_split': 5, 'random_state': 29, 'min_samples_leaf': 1, 'max_features': 0.13105961533522137, 'bootstrap': False, 'criterion': 'log_loss'}. Best is trial 103 with value: 0.9324009324009324.
# [I 2024-11-19 22:29:26,748] Trial 132 finished with value: 0.9265734265734266 and parameters: {'n_estimators': 418, 'max_depth': 19, 'min_samples_split': 5, 'random_state': 27, 'min_samples_leaf': 1, 'max_features': 0.11520645550856726, 'bootstrap': False, 'criterion': 'log_loss'}. Best is trial 103 with value: 0.9324009324009324.
# [I 2024-11-19 22:29:40,079] Trial 133 finished with value: 0.9277389277389277 and parameters: {'n_estimators': 470, 'max_depth': 18, 'min_samples_split': 4, 'random_state': 30, 'min_samples_leaf': 2, 'max_features': 0.1384152965064494, 'bootstrap': False, 'criterion': 'log_loss'}. Best is trial 103 with value: 0.9324009324009324.
# [I 2024-11-19 22:29:56,285] Trial 134 finished with value: 0.9242424242424242 and parameters: {'n_estimators': 450, 'max_depth': 17, 'min_samples_split': 5, 'random_state': 33, 'min_samples_leaf': 1, 'max_features': 0.16223880144304115, 'bootstrap': False, 'criterion': 'log_loss'}. Best is trial 103 with value: 0.9324009324009324.
# [I 2024-11-19 22:30:04,701] Trial 135 finished with value: 0.9079254079254079 and parameters: {'n_estimators': 434, 'max_depth': 20, 'min_samples_split': 4, 'random_state': 28, 'min_samples_leaf': 2, 'max_features': 0.12765778347601608, 'bootstrap': True, 'criterion': 'log_loss', 'max_samples': 0.7571661934493583}. Best is trial 103 with value: 0.9324009324009324.
# [I 2024-11-19 22:30:16,754] Trial 136 finished with value: 0.9242424242424243 and parameters: {'n_estimators': 405, 'max_depth': 19, 'min_samples_split': 6, 'random_state': 26, 'min_samples_leaf': 1, 'max_features': 0.11283082987027748, 'bootstrap': False, 'criterion': 'gini'}. Best is trial 103 with value: 0.9324009324009324.
# [I 2024-11-19 22:30:33,518] Trial 137 finished with value: 0.923076923076923 and parameters: {'n_estimators': 459, 'max_depth': 16, 'min_samples_split': 3, 'random_state': 31, 'min_samples_leaf': 2, 'max_features': 0.15322142808007636, 'bootstrap': False, 'criterion': 'log_loss'}. Best is trial 103 with value: 0.9324009324009324.
# [I 2024-11-19 22:30:44,520] Trial 138 finished with value: 0.9289044289044289 and parameters: {'n_estimators': 441, 'max_depth': 22, 'min_samples_split': 5, 'random_state': 32, 'min_samples_leaf': 1, 'max_features': 0.1006806857044106, 'bootstrap': False, 'criterion': 'log_loss'}. Best is trial 103 with value: 0.9324009324009324.
# [I 2024-11-19 22:31:02,672] Trial 139 finished with value: 0.9254079254079254 and parameters: {'n_estimators': 463, 'max_depth': 15, 'min_samples_split': 4, 'random_state': 29, 'min_samples_leaf': 2, 'max_features': 0.19339533303697068, 'bootstrap': False, 'criterion': 'log_loss'}. Best is trial 103 with value: 0.9324009324009324.
# [I 2024-11-19 22:31:17,418] Trial 140 finished with value: 0.9254079254079254 and parameters: {'n_estimators': 425, 'max_depth': 17, 'min_samples_split': 6, 'random_state': 38, 'min_samples_leaf': 1, 'max_features': 0.17516608674351086, 'bootstrap': False, 'criterion': 'log_loss'}. Best is trial 103 with value: 0.9324009324009324.
# [I 2024-11-19 22:31:30,612] Trial 141 finished with value: 0.9254079254079254 and parameters: {'n_estimators': 443, 'max_depth': 18, 'min_samples_split': 4, 'random_state': 26, 'min_samples_leaf': 2, 'max_features': 0.1427829831387473, 'bootstrap': False, 'criterion': 'log_loss'}. Best is trial 103 with value: 0.9324009324009324.
# [I 2024-11-19 22:31:43,630] Trial 142 finished with value: 0.9289044289044289 and parameters: {'n_estimators': 433, 'max_depth': 18, 'min_samples_split': 5, 'random_state': 27, 'min_samples_leaf': 1, 'max_features': 0.13759769768062766, 'bootstrap': False, 'criterion': 'log_loss'}. Best is trial 103 with value: 0.9324009324009324.
# ...
# [I 2024-11-20 08:00:45,549] Trial 4954 finished with value: 0.9195804195804196 and parameters: {'n_estimators': 113, 'max_depth': 15, 'min_samples_split': 3, 'random_state': 21, 'min_samples_leaf': 2, 'max_features': 0.14128710316835777, 'bootstrap': False, 'criterion': 'log_loss'}. Best is trial 1223 with value: 0.9405594405594405.
# [I 2024-11-20 08:01:05,547] Trial 4955 finished with value: 0.9079254079254079 and parameters: {'n_estimators': 134, 'max_depth': 14, 'min_samples_split': 3, 'random_state': 27, 'min_samples_leaf': 1, 'max_features': 0.793929827580433, 'bootstrap': False, 'criterion': 'entropy'}. Best is trial 1223 with value: 0.9405594405594405.
# [I 2024-11-20 08:01:10,828] Trial 4956 finished with value: 0.9300699300699301 and parameters: {'n_estimators': 119, 'max_depth': 14, 'min_samples_split': 3, 'random_state': 25, 'min_samples_leaf': 1, 'max_features': 0.11605918967602576, 'bootstrap': False, 'criterion': 'log_loss'}. Best is trial 1223 with value: 0.9405594405594405.
# [I 2024-11-20 08:01:15,824] Trial 4957 finished with value: 0.9277389277389277 and parameters: {'n_estimators': 94, 'max_depth': 15, 'min_samples_split': 4, 'random_state': 26, 'min_samples_leaf': 2, 'max_features': 0.1563153103681562, 'bootstrap': False, 'criterion': 'log_loss'}. Best is trial 1223 with value: 0.9405594405594405.
# [I 2024-11-20 08:01:21,686] Trial 4958 finished with value: 0.9335664335664334 and parameters: {'n_estimators': 128, 'max_depth': 15, 'min_samples_split': 3, 'random_state': 18, 'min_samples_leaf': 1, 'max_features': 0.12724057879747738, 'bootstrap': False, 'criterion': 'log_loss'}. Best is trial 1223 with value: 0.9405594405594405.
# [I 2024-11-20 08:01:27,001] Trial 4959 finished with value: 0.9300699300699301 and parameters: {'n_estimators': 104, 'max_depth': 15, 'min_samples_split': 3, 'random_state': 24, 'min_samples_leaf': 1, 'max_features': 0.1161559419260059, 'bootstrap': False, 'criterion': 'log_loss'}. Best is trial 1223 with value: 0.9405594405594405.
# [I 2024-11-20 08:01:33,752] Trial 4960 finished with value: 0.9254079254079254 and parameters: {'n_estimators': 139, 'max_depth': 14, 'min_samples_split': 3, 'random_state': 28, 'min_samples_leaf': 2, 'max_features': 0.1424399262308272, 'bootstrap': False, 'criterion': 'entropy'}. Best is trial 1223 with value: 0.9405594405594405.
# [I 2024-11-20 08:01:39,306] Trial 4961 finished with value: 0.9300699300699301 and parameters: {'n_estimators': 114, 'max_depth': 14, 'min_samples_split': 3, 'random_state': 25, 'min_samples_leaf': 1, 'max_features': 0.11648316849533666, 'bootstrap': False, 'criterion': 'log_loss'}. Best is trial 1223 with value: 0.9405594405594405.
# [I 2024-11-20 08:01:44,224] Trial 4962 finished with value: 0.9289044289044289 and parameters: {'n_estimators': 105, 'max_depth': 24, 'min_samples_split': 3, 'random_state': 27, 'min_samples_leaf': 1, 'max_features': 0.16169910888232575, 'bootstrap': False, 'criterion': 'log_loss'}. Best is trial 1223 with value: 0.9405594405594405.
# [I 2024-11-20 08:01:49,427] Trial 4963 finished with value: 0.9289044289044289 and parameters: {'n_estimators': 126, 'max_depth': 24, 'min_samples_split': 3, 'random_state': 26, 'min_samples_leaf': 2, 'max_features': 0.14222540700530734, 'bootstrap': False, 'criterion': 'log_loss'}. Best is trial 1223 with value: 0.9405594405594405.
# [I 2024-11-20 08:02:14,118] Trial 4964 finished with value: 0.8986013986013986 and parameters: {'n_estimators': 161, 'max_depth': 16, 'min_samples_split': 3, 'random_state': 24, 'min_samples_leaf': 1, 'max_features': 0.8898312418660788, 'bootstrap': False, 'criterion': 'entropy'}. Best is trial 1223 with value: 0.9405594405594405.
# [I 2024-11-20 08:02:16,801] Trial 4965 finished with value: 0.8997668997668998 and parameters: {'n_estimators': 120, 'max_depth': 16, 'min_samples_split': 4, 'random_state': 28, 'min_samples_leaf': 1, 'max_features': 0.1287206831044763, 'bootstrap': True, 'criterion': 'log_loss', 'max_samples': 0.5591421812482745}. Best is trial 1223 with value: 0.9405594405594405.
# [I 2024-11-20 08:02:19,956] Trial 4966 finished with value: 0.9254079254079254 and parameters: {'n_estimators': 50, 'max_depth': 15, 'min_samples_split': 3, 'random_state': 11, 'min_samples_leaf': 2, 'max_features': 0.18791827446039772, 'bootstrap': False, 'criterion': 'log_loss'}. Best is trial 1223 with value: 0.9405594405594405.
# [I 2024-11-20 08:02:24,920] Trial 4967 finished with value: 0.921911421911422 and parameters: {'n_estimators': 138, 'max_depth': 15, 'min_samples_split': 4, 'random_state': 43, 'min_samples_leaf': 1, 'max_features': 0.11616952109482309, 'bootstrap': False, 'criterion': 'gini'}. Best is trial 1223 with value: 0.9405594405594405.
# [I 2024-11-20 08:02:28,770] Trial 4968 finished with value: 0.9277389277389277 and parameters: {'n_estimators': 95, 'max_depth': 16, 'min_samples_split': 3, 'random_state': 26, 'min_samples_leaf': 1, 'max_features': 0.13975506217988298, 'bootstrap': False, 'criterion': 'log_loss'}. Best is trial 1223 with value: 0.9405594405594405.
# [I 2024-11-20 08:02:45,568] Trial 4969 finished with value: 0.9265734265734267 and parameters: {'n_estimators': 493, 'max_depth': 16, 'min_samples_split': 3, 'random_state': 25, 'min_samples_leaf': 1, 'max_features': 0.16745014085003074, 'bootstrap': False, 'criterion': 'entropy'}. Best is trial 1223 with value: 0.9405594405594405.
# [I 2024-11-20 08:02:49,061] Trial 4970 finished with value: 0.9347319347319347 and parameters: {'n_estimators': 90, 'max_depth': 13, 'min_samples_split': 3, 'random_state': 27, 'min_samples_leaf': 2, 'max_features': 0.11646585701459602, 'bootstrap': False, 'criterion': 'log_loss'}. Best is trial 1223 with value: 0.9405594405594405.
# [I 2024-11-20 08:02:54,042] Trial 4971 finished with value: 0.9254079254079254 and parameters: {'n_estimators': 147, 'max_depth': 15, 'min_samples_split': 3, 'random_state': 24, 'min_samples_leaf': 1, 'max_features': 0.143471602785851, 'bootstrap': False, 'criterion': 'log_loss'}. Best is trial 1223 with value: 0.9405594405594405.
# [I 2024-11-20 08:02:59,023] Trial 4972 finished with value: 0.9312354312354313 and parameters: {'n_estimators': 132, 'max_depth': 13, 'min_samples_split': 3, 'random_state': 26, 'min_samples_leaf': 1, 'max_features': 0.11533986244632283, 'bootstrap': False, 'criterion': 'log_loss'}. Best is trial 1223 with value: 0.9405594405594405.
# [I 2024-11-20 08:03:03,281] Trial 4973 finished with value: 0.921911421911422 and parameters: {'n_estimators': 111, 'max_depth': 15, 'min_samples_split': 4, 'random_state': 19, 'min_samples_leaf': 2, 'max_features': 0.128223168636377, 'bootstrap': False, 'criterion': 'log_loss'}. Best is trial 1223 with value: 0.9405594405594405.
# [I 2024-11-20 08:03:08,575] Trial 4974 finished with value: 0.9277389277389277 and parameters: {'n_estimators': 123, 'max_depth': 25, 'min_samples_split': 3, 'random_state': 22, 'min_samples_leaf': 1, 'max_features': 0.15456567021870818, 'bootstrap': False, 'criterion': 'entropy'}. Best is trial 1223 with value: 0.9405594405594405.
# [I 2024-11-20 08:03:14,188] Trial 4975 finished with value: 0.9277389277389277 and parameters: {'n_estimators': 156, 'max_depth': 13, 'min_samples_split': 3, 'random_state': 37, 'min_samples_leaf': 2, 'max_features': 0.1150763867282871, 'bootstrap': False, 'criterion': 'log_loss'}. Best is trial 1223 with value: 0.9405594405594405.
# [I 2024-11-20 08:03:19,444] Trial 4976 finished with value: 0.9265734265734266 and parameters: {'n_estimators': 138, 'max_depth': 14, 'min_samples_split': 3, 'random_state': 25, 'min_samples_leaf': 1, 'max_features': 0.1410052817958054, 'bootstrap': False, 'criterion': 'log_loss'}. Best is trial 1223 with value: 0.9405594405594405.
# [I 2024-11-20 08:03:26,181] Trial 4977 finished with value: 0.923076923076923 and parameters: {'n_estimators': 171, 'max_depth': 24, 'min_samples_split': 3, 'random_state': 29, 'min_samples_leaf': 3, 'max_features': 0.175086726462217, 'bootstrap': False, 'criterion': 'log_loss'}. Best is trial 1223 with value: 0.9405594405594405.
# [I 2024-11-20 08:03:39,115] Trial 4978 finished with value: 0.9289044289044289 and parameters: {'n_estimators': 475, 'max_depth': 15, 'min_samples_split': 4, 'random_state': 39, 'min_samples_leaf': 1, 'max_features': 0.1271278870373442, 'bootstrap': False, 'criterion': 'entropy'}. Best is trial 1223 with value: 0.9405594405594405.
# [I 2024-11-20 08:03:42,722] Trial 4979 finished with value: 0.9242424242424242 and parameters: {'n_estimators': 104, 'max_depth': 15, 'min_samples_split': 2, 'random_state': 28, 'min_samples_leaf': 1, 'max_features': 0.11540720028347415, 'bootstrap': False, 'criterion': 'log_loss'}. Best is trial 1223 with value: 0.9405594405594405.
# [I 2024-11-20 08:03:45,139] Trial 4980 finished with value: 0.9265734265734266 and parameters: {'n_estimators': 50, 'max_depth': 14, 'min_samples_split': 3, 'random_state': 26, 'min_samples_leaf': 1, 'max_features': 0.1531951165175611, 'bootstrap': False, 'criterion': 'log_loss'}. Best is trial 1223 with value: 0.9405594405594405.
# [I 2024-11-20 08:03:47,748] Trial 4981 finished with value: 0.8962703962703964 and parameters: {'n_estimators': 129, 'max_depth': 24, 'min_samples_split': 7, 'random_state': 27, 'min_samples_leaf': 2, 'max_features': 0.13897801927800735, 'bootstrap': True, 'criterion': 'log_loss', 'max_samples': 0.6087980796635588}. Best is trial 1223 with value: 0.9405594405594405.
# [I 2024-11-20 08:03:51,688] Trial 4982 finished with value: 0.9277389277389277 and parameters: {'n_estimators': 114, 'max_depth': 14, 'min_samples_split': 2, 'random_state': 24, 'min_samples_leaf': 1, 'max_features': 0.1282546001947912, 'bootstrap': False, 'criterion': 'log_loss'}. Best is trial 1223 with value: 0.9405594405594405.
# [I 2024-11-20 08:03:54,773] Trial 4983 finished with value: 0.9289044289044289 and parameters: {'n_estimators': 86, 'max_depth': 13, 'min_samples_split': 2, 'random_state': 21, 'min_samples_leaf': 1, 'max_features': 0.10068282349422672, 'bootstrap': False, 'criterion': 'entropy'}. Best is trial 1223 with value: 0.9405594405594405.
# [I 2024-11-20 08:03:57,272] Trial 4984 finished with value: 0.9207459207459207 and parameters: {'n_estimators': 58, 'max_depth': 15, 'min_samples_split': 3, 'random_state': 23, 'min_samples_leaf': 2, 'max_features': 0.1667031563752886, 'bootstrap': False, 'criterion': 'log_loss'}. Best is trial 1223 with value: 0.9405594405594405.
# [I 2024-11-20 08:04:06,957] Trial 4985 finished with value: 0.9300699300699301 and parameters: {'n_estimators': 446, 'max_depth': 15, 'min_samples_split': 2, 'random_state': 25, 'min_samples_leaf': 1, 'max_features': 0.10026683709064961, 'bootstrap': False, 'criterion': 'log_loss'}. Best is trial 1223 with value: 0.9405594405594405.
# [I 2024-11-20 08:04:11,308] Trial 4986 finished with value: 0.9172494172494172 and parameters: {'n_estimators': 144, 'max_depth': 16, 'min_samples_split': 2, 'random_state': 27, 'min_samples_leaf': 5, 'max_features': 0.11465637325719633, 'bootstrap': False, 'criterion': 'log_loss'}. Best is trial 1223 with value: 0.9405594405594405.
# [I 2024-11-20 08:04:14,776] Trial 4987 finished with value: 0.9335664335664337 and parameters: {'n_estimators': 119, 'max_depth': 14, 'min_samples_split': 2, 'random_state': 25, 'min_samples_leaf': 2, 'max_features': 0.10002177398427334, 'bootstrap': False, 'criterion': 'entropy'}. Best is trial 1223 with value: 0.9405594405594405.
# [I 2024-11-20 08:04:36,643] Trial 4988 finished with value: 0.8776223776223776 and parameters: {'n_estimators': 130, 'max_depth': 14, 'min_samples_split': 3, 'random_state': 27, 'min_samples_leaf': 1, 'max_features': 0.9969322355230716, 'bootstrap': False, 'criterion': 'log_loss'}. Best is trial 1223 with value: 0.9405594405594405.
# [I 2024-11-20 08:04:40,462] Trial 4989 finished with value: 0.9079254079254079 and parameters: {'n_estimators': 152, 'max_depth': 16, 'min_samples_split': 16, 'random_state': 29, 'min_samples_leaf': 1, 'max_features': 0.10051596923672655, 'bootstrap': False, 'criterion': 'gini'}. Best is trial 1223 with value: 0.9405594405594405.
# [I 2024-11-20 08:04:44,054] Trial 4990 finished with value: 0.9289044289044289 and parameters: {'n_estimators': 88, 'max_depth': 14, 'min_samples_split': 2, 'random_state': 26, 'min_samples_leaf': 2, 'max_features': 0.14311727259973708, 'bootstrap': False, 'criterion': 'log_loss'}. Best is trial 1223 with value: 0.9405594405594405.
# [I 2024-11-20 08:04:47,870] Trial 4991 finished with value: 0.9277389277389277 and parameters: {'n_estimators': 109, 'max_depth': 15, 'min_samples_split': 3, 'random_state': 23, 'min_samples_leaf': 1, 'max_features': 0.12939379965625206, 'bootstrap': False, 'criterion': 'log_loss'}. Best is trial 1223 with value: 0.9405594405594405.
# [I 2024-11-20 08:04:51,795] Trial 4992 finished with value: 0.9020979020979021 and parameters: {'n_estimators': 99, 'max_depth': 16, 'min_samples_split': 2, 'random_state': 24, 'min_samples_leaf': 12, 'max_features': 0.1927524501601326, 'bootstrap': False, 'criterion': 'entropy'}. Best is trial 1223 with value: 0.9405594405594405.
# [I 2024-11-20 08:04:57,163] Trial 4993 finished with value: 0.9277389277389277 and parameters: {'n_estimators': 137, 'max_depth': 15, 'min_samples_split': 3, 'random_state': 27, 'min_samples_leaf': 1, 'max_features': 0.1554632554625487, 'bootstrap': False, 'criterion': 'log_loss'}. Best is trial 1223 with value: 0.9405594405594405.
# [I 2024-11-20 08:05:00,848] Trial 4994 finished with value: 0.9242424242424242 and parameters: {'n_estimators': 122, 'max_depth': 25, 'min_samples_split': 2, 'random_state': 25, 'min_samples_leaf': 3, 'max_features': 0.11677113859450253, 'bootstrap': False, 'criterion': 'log_loss'}. Best is trial 1223 with value: 0.9405594405594405.
# [I 2024-11-20 08:05:03,156] Trial 4995 finished with value: 0.9207459207459207 and parameters: {'n_estimators': 57, 'max_depth': 15, 'min_samples_split': 2, 'random_state': 22, 'min_samples_leaf': 2, 'max_features': 0.12829946287932847, 'bootstrap': False, 'criterion': 'log_loss'}. Best is trial 1223 with value: 0.9405594405594405.
# [I 2024-11-20 08:05:07,642] Trial 4996 finished with value: 0.9242424242424243 and parameters: {'n_estimators': 129, 'max_depth': 15, 'min_samples_split': 3, 'random_state': 13, 'min_samples_leaf': 1, 'max_features': 0.14100106515716518, 'bootstrap': False, 'criterion': 'log_loss'}. Best is trial 1223 with value: 0.9405594405594405.
# [I 2024-11-20 08:05:13,239] Trial 4997 finished with value: 0.923076923076923 and parameters: {'n_estimators': 142, 'max_depth': 24, 'min_samples_split': 2, 'random_state': 3, 'min_samples_leaf': 1, 'max_features': 0.16450246439595853, 'bootstrap': False, 'criterion': 'entropy'}. Best is trial 1223 with value: 0.9405594405594405.
# [I 2024-11-20 08:05:16,741] Trial 4998 finished with value: 0.9184149184149183 and parameters: {'n_estimators': 114, 'max_depth': 17, 'min_samples_split': 4, 'random_state': 28, 'min_samples_leaf': 2, 'max_features': 0.12732406251329342, 'bootstrap': False, 'criterion': 'log_loss'}. Best is trial 1223 with value: 0.9405594405594405.
# [I 2024-11-20 08:05:19,223] Trial 4999 finished with value: 0.9289044289044289 and parameters: {'n_estimators': 100, 'max_depth': 16, 'min_samples_split': 3, 'random_state': 26, 'min_samples_leaf': 1, 'max_features': 0.10009283157492017, 'bootstrap': False, 'criterion': 'log_loss'}. Best is trial 1223 with value: 0.9405594405594405.
# Best parameters for Random Forest: {'n_estimators': 108, 'max_depth': 22, 'min_samples_split': 3, 'random_state': 20, 'min_samples_leaf': 1, 'max_features': 0.13137811479167025, 'bootstrap': False, 'criterion': 'log_loss'}
# RandomForestClassifier(bootstrap=False, criterion='log_loss', max_depth=22,
#                        max_features=0.13137811479167025, min_samples_split=3,
#                        n_estimators=108, n_jobs=-1, random_state=20)

# %%
import optuna
import xgboost as xgb
from sklearn.metrics import classification_report, confusion_matrix
import numpy as np

# Function to optimize hyperparameters using Optuna
def objective(trial):
    # Define the hyperparameters to tune
    param = {
        'n_estimators': trial.suggest_categorical('n_estimators', [100, 200, 300, 400, 500]),
        'max_depth': trial.suggest_int('max_depth', 3, 10),
        'learning_rate': trial.suggest_float('learning_rate', 0.01, 0.3, log=True),
        'subsample': trial.suggest_float('subsample', 0.6, 1.0),
        'colsample_bytree': trial.suggest_float('colsample_bytree', 0.6, 1.0),
        'min_child_weight': trial.suggest_int('min_child_weight', 1, 10),
        'gamma': trial.suggest_float('gamma', 1e-8, 1.0, log=True),
        'reg_alpha': trial.suggest_float('reg_alpha', 1e-8, 1.0, log=True),
        'reg_lambda': trial.suggest_float('reg_lambda', 1e-8, 1.0, log=True),
        'objective': 'multi:softmax',
        'num_class': len(classes),  # Ensure this is set correctly based on your target variable
        'eval_metric': 'mlogloss'
    }

    # Create the model with the suggested hyperparameters
    model = xgb.XGBClassifier(**param, random_state=18)

    # Fit the model
    model.fit(X_train, y_train)

    # Evaluate the model
    y_pred = model.predict(X_test)
    accuracy = (y_pred == y_test).mean()  # Accuracy as the objective to maximize

    return accuracy

# Create an Optuna study
study = optuna.create_study(direction='maximize')

# Optimize the hyperparameters
study.optimize(objective, n_trials=5000)

# Print the best trial details
print(f"Best trial: {study.best_trial.params}")

# Train the model with the best parameters found
best_params = study.best_trial.params
best_model = xgb.XGBClassifier(**best_params, random_state=18)
best_model.fit(X_train, y_train)

# Predict and evaluate the final model
y_pred = best_model.predict(X_test)
print("Optuna Tuned XGBoost Classification Report:")
print(classification_report(y_test, y_pred))
print("Confusion Matrix:")
print(confusion_matrix(y_test, y_pred))
# Out:
# [I 2024-11-19 01:05:09,821] A new study created in memory with name: no-name-89fd8d65-7541-428e-867a-7b2fc25fef90
# [I 2024-11-19 01:05:20,249] Trial 0 finished with value: 0.9534883720930233 and parameters: {'n_estimators': 100, 'max_depth': 8, 'learning_rate': 0.026081194324764658, 'subsample': 0.7250399297610066, 'colsample_bytree': 0.6764239858372214, 'min_child_weight': 7, 'gamma': 0.0015543872184413505, 'reg_alpha': 0.0001195624987008421, 'reg_lambda': 0.015227175924103433}. Best is trial 0 with value: 0.9534883720930233.
# [I 2024-11-19 01:05:36,188] Trial 1 finished with value: 0.9441860465116279 and parameters: {'n_estimators': 500, 'max_depth': 6, 'learning_rate': 0.10027155429756181, 'subsample': 0.6327280119177586, 'colsample_bytree': 0.9727489536735743, 'min_child_weight': 5, 'gamma': 4.1833076362429466e-05, 'reg_alpha': 0.777853906750517, 'reg_lambda': 0.3004751897144287}. Best is trial 0 with value: 0.9534883720930233.
# [I 2024-11-19 01:06:18,289] Trial 2 finished with value: 0.9534883720930233 and parameters: {'n_estimators': 500, 'max_depth': 5, 'learning_rate': 0.015281729978747898, 'subsample': 0.9811681110011529, 'colsample_bytree': 0.9219318930992763, 'min_child_weight': 4, 'gamma': 5.183989980403239e-07, 'reg_alpha': 6.065811856935158e-06, 'reg_lambda': 1.8690461685031785e-07}. Best is trial 0 with value: 0.9534883720930233.
# [I 2024-11-19 01:06:29,241] Trial 3 finished with value: 0.9441860465116279 and parameters: {'n_estimators': 400, 'max_depth': 4, 'learning_rate': 0.20687473067588913, 'subsample': 0.7168159071940998, 'colsample_bytree': 0.8412175884975217, 'min_child_weight': 8, 'gamma': 1.6047401850430684e-08, 'reg_alpha': 1.509914024722385e-08, 'reg_lambda': 0.45287621449788307}. Best is trial 0 with value: 0.9534883720930233.
# [I 2024-11-19 01:06:36,324] Trial 4 finished with value: 0.9488372093023256 and parameters: {'n_estimators': 200, 'max_depth': 6, 'learning_rate': 0.06955505396278491, 'subsample': 0.8526279415471423, 'colsample_bytree': 0.7159009705196399, 'min_child_weight': 10, 'gamma': 0.022327201783184435, 'reg_alpha': 0.0004234178965989329, 'reg_lambda': 1.6647066748039545e-06}. Best is trial 0 with value: 0.9534883720930233.
# [I 2024-11-19 01:06:41,712] Trial 5 finished with value: 0.958139534883721 and parameters: {'n_estimators': 100, 'max_depth': 9, 'learning_rate': 0.19263629640050273, 'subsample': 0.654242109539969, 'colsample_bytree': 0.8139368719751343, 'min_child_weight': 8, 'gamma': 0.0203287679241584, 'reg_alpha': 2.3590067416606226e-08, 'reg_lambda': 0.0002879410562427547}. Best is trial 5 with value: 0.958139534883721.
# [I 2024-11-19 01:07:14,822] Trial 6 finished with value: 0.9488372093023256 and parameters: {'n_estimators': 500, 'max_depth': 9, 'learning_rate': 0.018507010906240146, 'subsample': 0.8383650825387007, 'colsample_bytree': 0.8224964389395445, 'min_child_weight': 8, 'gamma': 5.556675508229878e-06, 'reg_alpha': 2.2590630736185995e-06, 'reg_lambda': 1.08032773333755e-08}. Best is trial 5 with value: 0.958139534883721.
# [I 2024-11-19 01:07:28,447] Trial 7 finished with value: 0.9488372093023256 and parameters: {'n_estimators': 500, 'max_depth': 6, 'learning_rate': 0.22918718795960358, 'subsample': 0.9853293671683432, 'colsample_bytree': 0.6958967935787492, 'min_child_weight': 10, 'gamma': 0.0007628847351169273, 'reg_alpha': 0.00011735308518484541, 'reg_lambda': 0.52153772907978}. Best is trial 5 with value: 0.958139534883721.
# [I 2024-11-19 01:07:42,014] Trial 8 finished with value: 0.9395348837209302 and parameters: {'n_estimators': 200, 'max_depth': 5, 'learning_rate': 0.04534954763124582, 'subsample': 0.6121652997645384, 'colsample_bytree': 0.8383935578673193, 'min_child_weight': 9, 'gamma': 0.013536814090469928, 'reg_alpha': 0.0003062935099249994, 'reg_lambda': 0.009785468149396617}. Best is trial 5 with value: 0.958139534883721.
# [I 2024-11-19 01:08:21,637] Trial 9 finished with value: 0.9488372093023256 and parameters: {'n_estimators': 300, 'max_depth': 10, 'learning_rate': 0.014578825754401451, 'subsample': 0.8743437461439548, 'colsample_bytree': 0.9425583407781777, 'min_child_weight': 10, 'gamma': 4.440934105704009e-07, 'reg_alpha': 6.849055025185718e-06, 'reg_lambda': 5.841125806422741e-08}. Best is trial 5 with value: 0.958139534883721.
# [I 2024-11-19 01:10:52,901] Trial 24 finished with value: 0.958139534883721 and parameters: {'n_estimators': 400, 'max_depth': 8, 'learning_rate': 0.05877413447941195, 'subsample': 0.7590232802094897, 'colsample_bytree': 0.6428255021404473, 'min_child_weight': 3, 'gamma': 0.15590660813564608, 'reg_alpha': 1.596396765611513e-05, 'reg_lambda': 9.892843006504853e-06}. Best is trial 17 with value: 0.9627906976744186.
# [I 2024-11-19 01:11:11,781] Trial 25 finished with value: 0.9534883720930233 and parameters: {'n_estimators': 300, 'max_depth': 7, 'learning_rate': 0.04329837711902782, 'subsample': 0.8142580712205703, 'colsample_bytree': 0.9916066733260563, 'min_child_weight': 2, 'gamma': 0.4346697352966664, 'reg_alpha': 1.0539008666489188e-08, 'reg_lambda': 1.3117700771498737e-06}. Best is trial 17 with value: 0.9627906976744186.
# [I 2024-11-19 01:11:22,142] Trial 26 finished with value: 0.9441860465116279 and parameters: {'n_estimators': 100, 'max_depth': 9, 'learning_rate': 0.030522695672057464, 'subsample': 0.6275580205017344, 'colsample_bytree': 0.782725484368886, 'min_child_weight': 4, 'gamma': 0.9783910021819852, 'reg_alpha': 5.809140166596019e-07, 'reg_lambda': 1.6044947195956643e-06}. Best is trial 17 with value: 0.9627906976744186.
# [I 2024-11-19 01:11:37,264] Trial 27 finished with value: 0.9627906976744186 and parameters: {'n_estimators': 100, 'max_depth': 8, 'learning_rate': 0.08986709459551884, 'subsample': 0.7396281882401301, 'colsample_bytree': 0.7352725084540185, 'min_child_weight': 1, 'gamma': 0.0037030198917062424, 'reg_alpha': 5.54153763692366e-08, 'reg_lambda': 0.00017011510596818527}. Best is trial 17 with value: 0.9627906976744186.
# [I 2024-11-19 01:11:47,958] Trial 28 finished with value: 0.958139534883721 and parameters: {'n_estimators': 100, 'max_depth': 5, 'learning_rate': 0.05234535451656021, 'subsample': 0.6849675691832534, 'colsample_bytree': 0.8630246854772288, 'min_child_weight': 3, 'gamma': 0.05591753430611901, 'reg_alpha': 0.004251480604812956, 'reg_lambda': 1.8782503038135233e-05}. Best is trial 17 with value: 0.9627906976744186.
# [I 2024-11-19 01:11:57,290] Trial 29 finished with value: 0.958139534883721 and parameters: {'n_estimators': 100, 'max_depth': 8, 'learning_rate': 0.11419321262638549, 'subsample': 0.6946373720538662, 'colsample_bytree': 0.9133458628992355, 'min_child_weight': 2, 'gamma': 0.0006132507666026266, 'reg_alpha': 3.476010931185105e-05, 'reg_lambda': 0.0040316004430633445}. Best is trial 17 with value: 0.9627906976744186.
# [I 2024-11-19 01:12:03,409] Trial 30 finished with value: 0.9488372093023256 and parameters: {'n_estimators': 100, 'max_depth': 7, 'learning_rate': 0.1553753225609433, 'subsample': 0.6403698899331203, 'colsample_bytree': 0.6549777369058596, 'min_child_weight': 4, 'gamma': 0.13652453828952132, 'reg_alpha': 5.2261854692398276e-08, 'reg_lambda': 3.3936971735969177e-06}. Best is trial 17 with value: 0.9627906976744186.
# [I 2024-11-19 01:14:51,482] Trial 38 finished with value: 0.9534883720930233 and parameters: {'n_estimators': 300, 'max_depth': 9, 'learning_rate': 0.0731213051996122, 'subsample': 0.8041779328512065, 'colsample_bytree': 0.7135187507947578, 'min_child_weight': 5, 'gamma': 0.024208061856183218, 'reg_alpha': 1.9365998843270084e-07, 'reg_lambda': 0.0005189961484831951}. Best is trial 31 with value: 0.9674418604651163.
# [I 2024-11-19 01:14:56,567] Trial 39 finished with value: 0.958139534883721 and parameters: {'n_estimators': 100, 'max_depth': 8, 'learning_rate': 0.287449223167227, 'subsample': 0.7211501348873868, 'colsample_bytree': 0.6909769194845232, 'min_child_weight': 4, 'gamma': 3.089727396739992e-08, 'reg_alpha': 0.342305371747025, 'reg_lambda': 0.0035626558903473467}. Best is trial 31 with value: 0.9674418604651163.
# [I 2024-11-19 01:15:14,714] Trial 40 finished with value: 0.9534883720930233 and parameters: {'n_estimators': 500, 'max_depth': 4, 'learning_rate': 0.11035612185008827, 'subsample': 0.6206194359333671, 'colsample_bytree': 0.9508953683795108, 'min_child_weight': 3, 'gamma': 0.0022948494036063288, 'reg_alpha': 3.0924667956214724e-08, 'reg_lambda': 4.046162716027712e-06}. Best is trial 31 with value: 0.9674418604651163.
# [I 2024-11-19 01:15:37,720] Trial 41 finished with value: 0.958139534883721 and parameters: {'n_estimators': 100, 'max_depth': 9, 'learning_rate': 0.08242963972891391, 'subsample': 0.7459899858247315, 'colsample_bytree': 0.8003705146763016, 'min_child_weight': 1, 'gamma': 0.003819466240576636, 'reg_alpha': 6.019134325145053e-08, 'reg_lambda': 0.00018708815855399932}. Best is trial 31 with value: 0.9674418604651163.
# [I 2024-11-19 01:15:48,973] Trial 42 finished with value: 0.9674418604651163 and parameters: {'n_estimators': 100, 'max_depth': 8, 'learning_rate': 0.08136135028739208, 'subsample': 0.729228785243667, 'colsample_bytree': 0.7417029999274282, 'min_child_weight': 1, 'gamma': 2.0673896971403806e-05, 'reg_alpha': 3.979681099149246e-07, 'reg_lambda': 2.2512214273730494e-05}. Best is trial 31 with value: 0.9674418604651163.
# [I 2024-11-19 01:15:56,675] Trial 43 finished with value: 0.9674418604651163 and parameters: {'n_estimators': 100, 'max_depth': 7, 'learning_rate': 0.12972261121687176, 'subsample': 0.6524096786906576, 'colsample_bytree': 0.7330547412772701, 'min_child_weight': 2, 'gamma': 1.4995127786151933e-05, 'reg_alpha': 2.0967185839213127e-08, 'reg_lambda': 2.108614260282606e-05}. Best is trial 31 with value: 0.9674418604651163.
# [I 2024-11-19 01:16:05,124] Trial 44 finished with value: 0.9534883720930233 and parameters: {'n_estimators': 100, 'max_depth': 7, 'learning_rate': 0.14354939345356607, 'subsample': 0.6495835566986229, 'colsample_bytree': 0.6430269315793974, 'min_child_weight': 2, 'gamma': 7.498908162400377e-06, 'reg_alpha': 1.8325059958692013e-08, 'reg_lambda': 3.452468061800878e-05}. Best is trial 31 with value: 0.9674418604651163.
# [I 2024-11-19 01:16:23,572] Trial 45 finished with value: 0.958139534883721 and parameters: {'n_estimators': 200, 'max_depth': 6, 'learning_rate': 0.06485005902949462, 'subsample': 0.716443630271882, 'colsample_bytree': 0.7227870919776116, 'min_child_weight': 1, 'gamma': 2.4998337349827e-05, 'reg_alpha': 4.6936897721024604e-07, 'reg_lambda': 2.4214472249035608e-05}. Best is trial 31 with value: 0.9674418604651163.
# [I 2024-11-19 01:16:33,346] Trial 46 finished with value: 0.9534883720930233 and parameters: {'n_estimators': 100, 'max_depth': 8, 'learning_rate': 0.09228422415157372, 'subsample': 0.6653611902202345, 'colsample_bytree': 0.744414742450345, 'min_child_weight': 2, 'gamma': 2.190295615905716e-06, 'reg_alpha': 1.804636137267343e-08, 'reg_lambda': 0.00037044716808053635}. Best is trial 31 with value: 0.9674418604651163.
# [I 2024-11-19 01:16:57,973] Trial 47 finished with value: 0.958139534883721 and parameters: {'n_estimators': 500, 'max_depth': 6, 'learning_rate': 0.0531351388185115, 'subsample': 0.768994736243038, 'colsample_bytree': 0.6880576978533198, 'min_child_weight': 1, 'gamma': 9.04133107762833e-06, 'reg_alpha': 3.0760582677384886e-06, 'reg_lambda': 8.457945731116043e-05}. Best is trial 31 with value: 0.9674418604651163.
# [I 2024-11-19 01:17:05,071] Trial 48 finished with value: 0.958139534883721 and parameters: {'n_estimators': 100, 'max_depth': 7, 'learning_rate': 0.1900971429272598, 'subsample': 0.7051865476960553, 'colsample_bytree': 0.7687186204498736, 'min_child_weight': 2, 'gamma': 1.8642575844829316e-06, 'reg_alpha': 1.2940958786513963e-07, 'reg_lambda': 1.4528218627953883e-05}. Best is trial 31 with value: 0.9674418604651163.
# [I 2024-11-19 01:17:19,140] Trial 49 finished with value: 0.958139534883721 and parameters: {'n_estimators': 400, 'max_depth': 5, 'learning_rate': 0.13037262379566011, 'subsample': 0.7221088694105244, 'colsample_bytree': 0.7062433845548198, 'min_child_weight': 1, 'gamma': 2.5304193785403937e-07, 'reg_alpha': 1.025801866545318e-08, 'reg_lambda': 7.19350742979563e-05}. Best is trial 31 with value: 0.9674418604651163.
# [I 2024-11-19 01:17:27,210] Trial 50 finished with value: 0.958139534883721 and parameters: {'n_estimators': 100, 'max_depth': 8, 'learning_rate': 0.23369147746947397, 'subsample': 0.9553957115428845, 'colsample_bytree': 0.6244612720782099, 'min_child_weight': 2, 'gamma': 3.712033063784222e-05, 'reg_alpha': 3.0706742626232556e-07, 'reg_lambda': 8.103850942997599e-07}. Best is trial 31 with value: 0.9674418604651163.
# [I 2024-11-19 01:17:35,139] Trial 51 finished with value: 0.9627906976744186 and parameters: {'n_estimators': 100, 'max_depth': 9, 'learning_rate': 0.10754848187497607, 'subsample': 0.6757690686348251, 'colsample_bytree': 0.8351227704657341, 'min_child_weight': 3, 'gamma': 0.0002830981176198223, 'reg_alpha': 2.2210898905246173e-08, 'reg_lambda': 3.727102386978282e-06}. Best is trial 31 with value: 0.9674418604651163.
# [I 2024-11-19 01:17:42,655] Trial 52 finished with value: 0.9627906976744186 and parameters: {'n_estimators': 100, 'max_depth': 8, 'learning_rate': 0.12925484952423957, 'subsample': 0.6512727915561627, 'colsample_bytree': 0.8045711511912043, 'min_child_weight': 2, 'gamma': 1.684847328266272e-05, 'reg_alpha': 3.5058292992114473e-08, 'reg_lambda': 1.0593869479581524e-07}. Best is trial 31 with value: 0.9674418604651163.
# [I 2024-11-19 01:23:13,663] Trial 82 finished with value: 0.9534883720930233 and parameters: {'n_estimators': 100, 'max_depth': 9, 'learning_rate': 0.13304204092600183, 'subsample': 0.7127241622370318, 'colsample_bytree': 0.7312786524173083, 'min_child_weight': 1, 'gamma': 0.009919012268613648, 'reg_alpha': 1.9823002942409092e-07, 'reg_lambda': 0.00011151995261572815}. Best is trial 31 with value: 0.9674418604651163.
# [I 2024-11-19 01:23:21,757] Trial 83 finished with value: 0.9488372093023256 and parameters: {'n_estimators': 100, 'max_depth': 8, 'learning_rate': 0.1069114457439359, 'subsample': 0.7676949910445345, 'colsample_bytree': 0.6565390086846106, 'min_child_weight': 2, 'gamma': 0.027367652699783016, 'reg_alpha': 1.48447356670921e-08, 'reg_lambda': 3.683155867414124e-05}. Best is trial 31 with value: 0.9674418604651163.
# [I 2024-11-19 01:23:27,111] Trial 84 finished with value: 0.9534883720930233 and parameters: {'n_estimators': 100, 'max_depth': 3, 'learning_rate': 0.18574719379570476, 'subsample': 0.7383855589219154, 'colsample_bytree': 0.6027671924584224, 'min_child_weight': 1, 'gamma': 0.01282577658338512, 'reg_alpha': 2.682629804459509e-06, 'reg_lambda': 1.937952591960724e-05}. Best is trial 31 with value: 0.9674418604651163.
# [I 2024-11-19 01:23:43,628] Trial 85 finished with value: 0.9627906976744186 and parameters: {'n_estimators': 500, 'max_depth': 8, 'learning_rate': 0.07656833914478638, 'subsample': 0.7277295110437227, 'colsample_bytree': 0.6957894518583482, 'min_child_weight': 2, 'gamma': 0.5734577943539285, 'reg_alpha': 3.237010539064035e-08, 'reg_lambda': 8.698453232340433e-05}. Best is trial 31 with value: 0.9674418604651163.
# [I 2024-11-19 01:23:54,700] Trial 86 finished with value: 0.9534883720930233 and parameters: {'n_estimators': 100, 'max_depth': 9, 'learning_rate': 0.11881285585127854, 'subsample': 0.6752174619886906, 'colsample_bytree': 0.7202725942936683, 'min_child_weight': 1, 'gamma': 0.04490579621013185, 'reg_alpha': 1.0750407923054928e-07, 'reg_lambda': 0.00037597625112867925}. Best is trial 31 with value: 0.9674418604651163.
# [I 2024-11-19 01:24:04,901] Trial 87 finished with value: 0.9441860465116279 and parameters: {'n_estimators': 300, 'max_depth': 7, 'learning_rate': 0.15143340305867717, 'subsample': 0.7975024842367296, 'colsample_bytree': 0.7506220691056322, 'min_child_weight': 6, 'gamma': 0.11189128406961407, 'reg_alpha': 5.138985793434307e-06, 'reg_lambda': 0.002309678783682227}. Best is trial 31 with value: 0.9674418604651163.
# [I 2024-11-19 01:24:11,868] Trial 88 finished with value: 0.9534883720930233 and parameters: {'n_estimators': 100, 'max_depth': 6, 'learning_rate': 0.21168041541090196, 'subsample': 0.6952136316588702, 'colsample_bytree': 0.8784587207946826, 'min_child_weight': 2, 'gamma': 4.879776382548007e-06, 'reg_alpha': 1.9019548777170168e-06, 'reg_lambda': 0.00017037527562301265}. Best is trial 31 with value: 0.9674418604651163.
# [I 2024-11-19 01:27:36,735] Trial 103 finished with value: 0.958139534883721 and parameters: {'n_estimators': 100, 'max_depth': 8, 'learning_rate': 0.10215429734400613, 'subsample': 0.6678692101447072, 'colsample_bytree': 0.7245598472057927, 'min_child_weight': 1, 'gamma': 5.539832367348246e-06, 'reg_alpha': 3.873205388781578e-08, 'reg_lambda': 2.043498774095309e-08}. Best is trial 31 with value: 0.9674418604651163.
# [I 2024-11-19 01:27:44,583] Trial 104 finished with value: 0.9534883720930233 and parameters: {'n_estimators': 100, 'max_depth': 8, 'learning_rate': 0.11069679646384556, 'subsample': 0.6902670509793887, 'colsample_bytree': 0.8087523046618125, 'min_child_weight': 7, 'gamma': 5.9696597161979404e-05, 'reg_alpha': 0.0001522154277247348, 'reg_lambda': 1.1218654372705968e-07}. Best is trial 31 with value: 0.9674418604651163.
# [I 2024-11-19 01:27:56,280] Trial 105 finished with value: 0.958139534883721 and parameters: {'n_estimators': 100, 'max_depth': 7, 'learning_rate': 0.08887813792130529, 'subsample': 0.7437171890792363, 'colsample_bytree': 0.8465065882089695, 'min_child_weight': 2, 'gamma': 3.5458376878855054e-05, 'reg_alpha': 9.358906809894032e-07, 'reg_lambda': 2.734870132948441e-07}. Best is trial 31 with value: 0.9674418604651163.
# [I 2024-11-19 01:28:11,553] Trial 106 finished with value: 0.9627906976744186 and parameters: {'n_estimators': 500, 'max_depth': 8, 'learning_rate': 0.17252131259313908, 'subsample': 0.6541097994409804, 'colsample_bytree': 0.7062387214864654, 'min_child_weight': 3, 'gamma': 0.00012177957352745941, 'reg_alpha': 1.8330164801648176e-08, 'reg_lambda': 0.00042790143631083805}. Best is trial 31 with value: 0.9674418604651163.
# [I 2024-11-19 01:28:20,258] Trial 107 finished with value: 0.9534883720930233 and parameters: {'n_estimators': 100, 'max_depth': 9, 'learning_rate': 0.13455759313911536, 'subsample': 0.600045182420153, 'colsample_bytree': 0.7646370561081858, 'min_child_weight': 1, 'gamma': 0.15252695932761556, 'reg_alpha': 6.904285149838517e-08, 'reg_lambda': 0.00011902337517975792}. Best is trial 31 with value: 0.9674418604651163.
# [I 2024-11-19 01:28:34,064] Trial 108 finished with value: 0.958139534883721 and parameters: {'n_estimators': 300, 'max_depth': 9, 'learning_rate': 0.09603396124581212, 'subsample': 0.6553259385091931, 'colsample_bytree': 0.7417744994127364, 'min_child_weight': 4, 'gamma': 0.09637960824563357, 'reg_alpha': 2.314879141928994e-07, 'reg_lambda': 1.0227013668395388e-08}. Best is trial 31 with value: 0.9674418604651163.
# [I 2024-11-19 01:28:48,062] Trial 109 finished with value: 0.9627906976744186 and parameters: {'n_estimators': 100, 'max_depth': 10, 'learning_rate': 0.07441142145590732, 'subsample': 0.6996337390258641, 'colsample_bytree': 0.7140673281005739, 'min_child_weight': 2, 'gamma': 2.0789939512998304e-05, 'reg_alpha': 4.5440613879334913e-07, 'reg_lambda': 1.5493771059687892e-05}. Best is trial 31 with value: 0.9674418604651163.
# [I 2024-11-19 01:28:58,659] Trial 110 finished with value: 0.958139534883721 and parameters: {'n_estimators': 100, 'max_depth': 8, 'learning_rate': 0.11905826546087914, 'subsample': 0.633962231448056, 'colsample_bytree': 0.8347476773417384, 'min_child_weight': 1, 'gamma': 1.1096687161044715e-06, 'reg_alpha': 2.7983776633033844e-08, 'reg_lambda': 5.646297474697351e-05}. Best is trial 31 with value: 0.9674418604651163.
# [I 2024-11-19 01:29:05,407] Trial 111 finished with value: 0.9534883720930233 and parameters: {'n_estimators': 100, 'max_depth': 8, 'learning_rate': 0.07938446626040083, 'subsample': 0.6632195825135346, 'colsample_bytree': 0.7887976655461867, 'min_child_weight': 1, 'gamma': 0.6196575265284618, 'reg_alpha': 1.1914633404991873e-08, 'reg_lambda': 0.00017041356846804885}. Best is trial 31 with value: 0.9674418604651163.
# [I 2024-11-19 01:29:11,518] Trial 112 finished with value: 0.9395348837209302 and parameters: {'n_estimators': 100, 'max_depth': 8, 'learning_rate': 0.10611520171485178, 'subsample': 0.6461660170785548, 'colsample_bytree': 0.7806749306000126, 'min_child_weight': 1, 'gamma': 0.744841032063227, 'reg_alpha': 1.73839117944303e-08, 'reg_lambda': 0.0006513923967893413}. Best is trial 31 with value: 0.9674418604651163.
# [I 2024-11-19 01:29:22,071] Trial 113 finished with value: 0.958139534883721 and parameters: {'n_estimators': 100, 'max_depth': 8, 'learning_rate': 0.05089892174020943, 'subsample': 0.6810613072506909, 'colsample_bytree': 0.806747895252806, 'min_child_weight': 1, 'gamma': 0.457750009819817, 'reg_alpha': 1.050935452745223e-08, 'reg_lambda': 8.659265988227658e-05}. Best is trial 31 with value: 0.9674418604651163.
# ...
# [I 2024-11-19 07:59:34,191] Trial 4964 finished with value: 0.958139534883721 and parameters: {'n_estimators': 400, 'max_depth': 9, 'learning_rate': 0.06441213050126274, 'subsample': 0.732119937438095, 'colsample_bytree': 0.6869128934123531, 'min_child_weight': 1, 'gamma': 0.0027356171158817023, 'reg_alpha': 8.219680903797146e-05, 'reg_lambda': 1.3738392562356594e-06}. Best is trial 261 with value: 0.9720930232558139.
# [I 2024-11-19 07:59:36,650] Trial 4965 finished with value: 0.9488372093023256 and parameters: {'n_estimators': 100, 'max_depth': 6, 'learning_rate': 0.07264588111165439, 'subsample': 0.7149749799272652, 'colsample_bytree': 0.6751947115536798, 'min_child_weight': 10, 'gamma': 0.0007948859260623128, 'reg_alpha': 6.96591225408194e-08, 'reg_lambda': 3.1218513505025256e-06}. Best is trial 261 with value: 0.9720930232558139.
# [I 2024-11-19 07:59:40,795] Trial 4966 finished with value: 0.9534883720930233 and parameters: {'n_estimators': 100, 'max_depth': 9, 'learning_rate': 0.059475947698096214, 'subsample': 0.7248417162528049, 'colsample_bytree': 0.7022286165445466, 'min_child_weight': 3, 'gamma': 0.00025178909173652564, 'reg_alpha': 3.520685330750145e-08, 'reg_lambda': 4.719593180089131e-05}. Best is trial 261 with value: 0.9720930232558139.
# [I 2024-11-19 08:00:53,526] Trial 4982 finished with value: 0.958139534883721 and parameters: {'n_estimators': 100, 'max_depth': 9, 'learning_rate': 0.017311257715780203, 'subsample': 0.7328889796358163, 'colsample_bytree': 0.6738948806798156, 'min_child_weight': 1, 'gamma': 0.0011311973302388417, 'reg_alpha': 8.116398637286748e-05, 'reg_lambda': 4.415387522156974e-07}. Best is trial 261 with value: 0.9720930232558139.
# [I 2024-11-19 08:00:58,145] Trial 4983 finished with value: 0.958139534883721 and parameters: {'n_estimators': 200, 'max_depth': 6, 'learning_rate': 0.08931871026289347, 'subsample': 0.6994672386419152, 'colsample_bytree': 0.654188689834042, 'min_child_weight': 2, 'gamma': 0.00034580523666498804, 'reg_alpha': 0.5879236454064687, 'reg_lambda': 2.634252378201123e-05}. Best is trial 261 with value: 0.9720930232558139.
# [I 2024-11-19 08:01:03,073] Trial 4984 finished with value: 0.9627906976744186 and parameters: {'n_estimators': 100, 'max_depth': 9, 'learning_rate': 0.05770499609466594, 'subsample': 0.7189768564284266, 'colsample_bytree': 0.6805834193293127, 'min_child_weight': 1, 'gamma': 0.0018040303885297636, 'reg_alpha': 6.57490138009239e-08, 'reg_lambda': 1.3455723428982256e-06}. Best is trial 261 with value: 0.9720930232558139.
# [I 2024-11-19 08:01:04,936] Trial 4985 finished with value: 0.9534883720930233 and parameters: {'n_estimators': 100, 'max_depth': 3, 'learning_rate': 0.07116385805743039, 'subsample': 0.7438004513749544, 'colsample_bytree': 0.6950671578389188, 'min_child_weight': 2, 'gamma': 0.00018017131596196852, 'reg_alpha': 3.6847510773349064e-08, 'reg_lambda': 7.955417122430503e-07}. Best is trial 261 with value: 0.9720930232558139.
# [I 2024-11-19 08:01:08,412] Trial 4986 finished with value: 0.9627906976744186 and parameters: {'n_estimators': 100, 'max_depth': 6, 'learning_rate': 0.06157968291464457, 'subsample': 0.7101153077476746, 'colsample_bytree': 0.7433113453861203, 'min_child_weight': 2, 'gamma': 0.0007624503136587462, 'reg_alpha': 1.390424994388428e-05, 'reg_lambda': 1.8245964652976876e-07}. Best is trial 261 with value: 0.9720930232558139.
# [I 2024-11-19 08:01:14,955] Trial 4987 finished with value: 0.958139534883721 and parameters: {'n_estimators': 400, 'max_depth': 9, 'learning_rate': 0.06632184391843612, 'subsample': 0.7279100214827204, 'colsample_bytree': 0.7258538267225826, 'min_child_weight': 3, 'gamma': 0.006028474887371344, 'reg_alpha': 0.00012074775983924613, 'reg_lambda': 0.01776525196918858}. Best is trial 261 with value: 0.9720930232558139.
# [I 2024-11-19 08:01:19,000] Trial 4988 finished with value: 0.9674418604651163 and parameters: {'n_estimators': 100, 'max_depth': 9, 'learning_rate': 0.08112001144141329, 'subsample': 0.7356101824580429, 'colsample_bytree': 0.7040183339783737, 'min_child_weight': 1, 'gamma': 0.0036028803568882123, 'reg_alpha': 1.482685740507618e-07, 'reg_lambda': 2.7534217909723797e-06}. Best is trial 261 with value: 0.9720930232558139.
# [I 2024-11-19 08:01:57,795] Trial 4996 finished with value: 0.9674418604651163 and parameters: {'n_estimators': 100, 'max_depth': 6, 'learning_rate': 0.06739143004458284, 'subsample': 0.9286577463891164, 'colsample_bytree': 0.6884693196548234, 'min_child_weight': 2, 'gamma': 4.193885575342638e-05, 'reg_alpha': 8.068143704613971e-08, 'reg_lambda': 4.879319729904504e-07}. Best is trial 261 with value: 0.9720930232558139.
# [I 2024-11-19 08:02:01,376] Trial 4997 finished with value: 0.958139534883721 and parameters: {'n_estimators': 100, 'max_depth': 9, 'learning_rate': 0.08857361791835039, 'subsample': 0.7318247674815908, 'colsample_bytree': 0.658790099182649, 'min_child_weight': 1, 'gamma': 0.0043145249075673235, 'reg_alpha': 0.0003591286554944305, 'reg_lambda': 0.0008225215322355336}. Best is trial 261 with value: 0.9720930232558139.
# [I 2024-11-19 08:02:04,890] Trial 4998 finished with value: 0.958139534883721 and parameters: {'n_estimators': 100, 'max_depth': 6, 'learning_rate': 0.06096557500277445, 'subsample': 0.7513505929283436, 'colsample_bytree': 0.6794261546237469, 'min_child_weight': 2, 'gamma': 0.0009111906221655154, 'reg_alpha': 6.216114417195752e-05, 'reg_lambda': 9.636261181461984e-07}. Best is trial 261 with value: 0.9720930232558139.
# [I 2024-11-19 08:02:11,471] Trial 4999 finished with value: 0.958139534883721 and parameters: {'n_estimators': 400, 'max_depth': 9, 'learning_rate': 0.056063517657616586, 'subsample': 0.7166492609800849, 'colsample_bytree': 0.7060955866791684, 'min_child_weight': 3, 'gamma': 0.0073928164358758285, 'reg_alpha': 5.952853969765662e-08, 'reg_lambda': 0.0795877578042916}. Best is trial 261 with value: 0.9720930232558139.
# Best trial: {'n_estimators': 100, 'max_depth': 8, 'learning_rate': 0.06620846583232173, 'subsample': 0.7123388083841681, 'colsample_bytree': 0.804951267439598, 'min_child_weight': 1, 'gamma': 0.0001037579469140485, 'reg_alpha': 2.590054955814063e-06, 'reg_lambda': 1.6044054957732977e-07}
# Optuna Tuned XGBoost Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.93      1.00      0.96        74
#            1       1.00      0.68      0.81        19
#            2       1.00      1.00      1.00       122
#
#     accuracy                           0.97       215
#    macro avg       0.97      0.89      0.92       215
# weighted avg       0.97      0.97      0.97       215
#
# Confusion Matrix:
# [[ 74   0   0]
#  [  6  13   0]
#  [  0   0 122]]

# %%
import optuna
from sklearn import svm
from sklearn.metrics import accuracy_score
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

# Split the data into train and test sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=2)

# Standardize the features (important for SVM)
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# Define the Optuna optimization objective function
def objective(trial):
    # Define the search space for each parameter
    C = trial.suggest_float('C', 1e-3, 1e3, log=True)
    kernel = trial.suggest_categorical('kernel', ['linear', 'poly', 'rbf', 'sigmoid'])
    
    if kernel in ['poly', 'rbf', 'sigmoid']:
        gamma = trial.suggest_float('gamma', 1e-4, 1e1, log=True)
    else:
        gamma = 'scale'  # 'scale' is recommended for linear kernels

    # Only use degree parameter if kernel is 'poly'
    if kernel == 'poly':
        degree = trial.suggest_int('degree', 2, 5)
    else:
        degree = 3  # Default value for non-poly kernels

    # Create and train the SVM model
    model = svm.SVC(C=C, kernel=kernel, gamma=gamma, degree=degree)
    model.fit(X_train_scaled, y_train)
    
    # Predict on the test set and calculate accuracy
    y_pred = model.predict(X_test_scaled)
    accuracy = accuracy_score(y_test, y_pred)
    return accuracy

# Create an Optuna study and optimize the objective function
study = optuna.create_study(direction='maximize')
study.optimize(objective, n_trials=50)  # Increase `n_trials` for a more thorough search

# Display the best parameters and accuracy
print("Best parameters:", study.best_params)
print("Best accuracy:", study.best_value)

# Train and evaluate an SVM model with the best parameters found
best_params = study.best_params
best_svm = svm.SVC(**best_params)
best_svm.fit(X_train_scaled, y_train)
y_pred_best = best_svm.predict(X_test_scaled)
best_accuracy = accuracy_score(y_test, y_pred_best)

print(f"Optimized SVM accuracy: {best_accuracy * 100:.2f}%")
# Out:
# [I 2024-11-19 08:02:16,468] A new study created in memory with name: no-name-648e07e5-947d-4f7c-8575-34883aa7dc29
# [I 2024-11-19 08:02:16,579] Trial 0 finished with value: 0.9348837209302325 and parameters: {'C': 871.842909349291, 'kernel': 'rbf', 'gamma': 0.00032788952131207347}. Best is trial 0 with value: 0.9348837209302325.
# [I 2024-11-19 08:02:16,740] Trial 1 finished with value: 0.627906976744186 and parameters: {'C': 0.014111870542620237, 'kernel': 'sigmoid', 'gamma': 0.1792787701648837}. Best is trial 0 with value: 0.9348837209302325.
# [I 2024-11-19 08:02:16,827] Trial 2 finished with value: 0.8883720930232558 and parameters: {'C': 0.9816802068941439, 'kernel': 'linear'}. Best is trial 0 with value: 0.9348837209302325.
# [I 2024-11-19 08:02:16,942] Trial 3 finished with value: 0.9255813953488372 and parameters: {'C': 879.3950193687654, 'kernel': 'poly', 'gamma': 1.4103954478525975, 'degree': 3}. Best is trial 0 with value: 0.9348837209302325.
# [I 2024-11-19 08:02:17,058] Trial 4 finished with value: 0.5255813953488372 and parameters: {'C': 1.3901883449864973, 'kernel': 'sigmoid', 'gamma': 0.47732656877169327}. Best is trial 0 with value: 0.9348837209302325.
# [I 2024-11-19 08:02:17,220] Trial 5 finished with value: 0.8232558139534883 and parameters: {'C': 75.29769082969419, 'kernel': 'poly', 'gamma': 0.0024730095727222966, 'degree': 4}. Best is trial 0 with value: 0.9348837209302325.
# [I 2024-11-19 08:02:17,503] Trial 6 finished with value: 0.5906976744186047 and parameters: {'C': 0.6077072574358451, 'kernel': 'rbf', 'gamma': 0.03360176761115128}. Best is trial 0 with value: 0.9348837209302325.
# [I 2024-11-19 08:02:17,603] Trial 7 finished with value: 0.49767441860465117 and parameters: {'C': 5.392627532977194, 'kernel': 'sigmoid', 'gamma': 0.018314160634499775}. Best is trial 0 with value: 0.9348837209302325.
# [I 2024-11-19 08:02:17,682] Trial 8 finished with value: 0.8883720930232558 and parameters: {'C': 8.477637530586941, 'kernel': 'linear'}. Best is trial 0 with value: 0.9348837209302325.
# [I 2024-11-19 08:02:17,763] Trial 9 finished with value: 0.8883720930232558 and parameters: {'C': 10.144905703605342, 'kernel': 'sigmoid', 'gamma': 0.0004551862957939644}. Best is trial 0 with value: 0.9348837209302325.
# [I 2024-11-19 08:02:17,969] Trial 10 finished with value: 0.5674418604651162 and parameters: {'C': 0.0018559013264256013, 'kernel': 'rbf', 'gamma': 0.00013790174047715044}. Best is trial 0 with value: 0.9348837209302325.
# [I 2024-11-19 08:02:18,089] Trial 11 finished with value: 0.8930232558139535 and parameters: {'C': 626.5761191920353, 'kernel': 'poly', 'gamma': 8.090909112557798, 'degree': 2}. Best is trial 0 with value: 0.9348837209302325.
# [I 2024-11-19 08:02:18,206] Trial 12 finished with value: 0.9255813953488372 and parameters: {'C': 989.1186226784032, 'kernel': 'poly', 'gamma': 9.475914146488337, 'degree': 3}. Best is trial 0 with value: 0.9348837209302325.
# [I 2024-11-19 08:02:18,501] Trial 13 finished with value: 0.6 and parameters: {'C': 117.78548898214048, 'kernel': 'rbf', 'gamma': 0.9628955168578236}. Best is trial 0 with value: 0.9348837209302325.
# [I 2024-11-19 08:02:18,648] Trial 14 finished with value: 0.8465116279069768 and parameters: {'C': 147.48415638251478, 'kernel': 'poly', 'gamma': 0.003432893499495002, 'degree': 5}. Best is trial 0 with value: 0.9348837209302325.
# [I 2024-11-19 08:02:18,906] Trial 15 finished with value: 0.5674418604651162 and parameters: {'C': 0.10214717309172755, 'kernel': 'rbf', 'gamma': 0.055025281487919006}. Best is trial 0 with value: 0.9348837209302325.
# [I 2024-11-19 08:02:19,063] Trial 16 finished with value: 0.9488372093023256 and parameters: {'C': 28.44156641197973, 'kernel': 'rbf', 'gamma': 0.003205026129056433}. Best is trial 16 with value: 0.9488372093023256.
# [I 2024-11-19 08:02:19,184] Trial 17 finished with value: 0.9395348837209302 and parameters: {'C': 40.22291590211146, 'kernel': 'rbf', 'gamma': 0.0014948698882626126}. Best is trial 16 with value: 0.9488372093023256.
# [I 2024-11-19 08:02:19,392] Trial 18 finished with value: 0.9534883720930233 and parameters: {'C': 28.46648353302724, 'kernel': 'rbf', 'gamma': 0.00409465514872289}. Best is trial 18 with value: 0.9534883720930233.
# [I 2024-11-19 08:02:19,652] Trial 19 finished with value: 0.7255813953488373 and parameters: {'C': 0.1342143594266943, 'kernel': 'rbf', 'gamma': 0.009265000514280518}. Best is trial 18 with value: 0.9534883720930233.
# [I 2024-11-19 08:02:19,895] Trial 20 finished with value: 0.9395348837209302 and parameters: {'C': 17.839485610524576, 'kernel': 'rbf', 'gamma': 0.007551915086175382}. Best is trial 18 with value: 0.9534883720930233.
# [I 2024-11-19 08:02:20,017] Trial 21 finished with value: 0.9395348837209302 and parameters: {'C': 50.19082785447529, 'kernel': 'rbf', 'gamma': 0.0015001576902951277}. Best is trial 18 with value: 0.9534883720930233.
# [I 2024-11-19 08:02:20,124] Trial 22 finished with value: 0.9348837209302325 and parameters: {'C': 28.506880959749324, 'kernel': 'rbf', 'gamma': 0.001055369954698058}. Best is trial 18 with value: 0.9534883720930233.
# [I 2024-11-19 08:02:20,356] Trial 23 finished with value: 0.9302325581395349 and parameters: {'C': 168.30293183143436, 'kernel': 'rbf', 'gamma': 0.006483821447024555}. Best is trial 18 with value: 0.9534883720930233.
# [I 2024-11-19 08:02:20,434] Trial 24 finished with value: 0.8883720930232558 and parameters: {'C': 2.8464077905744674, 'kernel': 'linear'}. Best is trial 18 with value: 0.9534883720930233.
# [I 2024-11-19 08:02:20,541] Trial 25 finished with value: 0.9395348837209302 and parameters: {'C': 29.70539342596742, 'kernel': 'rbf', 'gamma': 0.0008417686116844426}. Best is trial 18 with value: 0.9534883720930233.
# [I 2024-11-19 08:02:20,635] Trial 26 finished with value: 0.9302325581395349 and parameters: {'C': 284.047069748473, 'kernel': 'rbf', 'gamma': 0.00013397390245600813}. Best is trial 18 with value: 0.9534883720930233.
# [I 2024-11-19 08:02:20,898] Trial 27 finished with value: 0.5674418604651162 and parameters: {'C': 0.29240930713029667, 'kernel': 'rbf', 'gamma': 0.11034363155107867}. Best is trial 18 with value: 0.9534883720930233.
# [I 2024-11-19 08:02:21,058] Trial 28 finished with value: 0.9488372093023256 and parameters: {'C': 2.797966689463427, 'kernel': 'rbf', 'gamma': 0.0032028832639371986}. Best is trial 18 with value: 0.9534883720930233.
# [I 2024-11-19 08:02:21,422] Trial 29 finished with value: 0.8837209302325582 and parameters: {'C': 4.102702175033701, 'kernel': 'rbf', 'gamma': 0.015540762078190632}. Best is trial 18 with value: 0.9534883720930233.
# [I 2024-11-19 08:02:21,478] Trial 30 finished with value: 0.8883720930232558 and parameters: {'C': 2.225493142022233, 'kernel': 'linear'}. Best is trial 18 with value: 0.9534883720930233.
# [I 2024-11-19 08:02:21,673] Trial 31 finished with value: 0.9534883720930233 and parameters: {'C': 16.246633107903044, 'kernel': 'rbf', 'gamma': 0.003829613060691903}. Best is trial 18 with value: 0.9534883720930233.
# [I 2024-11-19 08:02:21,864] Trial 32 finished with value: 0.9534883720930233 and parameters: {'C': 10.073713921609457, 'kernel': 'rbf', 'gamma': 0.0034849777506478483}. Best is trial 18 with value: 0.9534883720930233.
# [I 2024-11-19 08:02:22,086] Trial 33 finished with value: 0.9302325581395349 and parameters: {'C': 15.141064029855333, 'kernel': 'rbf', 'gamma': 0.0048525245846648205}. Best is trial 18 with value: 0.9534883720930233.
# [I 2024-11-19 08:02:22,188] Trial 34 finished with value: 0.9302325581395349 and parameters: {'C': 9.289556049051736, 'kernel': 'rbf', 'gamma': 0.00036099544935468245}. Best is trial 18 with value: 0.9534883720930233.
# [I 2024-11-19 08:02:22,253] Trial 35 finished with value: 0.8 and parameters: {'C': 65.05439518085521, 'kernel': 'sigmoid', 'gamma': 0.0006496781100962903}. Best is trial 18 with value: 0.9534883720930233.
# [I 2024-11-19 08:02:22,525] Trial 36 finished with value: 0.8697674418604651 and parameters: {'C': 1.258349887761559, 'kernel': 'rbf', 'gamma': 0.017254698804805374}. Best is trial 18 with value: 0.9534883720930233.
# [I 2024-11-19 08:02:22,605] Trial 37 finished with value: 0.8883720930232558 and parameters: {'C': 261.80541763868155, 'kernel': 'linear'}. Best is trial 18 with value: 0.9534883720930233.
# [I 2024-11-19 08:02:22,740] Trial 38 finished with value: 0.9069767441860465 and parameters: {'C': 0.5191617478336039, 'kernel': 'rbf', 'gamma': 0.001926445820848473}. Best is trial 18 with value: 0.9534883720930233.
# [I 2024-11-19 08:02:22,851] Trial 39 finished with value: 0.4790697674418605 and parameters: {'C': 24.91475290165972, 'kernel': 'sigmoid', 'gamma': 0.046212440731209364}. Best is trial 18 with value: 0.9534883720930233.
# [I 2024-11-19 08:02:23,097] Trial 40 finished with value: 0.9162790697674419 and parameters: {'C': 6.289461267201848, 'kernel': 'rbf', 'gamma': 0.011092123925362525}. Best is trial 18 with value: 0.9534883720930233.
# [I 2024-11-19 08:02:23,253] Trial 41 finished with value: 0.9488372093023256 and parameters: {'C': 2.829121994723093, 'kernel': 'rbf', 'gamma': 0.0032134448029104853}. Best is trial 18 with value: 0.9534883720930233.
# [I 2024-11-19 08:02:23,465] Trial 42 finished with value: 0.9534883720930233 and parameters: {'C': 77.43638446751424, 'kernel': 'rbf', 'gamma': 0.004123192503138866}. Best is trial 18 with value: 0.9534883720930233.
# [I 2024-11-19 08:02:23,689] Trial 43 finished with value: 0.9302325581395349 and parameters: {'C': 86.76744222590307, 'kernel': 'rbf', 'gamma': 0.005058765149314433}. Best is trial 18 with value: 0.9534883720930233.
# [I 2024-11-19 08:02:23,946] Trial 44 finished with value: 0.8186046511627907 and parameters: {'C': 346.8386245887138, 'kernel': 'rbf', 'gamma': 0.02265524889058065}. Best is trial 18 with value: 0.9534883720930233.
# [I 2024-11-19 08:02:24,093] Trial 45 finished with value: 0.8372093023255814 and parameters: {'C': 11.903749356652984, 'kernel': 'poly', 'gamma': 0.0015644001958242662, 'degree': 5}. Best is trial 18 with value: 0.9534883720930233.
# [I 2024-11-19 08:02:24,201] Trial 46 finished with value: 0.4790697674418605 and parameters: {'C': 60.47359828467314, 'kernel': 'sigmoid', 'gamma': 0.08289812434136977}. Best is trial 18 with value: 0.9534883720930233.
# [I 2024-11-19 08:02:24,397] Trial 47 finished with value: 0.5674418604651162 and parameters: {'C': 0.006902504648567369, 'kernel': 'rbf', 'gamma': 0.0005794190343711471}. Best is trial 18 with value: 0.9534883720930233.
# [I 2024-11-19 08:02:24,480] Trial 48 finished with value: 0.8883720930232558 and parameters: {'C': 18.50786342524504, 'kernel': 'linear'}. Best is trial 18 with value: 0.9534883720930233.
# [I 2024-11-19 08:02:24,631] Trial 49 finished with value: 0.7302325581395349 and parameters: {'C': 6.058355958648488, 'kernel': 'poly', 'gamma': 0.00024094187090885273, 'degree': 2}. Best is trial 18 with value: 0.9534883720930233.
# Best parameters: {'C': 28.46648353302724, 'kernel': 'rbf', 'gamma': 0.00409465514872289}
# Best accuracy: 0.9534883720930233
# Optimized SVM accuracy: 95.35%

# %%
best_knn_params= {'n_neighbors': 6, 'metric': 'manhattan', 'weights': 'distance', 'p': 2}

import optuna
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score
from sklearn.preprocessing import StandardScaler

    # Create the KNN model with the hyperparameters
model = KNeighborsClassifier(**best_knn_params)

# Train the model
model.fit(X_train, y_train)

# Predict on the test set
y_pred = model.predict(X_test)

# Evaluate the accuracy
accuracy = accuracy_score(y_test, y_pred)
print("Accuracy:",accuracy)  # Return the accuracy as the objective to maximize

print("Classification Report:")
print(classification_report(y_test, y_pred))
print("Confusion Matrix:")
print(confusion_matrix(y_test, y_pred))
# Out:
# Accuracy: 0.9767441860465116
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.97      0.96      0.97        74
#            1       0.85      0.89      0.87        19
#            2       1.00      1.00      1.00       122
#
#     accuracy                           0.98       215
#    macro avg       0.94      0.95      0.95       215
# weighted avg       0.98      0.98      0.98       215
#
# Confusion Matrix:
# [[ 71   3   0]
#  [  2  17   0]
#  [  0   0 122]]

# %%
import os
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report, confusion_matrix
import pickle
import xgboost as xgb

best_xgb_params={'n_estimators': 100, 'max_depth': 8, 'learning_rate': 0.06620846583232173, 'subsample': 0.7123388083841681, 'colsample_bytree': 0.804951267439598, 'min_child_weight': 1, 'gamma': 0.0001037579469140485, 'reg_alpha': 2.590054955814063e-06, 'reg_lambda': 1.6044054957732977e-07,'random_state':18}
best_model = xgb.XGBClassifier(**best_xgb_params)
best_model.fit(X_train, y_train)

# Predict and evaluate the final model
y_pred = best_model.predict(X_test)
print("Optuna Tuned XGBoost Classification Report:")

accuracy = accuracy_score(y_test, y_pred)
print("Accuracy:",accuracy)  # Return the accuracy as the objective to maximize

print(classification_report(y_test, y_pred))
print("Confusion Matrix:")
print(confusion_matrix(y_test, y_pred))
# Out:
# Optuna Tuned XGBoost Classification Report:
# Accuracy: 0.9720930232558139
#               precision    recall  f1-score   support
#
#            0       0.93      1.00      0.96        74
#            1       1.00      0.68      0.81        19
#            2       1.00      1.00      1.00       122
#
#     accuracy                           0.97       215
#    macro avg       0.97      0.89      0.92       215
# weighted avg       0.97      0.97      0.97       215
#
# Confusion Matrix:
# [[ 74   0   0]
#  [  6  13   0]
#  [  0   0 122]]

# %%
best_svm_params= {'C': 28.46648353302724, 'kernel': 'rbf', 'gamma': 0.00409465514872289}

import optuna
from sklearn import svm
from sklearn.metrics import accuracy_score
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

model = svm.SVC(**best_svm_params)
model.fit(X_train, y_train)

# Predict on the test set and calculate accuracy
y_pred = model.predict(X_test)
accuracy = accuracy_score(y_test, y_pred)

accuracy = accuracy_score(y_test, y_pred)
print("Accuracy:",accuracy)  # Return the accuracy as the objective to maximize

print("Classification Report:")
print(classification_report(y_test, y_pred))
print("Confusion Matrix:")
print(confusion_matrix(y_test, y_pred))
# Out:
# Accuracy: 0.9534883720930233
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.91      0.96      0.93        74
#            1       0.86      0.63      0.73        19
#            2       0.99      1.00      1.00       122
#
#     accuracy                           0.95       215
#    macro avg       0.92      0.86      0.89       215
# weighted avg       0.95      0.95      0.95       215
#
# Confusion Matrix:
# [[ 71   2   1]
#  [  7  12   0]
#  [  0   0 122]]

# %%
from sklearn.ensemble import RandomForestClassifier

best_rf_params={'n_estimators': 58, 'max_depth': 18, 'min_samples_split': 7, 'min_samples_leaf': 1, 'max_features': 0.15677692182949887, 'bootstrap': False, 'criterion': 'log_loss','random_state':2}
rf_model = RandomForestClassifier(**best_rf_params)
# Train the model
rf_model.fit(X_train, y_train)

# Test the model
y_pred_rf = rf_model.predict(X_test)

accuracy = accuracy_score(y_test, y_pred_rf)
print("Accuracy:",accuracy)

print("Random Forest Classification Report:")
print(classification_report(y_test, y_pred_rf))
print("Confusion Matrix:")
print(confusion_matrix(y_test, y_pred_rf))
# Out:
# Accuracy: 0.9627906976744186
# Random Forest Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.91      0.99      0.95        74
#            1       0.92      0.63      0.75        19
#            2       1.00      1.00      1.00       122
#
#     accuracy                           0.96       215
#    macro avg       0.95      0.87      0.90       215
# weighted avg       0.96      0.96      0.96       215
#
# Confusion Matrix:
# [[ 73   1   0]
#  [  7  12   0]
#  [  0   0 122]]

# %%
# from sklearn.ensemble import RandomForestClassifier
# from sklearn.svm import SVC
# from sklearn.neighbors import KNeighborsClassifier
# from sklearn.naive_bayes import GaussianNB
# from sklearn.metrics import accuracy_score
# from xgboost import XGBClassifier

# # Define the range of random states to test
# random_states = range(0, 50)  # Adjust this range as needed

# # Define the models with initial parameters
# models = {
#     'Random Forest': RandomForestClassifier(**best_rf_params,n_jobs=-1),
#     'XGBoost': XGBClassifier(**best_xgb_params,n_jobs=-1),  # Assuming best_params are defined
#     'SVM': SVC(**best_svm_params),
#     'KNN': KNeighborsClassifier(**best_knn_params),
# }

# # Dictionary to store the best random state and accuracy for each model
# best_results = {}

# # Iterate through each model
# for model_name, model in models.items():
#     print(f"\nEvaluating {model_name}...")
    
#     best_accuracy = 0
#     best_random_state = None
#     accuracy_dict = {}
    
#     # Iterate through each random state
#     for state in random_states:
#         # Check if the model has a random_state parameter
#         if 'random_state' in model.get_params():
#             model.set_params(random_state=state)

#         # Train the model
#         model.fit(X_train, y_train)
        
#         # Predict on the test set
#         y_pred = model.predict(X_test)
        
#         # Calculate accuracy
#         accuracy = accuracy_score(y_test, y_pred)
#         accuracy_dict[state] = accuracy
        
#         # Update best accuracy and random state if needed
#         if accuracy > best_accuracy:
#             best_accuracy = accuracy
#             best_random_state = state
        
#         # Print accuracy for the current random state
#         print(f"Random State {state}: Accuracy = {accuracy:.2%}")

#     # Store the best random state and accuracy for the current model
#     best_results[model_name] = {
#         'Best Random State': best_random_state,
#         'Best Accuracy': best_accuracy,
#         'All Accuracies': accuracy_dict
#     }

#     # Print the best random state and accuracy for the current model
#     print(f"\nBest Random State for {model_name}: {best_random_state}")
#     print(f"Best Accuracy for {model_name}: {best_accuracy:.2%}")

# # Print summary of best results for all models
# print("\nSummary of Best Results:")
# for model_name, results in best_results.items():
#     print(f"{model_name}: Best Random State = {results['Best Random State']}, Best Accuracy = {results['Best Accuracy']:.2%}")

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from xgboost import XGBClassifier
from sklearn.metrics import precision_score, recall_score, f1_score, accuracy_score, roc_auc_score, average_precision_score
from sklearn.preprocessing import label_binarize

# Assuming best parameters are already defined:
# best_xgb_params, best_rf_params, best_knn_params, best_svm_params

# Define the models with best parameters
models = {
    "XGBoost": XGBClassifier(**best_xgb_params),
    "Random Forest": RandomForestClassifier(**best_rf_params),
    "KNN": KNeighborsClassifier(**best_knn_params),
    "SVM": SVC(probability=True, **best_svm_params)  # Using probability=True for ROC/PR-AUC
}

# Binarize the true labels for PR-AUC and ROC-AUC calculations (required for multiclass)
y_test_binarized = label_binarize(y_test, classes=np.unique(y_test))

# Dictionary to store metrics for each model
metrics = {}

# Evaluate each model
for model_name, model in models.items():
    # Train the model
    model.fit(X_train, y_train)
    
    # Predict classes
    y_pred = model.predict(X_test)
    
    # Predict probabilities for AUC metrics
    if hasattr(model, "predict_proba"):
        y_pred_proba = model.predict_proba(X_test)
    else:  # For models like SVM without `predict_proba`, use decision_function
        y_pred_proba = model.decision_function(X_test)
    
    # Calculate metrics
    precision = precision_score(y_test, y_pred, average='weighted')
    recall = recall_score(y_test, y_pred, average='weighted')
    f1 = f1_score(y_test, y_pred, average='weighted')
    accuracy = accuracy_score(y_test, y_pred)
    
    # Calculate PR-AUC and ROC-AUC
    pr_auc = average_precision_score(y_test_binarized, y_pred_proba, average="macro")
    roc_auc = roc_auc_score(y_test_binarized, y_pred_proba, multi_class="ovr", average="macro")
    
    # Store metrics for the current model
    metrics[model_name] = {
        "Precision": precision,
        "Recall": recall,
        "F1-Score": f1,
        "Accuracy": accuracy,
        "PR-AUC": pr_auc,
        "ROC-AUC": roc_auc
    }

# Print metrics for each model
for model_name, metric_values in metrics.items():
    print(f"\nMetrics for {model_name}:")
    for metric_name, value in metric_values.items():
        print(f"  {metric_name}: {value:.2%}")
# Out:
# Metrics for XGBoost:
#   Precision: 97.42%
#   Recall: 97.21%
#   F1-Score: 97.00%
#   Accuracy: 97.21%
#   PR-AUC: 95.28%
#   ROC-AUC: 99.09%
#
# Metrics for Random Forest:
#   Precision: 96.31%
#   Recall: 96.28%
#   F1-Score: 96.00%
#   Accuracy: 96.28%
#   PR-AUC: 96.32%
#   ROC-AUC: 99.43%
#
# Metrics for KNN:
#   Precision: 97.73%
#   Recall: 97.67%
#   F1-Score: 97.70%
#   Accuracy: 97.67%
#   PR-AUC: 97.32%
#   ROC-AUC: 99.52%
#
# Metrics for SVM:
#   Precision: 95.19%
#   Recall: 95.35%
#   F1-Score: 95.09%
#   Accuracy: 95.35%
#   PR-AUC: 93.99%
#   ROC-AUC: 98.78%

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from xgboost import XGBClassifier
from sklearn.metrics import precision_score, recall_score, f1_score, accuracy_score, roc_auc_score, average_precision_score
from sklearn.preprocessing import label_binarize

# Assuming best parameters are already defined:
# best_xgb_params, best_rf_params, best_knn_params, best_svm_params

# Define the models with best parameters
models = {
    "XGBoost": XGBClassifier(**best_xgb_params),
    "Random Forest": RandomForestClassifier(**best_rf_params),
    "KNN": KNeighborsClassifier(**best_knn_params),
    "SVM": SVC(probability=True, **best_svm_params)  # Using probability=True for ROC/PR-AUC
}

# Binarize the true labels for PR-AUC and ROC-AUC calculations (required for multiclass)
y_test_binarized = label_binarize(y_test, classes=np.unique(y_test))

# Dictionary to store metrics for each model
metrics = {}

# Evaluate each model
for model_name, model in models.items():
    # Train the model
    model.fit(X_train, y_train)
    
    # Predict classes
    y_pred = model.predict(X_test)
    
    # Predict probabilities for AUC metrics
    if hasattr(model, "predict_proba"):
        y_pred_proba = model.predict_proba(X_test)
    else:  # For models like SVM without `predict_proba`, use decision_function
        y_pred_proba = model.decision_function(X_test)
    
    # Calculate metrics
    precision = precision_score(y_test, y_pred, average='weighted')
    recall = recall_score(y_test, y_pred, average='weighted')
    f1 = f1_score(y_test, y_pred, average='weighted')
    accuracy = accuracy_score(y_test, y_pred)
    
    # Calculate PR-AUC and ROC-AUC
    pr_auc = average_precision_score(y_test_binarized, y_pred_proba, average="macro")
    roc_auc = roc_auc_score(y_test_binarized, y_pred_proba, multi_class="ovr", average="macro")
    
    # Store metrics for the current model
    metrics[model_name] = {
        "Precision": precision,
        "Recall": recall,
        "F1-Score": f1,
        "Accuracy": accuracy,
        "PR-AUC": pr_auc,
        "ROC-AUC": roc_auc
    }

# Print metrics for each model
for model_name, metric_values in metrics.items():
    print(f"\nMetrics for {model_name}:")
    for metric_name, value in metric_values.items():
        print(f"  {metric_name}: {value:.2%}")
# Out:
# Metrics for XGBoost:
#   Precision: 97.42%
#   Recall: 97.21%
#   F1-Score: 97.00%
#   Accuracy: 97.21%
#   PR-AUC: 95.28%
#   ROC-AUC: 99.09%
#
# Metrics for Random Forest:
#   Precision: 96.31%
#   Recall: 96.28%
#   F1-Score: 96.00%
#   Accuracy: 96.28%
#   PR-AUC: 96.32%
#   ROC-AUC: 99.43%
#
# Metrics for KNN:
#   Precision: 97.73%
#   Recall: 97.67%
#   F1-Score: 97.70%
#   Accuracy: 97.67%
#   PR-AUC: 97.32%
#   ROC-AUC: 99.52%
#
# Metrics for SVM:
#   Precision: 95.19%
#   Recall: 95.35%
#   F1-Score: 95.09%
#   Accuracy: 95.35%
#   PR-AUC: 94.01%
#   ROC-AUC: 98.79%

# %%
import matplotlib.pyplot as plt
from sklearn.metrics import precision_recall_curve, average_precision_score
from sklearn.preprocessing import label_binarize

# Assuming the models are defined and trained: models dictionary from the previous step
# Also assuming y_test and y_test_binarized are defined

# Plot PR-AUC for each model
for model_name, model in models.items():
    print(f"Generating PR-AUC curves for {model_name}...")
    
    # Predict probabilities or decision function
    if hasattr(model, "predict_proba"):
        y_pred_proba = model.predict_proba(X_test)
    else:
        y_pred_proba = model.decision_function(X_test)
    
    plt.figure(figsize=(10, 7))
    
    # Generate Precision-Recall curves for each class
    for i, class_name in enumerate(classes):
        precision, recall, _ = precision_recall_curve(y_test_binarized[:, i], y_pred_proba[:, i])
        pr_auc = average_precision_score(y_test_binarized[:, i], y_pred_proba[:, i])
        plt.plot(recall, precision, label=f"{class_name} (PR-AUC: {pr_auc:.2f})")
    
    # Plot settings
    plt.title(f"Precision-Recall Curve for {model_name}")
    plt.xlabel("Recall")
    plt.ylabel("Precision")
    plt.legend(loc="lower left")
    plt.grid()
    plt.show()
# Out:
# Generating PR-AUC curves for XGBoost...
# Generating PR-AUC curves for Random Forest...
# Generating PR-AUC curves for KNN...
# Generating PR-AUC curves for SVM...

# %%
import matplotlib.pyplot as plt
from sklearn.metrics import precision_recall_curve, average_precision_score
from sklearn.preprocessing import label_binarize
import numpy as np

# Assuming the models are defined and trained: models dictionary from the previous step
# Also assuming y_test and y_test_binarized are defined

# Initialize the plot
plt.figure(figsize=(12, 8))

# Plot PR-AUC curves for all models
for model_name, model in models.items():
    # Predict probabilities or decision function
    if hasattr(model, "predict_proba"):
        y_pred_proba = model.predict_proba(X_test)
    else:
        y_pred_proba = model.decision_function(X_test)
    
    # Initialize variables to calculate macro-average PR curve
    precisions = []
    recalls = []
    auc_scores = []
    
    # Compute PR curve and AUC for each class
    for i in range(y_test_binarized.shape[1]):
        precision, recall, _ = precision_recall_curve(y_test_binarized[:, i], y_pred_proba[:, i])
        pr_auc = average_precision_score(y_test_binarized[:, i], y_pred_proba[:, i])
        
        # Interpolate to standardize recall points (for averaging)
        recalls_interp = np.linspace(0, 1, 100)
        precisions_interp = np.interp(recalls_interp, recall[::-1], precision[::-1])
        
        precisions.append(precisions_interp)
        auc_scores.append(pr_auc)
    
    # Compute the macro-average precision and recall
    macro_precision = np.mean(precisions, axis=0)
    macro_recall = np.linspace(0, 1, 100)
    macro_auc = np.mean(auc_scores)
    
    # Plot the macro-average PR curve
    plt.plot(macro_recall, macro_precision, label=f"{model_name} (PR-AUC: {macro_auc:.2f})")

# Plot settings
plt.title("Macro-Averaged Precision-Recall Curves for All Models")
plt.xlabel("Recall")
plt.ylabel("Precision")
plt.legend(loc="lower left")
plt.grid()
plt.show()

# %%
# from sklearn.ensemble import RandomForestClassifier
# from sklearn.svm import SVC
# from sklearn.neighbors import KNeighborsClassifier
# from sklearn.naive_bayes import GaussianNB
# from sklearn.metrics import accuracy_score
# from xgboost import XGBClassifier

# # Define the range of random states to test
# random_states = range(0, 50)  # Adjust this range as needed

# # Define the models with initial parameters
# models = {
#     'Random Forest': RandomForestClassifier(),
#     # 'XGBoost': XGBClassifier(**best_xgb_params),  # Assuming best_params are defined
#     # 'SVM': SVC(**best_svm_params),
#     # 'KNN': KNeighborsClassifier(**best_knn_params),
# }

# # Dictionary to store the best random state and accuracy for each model
# best_results = {}

# # Iterate through each model
# for model_name, model in models.items():
#     print(f"\nEvaluating {model_name}...")
    
#     best_accuracy = 0
#     best_random_state = None
#     accuracy_dict = {}
    
#     # Iterate through each random state
#     for state in random_states:
#         # Check if the model has a random_state parameter
#         if 'random_state' in model.get_params():
#             model.set_params(random_state=state)

#         # Train the model
#         model.fit(X_train, y_train)
        
#         # Predict on the test set
#         y_pred = model.predict(X_test)
        
#         # Calculate accuracy
#         accuracy = accuracy_score(y_test, y_pred)
#         accuracy_dict[state] = accuracy
        
#         # Update best accuracy and random state if needed
#         if accuracy > best_accuracy:
#             best_accuracy = accuracy
#             best_random_state = state
        
#         # Print accuracy for the current random state
#         print(f"Random State {state}: Accuracy = {accuracy:.2%}")

#     # Store the best random state and accuracy for the current model
#     best_results[model_name] = {
#         'Best Random State': best_random_state,
#         'Best Accuracy': best_accuracy,
#         'All Accuracies': accuracy_dict
#     }

#     # Print the best random state and accuracy for the current model
#     print(f"\nBest Random State for {model_name}: {best_random_state}")
#     print(f"Best Accuracy for {model_name}: {best_accuracy:.2%}")

# # Print summary of best results for all models
# print("\nSummary of Best Results:")
# for model_name, results in best_results.items():
#     print(f"{model_name}: Best Random State = {results['Best Random State']}, Best Accuracy = {results['Best Accuracy']:.2%}")

# %%
import matplotlib.pyplot as plt
from sklearn.metrics import roc_curve, auc
from xgboost import XGBClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn.preprocessing import label_binarize
from sklearn.multiclass import OneVsRestClassifier
from sklearn.model_selection import train_test_split

# Split the data into train and test sets

# Binarize labels for ROC computation (needed for multiclass)
y_binarized = label_binarize(y_test, classes=list(range(len(set(y)))))

# Initialize models with the best parameters
xgb_model = XGBClassifier(**best_xgb_params)
rf_model = RandomForestClassifier(**best_rf_params)
knn_model = KNeighborsClassifier(**best_knn_params)
svm_model =SVC(**best_svm_params, probability=True)

# Fit models
xgb_model.fit(X_train, y_train)
rf_model.fit(X_train, y_train)
knn_model.fit(X_train, y_train)
svm_model.fit(X_train, y_train)

# Predict probabilities
xgb_probs = xgb_model.predict_proba(X_test)
rf_probs = rf_model.predict_proba(X_test)
knn_probs = knn_model.predict_proba(X_test)
svm_probs = svm_model.predict_proba(X_test)

# Compute ROC curves and AUCs
plt.figure(figsize=(10, 8))

models = [
    ("XGBoost", xgb_probs),
    ("Random Forest", rf_probs),
    ("KNN", knn_probs),
    ("SVM", svm_probs)
]

for model_name, probs in models:
    fpr, tpr, _ = roc_curve(y_binarized.ravel(), probs.ravel())
    roc_auc = auc(fpr, tpr)
    plt.plot(fpr, tpr, label=f"{model_name} (AUC = {roc_auc:.2f})")

# Plot random baseline
plt.plot([0, 1], [0, 1], 'k--', label='Random Baseline')

# Add labels and legend
plt.title('ROC Curves for Different Models')
plt.xlabel('False Positive Rate (FPR)')
plt.ylabel('True Positive Rate (TPR)')
plt.legend(loc="lower right")
plt.grid(alpha=0.3)
plt.show()

# %%
import matplotlib.pyplot as plt
from sklearn.metrics import roc_curve, auc
from sklearn.preprocessing import label_binarize
from sklearn.multiclass import OneVsRestClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from xgboost import XGBClassifier

# Class names
classes = ['Normal cases', 'Benign cases', 'Malignant cases']
n_classes = len(classes)

# Binarize the labels
y_binarized = label_binarize(y_test, classes=list(range(n_classes)))

# Initialize models with best parameters
xgb_model = XGBClassifier(**best_xgb_params)
rf_model = RandomForestClassifier(**best_rf_params)
knn_model = KNeighborsClassifier(**best_knn_params)
svm_model = SVC(**best_svm_params, probability=True)

# Fit models
xgb_model.fit(X_train, y_train)
rf_model.fit(X_train, y_train)
knn_model.fit(X_train, y_train)
svm_model.fit(X_train, y_train)

# Predict probabilities
xgb_probs = xgb_model.predict_proba(X_test)
rf_probs = rf_model.predict_proba(X_test)
knn_probs = knn_model.predict_proba(X_test)
svm_probs = svm_model.predict_proba(X_test)

# List of models and their predictions
models = [
    ("XGBoost", xgb_probs),
    ("Random Forest", rf_probs),
    ("KNN", knn_probs),
    ("SVM", svm_probs)
]

# Generate class-specific ROC plots for each model
for model_name, probs in models:
    plt.figure(figsize=(12, 8))
    for i in range(n_classes):
        fpr, tpr, _ = roc_curve(y_binarized[:, i], probs[:, i])
        roc_auc = auc(fpr, tpr)
        
        # Plot ROC curve for each class
        plt.plot(fpr, tpr, label=f"{classes[i]} (AUC = {roc_auc:.2f})")
    
    # Add labels, legend, and random baseline
    plt.plot([0, 1], [0, 1], 'k--', label='Random Baseline')
    plt.title(f"Class-Specific ROC Curves for {model_name}")
    plt.xlabel("False Positive Rate (FPR)")
    plt.ylabel("True Positive Rate (TPR)")
    plt.legend(loc="lower right")
    plt.grid(alpha=0.3)
    plt.show()
