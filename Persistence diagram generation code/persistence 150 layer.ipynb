# %%
import os
import time
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from ripser import ripser
from persim import plot_diagrams
from persim.persistent_entropy import persistent_entropy
from PIL import Image

# Parent directory containing folders with Excel files for each image
excel_folders_parent_dir = "C:\\Users\\Aneesh PB\\Downloads\\Topology Project\\VS code\\Point Cloud\\Normal cases\\"
# entropy_parent_folder = "C:\\Users\\Aneesh PB\\Downloads\\Topology Project\\VS code\\1000points\\Entropy2020\\Malignant cases\\"

i=0
# Iterate over each folder containing Excel files (each folder corresponds to an image)
for image_folder_name in os.listdir(excel_folders_parent_dir):
    # if i==20:
    #     break
    # i+=1
    image_folder_path = os.path.join(excel_folders_parent_dir, image_folder_name)
    image_path= os.path.join("C:\\Users\\Aneesh PB\\Downloads\\Topology Project\\New Data\\Images\\Normal cases\\", image_folder_name + ".jpg")
    
    if os.path.isdir(image_folder_path):
        #print(f"Processing image folder: {image_folder_name}")

        # Create output folder for persistence diagrams
        # output_folder_path = os.path.join("C:\\Users\\Aneesh PB\\Downloads\\Topology Project\\New Data\\Persistence\\Malignant cases\\", image_folder_name)
        # os.makedirs(output_folder_path, exist_ok=True)
        print(image_folder_name)
        img=np.array(Image.open(image_path))
        # Get a list of all Excel files in the directory (point cloud for the current image)
        excel_files = [file for file in os.listdir(image_folder_path) if file.endswith('150.xlsx')]

        # List to store entropy values for current image
        image_entropy_values = []

        # Process each Excel file (each file represents a point cloud for the image)
        for excel_file in excel_files:
            excel_file_path = os.path.join(image_folder_path, excel_file)
            #print(f"Processing Excel file: {excel_file}")

            # Read the coordinates from the Excel file
            df = pd.read_excel(excel_file_path)
            data_array = df.iloc[:, :2].values

            # Compute persistence diagrams
            tic = time.time()
            try:
                res = ripser(data_array, n_perm=1000, maxdim=1)
            except:
                try:
                    res = ripser(data_array, maxdim=1)
                except:
                    print("Skipping")
                    continue

            # toc = time.time()
            # timefull = toc - tic
            # print("Elapsed Time Subsampled Point Cloud: %.3g seconds" % (toc - tic))
            dgms_sub = res['dgms']
            e0 = persistent_entropy(dgms_sub[0])
            e1 = persistent_entropy(dgms_sub[1])
            image_entropy_values.append((excel_file.split('.')[0], e0[0], e1[0]))

            # Plot and save persistence diagrams
            plt.figure(figsize=(4, 4))
            fig,axs = plt.subplots(1,1)
            #axs.imshow(img)
            #plt.imshow(img)
            #print()
            plot_diagrams(dgms_sub,ax=axs)
            plt.title("Normal Case")
            fig.subplots_adjust(wspace=0.5)
            # output_file_path = os.path.join(output_folder_path, f'{os.path.splitext(excel_file)[0]}.png')
            # plt.savefig(output_file_path)
            plt.show()
            # print(f"Saved persistence diagram to: {output_file_path}")

        # Create a DataFrame from the entropy values for the current image
        # entropy_df = pd.DataFrame(columns=['Intensity', 'Entropy 0', 'Entropy 1'], data=image_entropy_values)

        # # Create output folder for entropy if it doesn't exist
        # # entropy_output_folder = os.path.join(entropy_parent_folder, image_folder_name)
        # entropy_output_folder=entropy_parent_folder
        # os.makedirs(entropy_output_folder, exist_ok=True)

        # # Save the DataFrame to an Excel file
        # entropy_excel_file_path = os.path.join(entropy_output_folder, f'{image_folder_name}_Entropy_values.xlsx')
        # entropy_df.to_excel(entropy_excel_file_path, index=False)
        # print(f"Entropy values for image {image_folder_name} saved to: {entropy_excel_file_path}")
# Out:
# Normal case (1)
# Normal case (10)
# Normal case (100)
# Normal case (101)
# Normal case (102)
# Normal case (103)
# Normal case (104)
# Normal case (105)
# Normal case (106)
# Normal case (107)
# Normal case (108)
# Normal case (109)
# Normal case (11)
# Normal case (110)
# Normal case (111)
# Normal case (112)
# Normal case (113)
# Normal case (114)
# Normal case (115)
# Normal case (116)

# %%
import os
import time
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from ripser import ripser
from persim import plot_diagrams
from persim.persistent_entropy import persistent_entropy
from PIL import Image

# Parent directory containing folders with Excel files for each image
excel_folders_parent_dir = "C:\\Users\\Aneesh PB\\Downloads\\Topology Project\\VS code\\Point Cloud\\Normal cases\\"
# entropy_parent_folder = "C:\\Users\\Aneesh PB\\Downloads\\Topology Project\\VS code\\1000points\\Entropy2020\\Malignant cases\\"

i=0
# Iterate over each folder containing Excel files (each folder corresponds to an image)
for image_folder_name in os.listdir(excel_folders_parent_dir):
    # if i==20:
    #     break
    # i+=1
    image_folder_path = os.path.join(excel_folders_parent_dir, image_folder_name)
    image_path= os.path.join("C:\\Users\\Aneesh PB\\Downloads\\Topology Project\\New Data\\Images\\Normal cases\\", image_folder_name + ".jpg")
    
    if os.path.isdir(image_folder_path):
        #print(f"Processing image folder: {image_folder_name}")

        # Create output folder for persistence diagrams
        # output_folder_path = os.path.join("C:\\Users\\Aneesh PB\\Downloads\\Topology Project\\New Data\\Persistence\\Malignant cases\\", image_folder_name)
        # os.makedirs(output_folder_path, exist_ok=True)
        print(image_folder_name)
        img=np.array(Image.open(image_path))
        # Get a list of all Excel files in the directory (point cloud for the current image)
        excel_files = [file for file in os.listdir(image_folder_path) if file.endswith('150.xlsx')]

        # List to store entropy values for current image
        image_entropy_values = []

        # Process each Excel file (each file represents a point cloud for the image)
        for excel_file in excel_files:
            excel_file_path = os.path.join(image_folder_path, excel_file)
            #print(f"Processing Excel file: {excel_file}")

            # Read the coordinates from the Excel file
            df = pd.read_excel(excel_file_path)
            data_array = df.iloc[:, :2].values

            # Compute persistence diagrams
            tic = time.time()
            try:
                res = ripser(data_array, n_perm=1000, maxdim=1)
            except:
                try:
                    res = ripser(data_array, maxdim=1)
                except:
                    print("Skipping")
                    continue

            # toc = time.time()
            # timefull = toc - tic
            # print("Elapsed Time Subsampled Point Cloud: %.3g seconds" % (toc - tic))
            dgms_sub = res['dgms']
            e0 = persistent_entropy(dgms_sub[0])
            e1 = persistent_entropy(dgms_sub[1])
            image_entropy_values.append((excel_file.split('.')[0], e0[0], e1[0]))

            # Plot and save persistence diagrams
            plt.figure(figsize=(4, 4))
            fig,axs = plt.subplots(1,2)
            axs[0].imshow(img)
            #plt.imshow(img)
            #print()
            plot_diagrams(dgms_sub,ax=axs[1])
            plt.title("Subsampled point's persistence diagrams")
            fig.subplots_adjust(wspace=0.5)
            # output_file_path = os.path.join(output_folder_path, f'{os.path.splitext(excel_file)[0]}.png')
            # plt.savefig(output_file_path)
            plt.show()
            # print(f"Saved persistence diagram to: {output_file_path}")

        # Create a DataFrame from the entropy values for the current image
        # entropy_df = pd.DataFrame(columns=['Intensity', 'Entropy 0', 'Entropy 1'], data=image_entropy_values)

        # # Create output folder for entropy if it doesn't exist
        # # entropy_output_folder = os.path.join(entropy_parent_folder, image_folder_name)
        # entropy_output_folder=entropy_parent_folder
        # os.makedirs(entropy_output_folder, exist_ok=True)

        # # Save the DataFrame to an Excel file
        # entropy_excel_file_path = os.path.join(entropy_output_folder, f'{image_folder_name}_Entropy_values.xlsx')
        # entropy_df.to_excel(entropy_excel_file_path, index=False)
        # print(f"Entropy values for image {image_folder_name} saved to: {entropy_excel_file_path}")
# Out:
# Normal case (1)
# Normal case (10)
# Normal case (100)
# Normal case (101)
# Normal case (102)
# Normal case (103)
# Normal case (104)
# Normal case (105)
# Normal case (106)
# Normal case (107)
# Normal case (108)
# Normal case (109)
# Normal case (11)
# Normal case (110)
# Normal case (111)
# Normal case (112)
# Normal case (113)
# Normal case (114)
# Normal case (115)
# Normal case (116)

# %%
import os
import time
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from ripser import ripser
from persim import plot_diagrams
from persim.persistent_entropy import persistent_entropy

# Parent directory containing folders with Excel files for each image
excel_folders_parent_dir = "C:\\Users\\Aneesh PB\\Downloads\\Topology Project\\VS code\\Point Cloud\\Bengin cases\\"
# entropy_parent_folder = "C:\\Users\\Aneesh PB\\Downloads\\Topology Project\\VS code\\1000points\\Entropy2020\\Malignant cases\\"

i=0
# Iterate over each folder containing Excel files (each folder corresponds to an image)
for image_folder_name in os.listdir(excel_folders_parent_dir):
    # if i==20:
    #     break
    # i+=1
    print(image_folder_name)
    image_folder_path = os.path.join(excel_folders_parent_dir, image_folder_name)
    if os.path.isdir(image_folder_path):
        #print(f"Processing image folder: {image_folder_name}")

        # Create output folder for persistence diagrams
        # output_folder_path = os.path.join("C:\\Users\\Aneesh PB\\Downloads\\Topology Project\\New Data\\Persistence\\Malignant cases\\", image_folder_name)
        # os.makedirs(output_folder_path, exist_ok=True)

        # Get a list of all Excel files in the directory (point cloud for the current image)
        excel_files = [file for file in os.listdir(image_folder_path) if file.endswith('150.xlsx')]

        # List to store entropy values for current image
        image_entropy_values = []
        
        # Process each Excel file (each file represents a point cloud for the image)
        for excel_file in excel_files:
            excel_file_path = os.path.join(image_folder_path, excel_file)
            #print(f"Processing Excel file: {excel_file}")

            # Read the coordinates from the Excel file
            df = pd.read_excel(excel_file_path)
            data_array = df.iloc[:, :2].values

            # Compute persistence diagrams
            tic = time.time()
            try:
                res = ripser(data_array, n_perm=1000, maxdim=1)
            except:
                try:
                    res = ripser(data_array, maxdim=1)
                except:
                    print("Skipping")
                    continue

            # toc = time.time()
            # timefull = toc - tic
            # print("Elapsed Time Subsampled Point Cloud: %.3g seconds" % (toc - tic))
            dgms_sub = res['dgms']
            e0 = persistent_entropy(dgms_sub[0])
            e1 = persistent_entropy(dgms_sub[1])
            image_entropy_values.append((excel_file.split('.')[0], e0[0], e1[0]))

            # Plot and save persistence diagrams
            plt.figure(figsize=(4, 4))
            plot_diagrams(dgms_sub)
            plt.title("Benign Case")
            # output_file_path = os.path.join(output_folder_path, f'{os.path.splitext(excel_file)[0]}.png')
            # plt.savefig(output_file_path)
            plt.show()
            # print(f"Saved persistence diagram to: {output_file_path}")

        # Create a DataFrame from the entropy values for the current image
        # entropy_df = pd.DataFrame(columns=['Intensity', 'Entropy 0', 'Entropy 1'], data=image_entropy_values)

        # # Create output folder for entropy if it doesn't exist
        # # entropy_output_folder = os.path.join(entropy_parent_folder, image_folder_name)
        # entropy_output_folder=entropy_parent_folder
        # os.makedirs(entropy_output_folder, exist_ok=True)

        # # Save the DataFrame to an Excel file
        # entropy_excel_file_path = os.path.join(entropy_output_folder, f'{image_folder_name}_Entropy_values.xlsx')
        # entropy_df.to_excel(entropy_excel_file_path, index=False)
        # print(f"Entropy values for image {image_folder_name} saved to: {entropy_excel_file_path}")
# Out:
# Bengin case (1)
# Bengin case (10)
# Bengin case (100)
# Bengin case (101)
# Bengin case (102)
# Bengin case (103)
# Bengin case (104)
# Bengin case (105)
# Bengin case (106)
# Bengin case (107)
# Bengin case (108)
# Bengin case (109)
# Bengin case (11)
# Bengin case (110)
# Bengin case (111)
# Bengin case (112)
# Bengin case (113)
# Bengin case (114)
# Bengin case (115)
# Bengin case (116)

# %%
import os
import time
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from ripser import ripser
from persim import plot_diagrams
from persim.persistent_entropy import persistent_entropy

# Parent directory containing folders with Excel files for each image
excel_folders_parent_dir = "C:\\Users\\Aneesh PB\\Downloads\\Topology Project\\VS code\\Point Cloud\\Malignant cases\\"
# entropy_parent_folder = "C:\\Users\\Aneesh PB\\Downloads\\Topology Project\\VS code\\1000points\\Entropy2020\\Malignant cases\\"

i=0
# Iterate over each folder containing Excel files (each folder corresponds to an image)
for image_folder_name in os.listdir(excel_folders_parent_dir):
    print(image_folder_name)
    # if i==20:
    #     break
    # i+=1
    image_folder_path = os.path.join(excel_folders_parent_dir, image_folder_name)
    if os.path.isdir(image_folder_path):
        #print(f"Processing image folder: {image_folder_name}")

        # Create output folder for persistence diagrams
        # output_folder_path = os.path.join("C:\\Users\\Aneesh PB\\Downloads\\Topology Project\\New Data\\Persistence\\Malignant cases\\", image_folder_name)
        # os.makedirs(output_folder_path, exist_ok=True)

        # Get a list of all Excel files in the directory (point cloud for the current image)
        excel_files = [file for file in os.listdir(image_folder_path) if file.endswith('150.xlsx')]

        # List to store entropy values for current image
        image_entropy_values = []

        # Process each Excel file (each file represents a point cloud for the image)
        for excel_file in excel_files:
            excel_file_path = os.path.join(image_folder_path, excel_file)
            #print(f"Processing Excel file: {excel_file}")

            # Read the coordinates from the Excel file
            df = pd.read_excel(excel_file_path)
            data_array = df.iloc[:, :2].values

            # Compute persistence diagrams
            tic = time.time()
            try:
                res = ripser(data_array, n_perm=1000, maxdim=1)
            except:
                try:
                    res = ripser(data_array, maxdim=1)
                except:
                    print("Skipping")
                    continue

            # toc = time.time()
            # timefull = toc - tic
            # print("Elapsed Time Subsampled Point Cloud: %.3g seconds" % (toc - tic))
            dgms_sub = res['dgms']
            e0 = persistent_entropy(dgms_sub[0])
            e1 = persistent_entropy(dgms_sub[1])
            image_entropy_values.append((excel_file.split('.')[0], e0[0], e1[0]))

            # Plot and save persistence diagrams
            plt.figure(figsize=(4, 4))
            plot_diagrams(dgms_sub)
            plt.title("Malignant Case")
            # output_file_path = os.path.join(output_folder_path, f'{os.path.splitext(excel_file)[0]}.png')
            # plt.savefig(output_file_path)
            plt.show()
            # print(f"Saved persistence diagram to: {output_file_path}")

        # Create a DataFrame from the entropy values for the current image
        # entropy_df = pd.DataFrame(columns=['Intensity', 'Entropy 0', 'Entropy 1'], data=image_entropy_values)

        # # Create output folder for entropy if it doesn't exist
        # # entropy_output_folder = os.path.join(entropy_parent_folder, image_folder_name)
        # entropy_output_folder=entropy_parent_folder
        # os.makedirs(entropy_output_folder, exist_ok=True)

        # # Save the DataFrame to an Excel file
        # entropy_excel_file_path = os.path.join(entropy_output_folder, f'{image_folder_name}_Entropy_values.xlsx')
        # entropy_df.to_excel(entropy_excel_file_path, index=False)
        # print(f"Entropy values for image {image_folder_name} saved to: {entropy_excel_file_path}")
# Out:
# Malignant case (1)
# Malignant case (10)
# Malignant case (11)
# Malignant case (12)
# Malignant case (13)
# Malignant case (14)
# Malignant case (15)
# Malignant case (16)
# Malignant case (17)
# Malignant case (18)
# Malignant case (19)
# Malignant case (2)
# Malignant case (20)
# Malignant case (3)
# Malignant case (4)
# Malignant case (5)
# Malignant case (6)
# Malignant case (7)
# Malignant case (8)
# Malignant case (9)

# %%
import os
import time
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from ripser import ripser
from persim import plot_diagrams
from persim.persistent_entropy import persistent_entropy
from PIL import Image

# Parent directory containing folders with Excel files for each image
excel_folders_parent_dir = "C:\\Users\\Aneesh PB\\Downloads\\Topology Project\\VS code\\Point Cloud\\Bengin cases\\"
# entropy_parent_folder = "C:\\Users\\Aneesh PB\\Downloads\\Topology Project\\VS code\\1000points\\Entropy2020\\Malignant cases\\"

i=0
# Iterate over each folder containing Excel files (each folder corresponds to an image)
for image_folder_name in os.listdir(excel_folders_parent_dir):
    # if i==20:
    #     break
    # i+=1
    image_folder_path = os.path.join(excel_folders_parent_dir, image_folder_name)
    image_path= os.path.join("C:\\Users\\Aneesh PB\\Downloads\\Topology Project\\New Data\\Images\\Bengin cases\\", image_folder_name + ".jpg")
    
    if os.path.isdir(image_folder_path):
        #print(f"Processing image folder: {image_folder_name}")

        # Create output folder for persistence diagrams
        # output_folder_path = os.path.join("C:\\Users\\Aneesh PB\\Downloads\\Topology Project\\New Data\\Persistence\\Malignant cases\\", image_folder_name)
        # os.makedirs(output_folder_path, exist_ok=True)
        print(image_folder_name)
        img=np.array(Image.open(image_path))
        # Get a list of all Excel files in the directory (point cloud for the current image)
        excel_files = [file for file in os.listdir(image_folder_path) if file.endswith('150.xlsx')]

        # List to store entropy values for current image
        image_entropy_values = []

        # Process each Excel file (each file represents a point cloud for the image)
        for excel_file in excel_files:
            excel_file_path = os.path.join(image_folder_path, excel_file)
            #print(f"Processing Excel file: {excel_file}")

            # Read the coordinates from the Excel file
            df = pd.read_excel(excel_file_path)
            data_array = df.iloc[:, :2].values

            # Compute persistence diagrams
            tic = time.time()
            try:
                res = ripser(data_array, n_perm=1000, maxdim=1)
            except:
                try:
                    res = ripser(data_array, maxdim=1)
                except:
                    print("Skipping")
                    continue

            # toc = time.time()
            # timefull = toc - tic
            # print("Elapsed Time Subsampled Point Cloud: %.3g seconds" % (toc - tic))
            dgms_sub = res['dgms']
            e0 = persistent_entropy(dgms_sub[0])
            e1 = persistent_entropy(dgms_sub[1])
            image_entropy_values.append((excel_file.split('.')[0], e0[0], e1[0]))

            # Plot and save persistence diagrams
            plt.figure(figsize=(4, 4))
            fig,axs = plt.subplots(1,2)
            axs[0].imshow(img)
            #plt.imshow(img)
            #print()
            plot_diagrams(dgms_sub,ax=axs[1])
            plt.title("Subsampled point's persistence diagrams")
            fig.subplots_adjust(wspace=0.5)
            # output_file_path = os.path.join(output_folder_path, f'{os.path.splitext(excel_file)[0]}.png')
            # plt.savefig(output_file_path)
            plt.show()
            # print(f"Saved persistence diagram to: {output_file_path}")

        # Create a DataFrame from the entropy values for the current image
        # entropy_df = pd.DataFrame(columns=['Intensity', 'Entropy 0', 'Entropy 1'], data=image_entropy_values)

        # # Create output folder for entropy if it doesn't exist
        # # entropy_output_folder = os.path.join(entropy_parent_folder, image_folder_name)
        # entropy_output_folder=entropy_parent_folder
        # os.makedirs(entropy_output_folder, exist_ok=True)

        # # Save the DataFrame to an Excel file
        # entropy_excel_file_path = os.path.join(entropy_output_folder, f'{image_folder_name}_Entropy_values.xlsx')
        # entropy_df.to_excel(entropy_excel_file_path, index=False)
        # print(f"Entropy values for image {image_folder_name} saved to: {entropy_excel_file_path}")
# Out:
# Bengin case (1)
# Bengin case (10)
# Bengin case (100)
# Bengin case (101)
# Bengin case (102)
# Bengin case (103)
# Bengin case (104)
# Bengin case (105)
# Bengin case (106)
# Bengin case (107)
# Bengin case (108)
# Bengin case (109)
# Bengin case (11)
# Bengin case (110)
# Bengin case (111)
# Bengin case (112)
# Bengin case (113)
# Bengin case (114)
# Bengin case (115)
# Bengin case (116)

# %%
import os
import time
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from ripser import ripser
from persim import plot_diagrams
from persim.persistent_entropy import persistent_entropy
from PIL import Image

# Parent directory containing folders with Excel files for each image
excel_folders_parent_dir = "C:\\Users\\Aneesh PB\\Downloads\\Topology Project\\VS code\\Point Cloud\\Malignant cases\\"
# entropy_parent_folder = "C:\\Users\\Aneesh PB\\Downloads\\Topology Project\\VS code\\1000points\\Entropy2020\\Malignant cases\\"

i=0
# Iterate over each folder containing Excel files (each folder corresponds to an image)
for image_folder_name in os.listdir(excel_folders_parent_dir):
    # if i==20:
    #     break
    # i+=1
    image_folder_path = os.path.join(excel_folders_parent_dir, image_folder_name)
    image_path= os.path.join("C:\\Users\\Aneesh PB\\Downloads\\Topology Project\\New Data\\Images\\Malignant cases\\", image_folder_name + ".jpg")
    
    if os.path.isdir(image_folder_path):
        #print(f"Processing image folder: {image_folder_name}")

        # Create output folder for persistence diagrams
        # output_folder_path = os.path.join("C:\\Users\\Aneesh PB\\Downloads\\Topology Project\\New Data\\Persistence\\Malignant cases\\", image_folder_name)
        # os.makedirs(output_folder_path, exist_ok=True)
        print(image_folder_name)
        img=np.array(Image.open(image_path))
        # Get a list of all Excel files in the directory (point cloud for the current image)
        excel_files = [file for file in os.listdir(image_folder_path) if file.endswith('150.xlsx')]

        # List to store entropy values for current image
        image_entropy_values = []

        # Process each Excel file (each file represents a point cloud for the image)
        for excel_file in excel_files:
            excel_file_path = os.path.join(image_folder_path, excel_file)
            #print(f"Processing Excel file: {excel_file}")

            # Read the coordinates from the Excel file
            df = pd.read_excel(excel_file_path)
            data_array = df.iloc[:, :2].values

            # Compute persistence diagrams
            tic = time.time()
            try:
                res = ripser(data_array, n_perm=1000, maxdim=1)
            except:
                try:
                    res = ripser(data_array, maxdim=1)
                except:
                    print("Skipping")
                    continue

            # toc = time.time()
            # timefull = toc - tic
            # print("Elapsed Time Subsampled Point Cloud: %.3g seconds" % (toc - tic))
            dgms_sub = res['dgms']
            e0 = persistent_entropy(dgms_sub[0])
            e1 = persistent_entropy(dgms_sub[1])
            image_entropy_values.append((excel_file.split('.')[0], e0[0], e1[0]))

            # Plot and save persistence diagrams
            plt.figure(figsize=(4, 4))
            fig,axs = plt.subplots(1,2)
            axs[0].imshow(img)
            #plt.imshow(img)
            #print()
            plot_diagrams(dgms_sub,ax=axs[1])
            plt.title("Subsampled point's persistence diagrams")
            fig.subplots_adjust(wspace=0.5)
            # output_file_path = os.path.join(output_folder_path, f'{os.path.splitext(excel_file)[0]}.png')
            # plt.savefig(output_file_path)
            plt.show()
            # print(f"Saved persistence diagram to: {output_file_path}")

        # Create a DataFrame from the entropy values for the current image
        # entropy_df = pd.DataFrame(columns=['Intensity', 'Entropy 0', 'Entropy 1'], data=image_entropy_values)

        # # Create output folder for entropy if it doesn't exist
        # # entropy_output_folder = os.path.join(entropy_parent_folder, image_folder_name)
        # entropy_output_folder=entropy_parent_folder
        # os.makedirs(entropy_output_folder, exist_ok=True)

        # # Save the DataFrame to an Excel file
        # entropy_excel_file_path = os.path.join(entropy_output_folder, f'{image_folder_name}_Entropy_values.xlsx')
        # entropy_df.to_excel(entropy_excel_file_path, index=False)
        # print(f"Entropy values for image {image_folder_name} saved to: {entropy_excel_file_path}")
# Out:
# Malignant case (1)
# Malignant case (10)
# Malignant case (11)
# Malignant case (12)
# Malignant case (13)
# Malignant case (14)
# Malignant case (15)
# Malignant case (16)
# Malignant case (17)
# Malignant case (18)
# Malignant case (19)
# Malignant case (2)
# Malignant case (20)
# Malignant case (3)
# Malignant case (4)
# Malignant case (5)
# Malignant case (6)
# Malignant case (7)
# Malignant case (8)
# Malignant case (9)
